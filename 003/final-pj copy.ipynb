# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import fetch_20newsgroups
from sklearn.metrics import confusion_matrix

# %%
data = fetch_20newsgroups()
categories = data.target_names
train = fetch_20newsgroups(subset='train', categories=categories)
test = fetch_20newsgroups(subset='test', categories=categories)

# %%
categories
# Out:
# ['alt.atheism',
#  'comp.graphics',
#  'comp.os.ms-windows.misc',
#  'comp.sys.ibm.pc.hardware',
#  'comp.sys.mac.hardware',
#  'comp.windows.x',
#  'misc.forsale',
#  'rec.autos',
#  'rec.motorcycles',
#  'rec.sport.baseball',
#  'rec.sport.hockey',
#  'sci.crypt',
#  'sci.electronics',
#  'sci.med',
#  'sci.space',
#  'soc.religion.christian',
#  'talk.politics.guns',
#  'talk.politics.mideast',
#  'talk.politics.misc',
#  'talk.religion.misc']

# %%
vocab_set = set()

# %%
for dstr in train.data:
    words = dstr.lower().split()
    vocab_set.update(words)

# %%
vocab_list = list(vocab_set)

# %%
vocab_list
# Out:
# ['silliness',
#  'drooled',
#  "max>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'a\\!;5\\]7u%?/5]34r,]7",
#  '1919.',
#  'makes:',
#  'bad;',
#  'bagirov,',
#  'tamaqua',
#  '"identify"',
#  '#!/usr/bin/perl',
#  'contract;',
#  'encylcopedia',
#  'candlewood',
#  'yet?',
#  'fallible,',
#  '>>well',
#  ':-(((',
#  '[start]',
#  'iici',
#  'printf("enter',
#  'chemistry:',
#  'halcyon',
#  '--autoweek',
#  'karagodaviev.',
#  '+1-415-494-4440',
#  'pistol:',
#  'toy"',
#  'investor',
#  "m%a86%a86%lg)r<f)b8f)b8e,3$qgq<4t-(n+-`'>o`w,e.$i+8-d[-qho;7l",
#  '>subsequent',
#  '"kind,',
#  'newsletter)',
#  'pittsburgh),',
#  'exotics',
#  'boots...',
#  'resistive.',
#  '_floor,',
#  'grant',
#  'secondaries',
#  'level."',
#  'phoniest',
#  'aliases/macros',
#  'confederation',
#  'encrypted?',
#  'ellison,',
#  ';10110011',
#  '<1993apr2.050451.7866@ucsu.colorado.edu>,',
#  'mf9f9hj)if6fb:=k]f?w]f?w]_8n+_9g]_9g:_9fbvj)i:6eiz#+h,f)b8f)b',
#  'lupron,',
#  '<ka0k+@andrew.cmu.edu>',
#  'intercourse',
#  "mk>>+'o79((;o7*478f,z3]\\/[x)3$^q2zg9zo_76$uqumcv#^l7;+93e/14+",
#  '<1r54to$oh@access.digex.net>',
#  'centre.',
#  ')()',
#  '3/4',
#  'things:',
#  'fatwa.',
#  'government-sponsored',
#  'sword.")',
#  '[wel82]',
#  '(8-46-3)',
#  '(~us$',
#  'vpnet',
#  'wickman',
#  '(oposite',
#  "mtd?,-,rd1]ad4*'<rur<1>tlt$`4ogf#p9`#+_wk19d$4>ulo-;c.u)+ccu-",
#  'archive-server@eff.org,',
#  '(dbgwab@arco.com)',
#  '>passion',
#  "md6g':2]iqsk'q\\>&:6g'qr\\zd3k':9%i.b\\zri%i03ho.ck*.cho+y'8d<k*",
#  'bedrooms',
#  'ipx).',
#  'increase:',
#  '989.8',
#  'jpeg-faq',
#  '185',
#  'upper/lower',
#  '(revised',
#  'sop',
#  'insane!"',
#  'draper@odin.mda.uth.tmc.edu',
#  "kekule's",
#  '1400k',
#  'perfect,',
#  'mortal.',
#  'marking',
#  'rotunda,',
#  'otl',
#  'bnr',
#  'cdma',
#  'sele_pntr->rooty+=',
#  'darling)',
#  "i)lu=3c-6x[73+/=pve-zf\\pf6>yn/'*o%4,r(g.",
#  "8'f=.ec62.)",
#  'm!0db.%%!@ns!-*ks',
#  'order,',
#  '>>joe',
#  '6mj>qs?t:"wefl5lfl4zfl7rd#!qiwbp:\'&eax?ba[+)j+.]a30',
#  '508',
#  'donahue)',
#  '>transfusion',
#  'pagans,',
#  'st1g9@rosie.uh.edu',
#  '<1993apr03.232325.23178@acme.gen.nz>',
#  'peru',
#  '21.5]',
#  'newsnet',
#  'vary.......',
#  'buckel)',
#  '(_university_physics_)',
#  '<1993apr19.194525.3888@lambda.msfc.nasa.gov>',
#  'sale-canon',
#  '"hi,',
#  'partitions,',
#  '>>unworthy',
#  '8;:53=ujbzk8!,vai5n$7uenq.%2x@@]fw:;\\s;',
#  'camel,',
#  'caps',
#  'briefing',
#  '1993:',
#  'adaquate',
#  'underoos',
#  'lineberry)',
#  'wheeler,',
#  'tutor."',
#  'm-"<)"0el;',
#  '>_moved_',
#  'kiehl,',
#  'betty',
#  'keysearch',
#  'kjenks@jsc.nasa.gov',
#  'hell..',
#  '"exposed',
#  '(703)-620-2200',
#  'qdieh',
#  'seen',
#  '703-281-3277',
#  'batwood@su1ab.harris-atd.com',
#  'walkie-talkies,',
#  '"excuse."',
#  '(lafontaine,',
#  'itself).',
#  '<1993apr21.170817.15845@sq.sq.com>',
#  're-creating',
#  'remixes',
#  'hurrah',
#  '07/02/95',
#  'persecuted,',
#  "mn;:yn;g<w-s<w-s<t471145ww45%=sq%=w?1w='=w=uww45%=w?=1=w=t=%%",
#  'madden',
#  'donchin',
#  'envelopes',
#  'beating",',
#  'fda/fbi/dea/batf',
#  'smileys,',
#  'driverand',
#  'ruckle)',
#  '(pascal',
#  'survaillance',
#  'reently',
#  'code,',
#  'industry,',
#  'chatnam',
#  'furnishing',
#  'dollars,',
#  'max>\'ax>\'ax>\'ax>\'ax>\'ax>\'aw6igiyxg.$*`7c-h8&,c"o-@]8i+3#ex20i',
#  'perpetuated',
#  'bonnie',
#  '"convertible"',
#  '(rexlex@fnal.fnal.gov)',
#  'mcelhiney',
#  't045-1',
#  'pub/plplot',
#  'grams',
#  '8y5d:p#,6k8&hou_m@:)s=;@b=d:@+]e:x',
#  'political',
#  'ghetto...',
#  'vedas.',
#  'm\'?$^(at=?k;"75u=?0&<,qa\\84an`m34u-34(-34(-0("`@("`@("":z71h:',
#  'll12@quads.uchicago.edu',
#  'one!!!!!!',
#  'patrons.',
#  '>sellouts)',
#  'cycling)',
#  'brilliant',
#  '>follow.',
#  'fpddet4.mentorg.com',
#  'haas',
#  '10,1964,',
#  'pedieos',
#  'rare???',
#  'team.',
#  '>all',
#  '0.407',
#  'access...',
#  'avraham',
#  '>defenseman.',
#  'ocelot.ioc.co.uk',
#  '8088/80286',
#  'airplanes;',
#  'e-mail:c.h.a.wong@bradford.ac.uk',
#  '(erwin',
#  'nationalized',
#  'pyron',
#  'sniff',
#  'mourns',
#  'magazine',
#  'greece:',
#  '(henrik',
#  'kasiniyor...',
#  'informatie',
#  '(gil',
#  'planned!)',
#  '42m',
#  'roman,',
#  'saltpeter?',
#  'gerhard',
#  'anatomy/cell',
#  'bclarke@galaxy.gov.bc.ca',
#  'mik',
#  'printf("will',
#  '[128.148.33.66]',
#  'claebaur@cup.portal.com',
#  'continues...i',
#  'rstevew@armory.com',
#  'push(@w,',
#  '72766',
#  'smb@col.hp.com',
#  "24's",
#  'abroad',
#  '277-9234.',
#  'endure.',
#  'medicine:',
#  '"defense"',
#  '(sans',
#  'comparable.',
#  'em"3ym;6t^;0em;6t)u-34;=1m',
#  '11:31:27',
#  'nasty.',
#  '&<te&p)"6p)"0d);6w4u#\'[^_o[^s>\\"@jlbzr+_8n+k*s]b_u7',
#  '<93apr08.202003.27851@acs.ucalgary.ca>',
#  'difficult?',
#  'but...what',
#  '(800)-usa-maps.',
#  "questions'",
#  '1-301-601-2215',
#  'person...and',
#  'octane',
#  'max>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax<qq,1f"z5\'w]]z*kn[n[n[nux#f9f9',
#  "md2^1qsii+y&1+vf1:9%i.fg'+vdzd3hz.l?':6ei:6f1.chzacj1d3hz.cj1",
#  'relational',
#  "m09'8ri'8rb\\z.i%!.m@z+y'*+\\hz.chzd<k*d2\\zrm@z.mb&+sj1+\\j1rlk*",
#  'pegged,',
#  'amusing..',
#  'argc;',
#  'lees',
#  'kac923',
#  '1320,',
#  '"proceedings',
#  'bunning',
#  '<1993apr21.155714.1@stsci.edu>',
#  'heathkit',
#  'frisky',
#  'johnston@me.udel.edu',
#  'hal9k.ann-arbor.mi.us,',
#  'uk.ac.ic.doc.src',
#  'pumped',
#  'dupes',
#  ')bonne',
#  'steczkowski)',
#  'ma7?=w4#1t=w=w7?==]u)=w?==tf%a85)=t!)w4!`w4f%2=u)24#==x5w27>%',
#  '(internet:',
#  'cabs,',
#  '>[stuff',
#  'caused....',
#  'instigated.',
#  '(leads',
#  'export.lcs.mit.edu:contrib/xwip.tar.z',
#  'o.b:8?n@8?x',
#  "m#&et@yd%<'0#g$0%0s>",
#  '520-5720',
#  '"homosexuality",',
#  'overriding',
#  'urn."',
#  "berman's",
#  '1)spike',
#  'ciphers,',
#  'post-season',
#  'color.pixel,',
#  'infoworld',
#  'stratagem',
#  'indivual',
#  'but:',
#  "m(8>'ax=&:vo/5\\bjp3n@fb6x@^&?8/4<z]z?8%&k#?514?5@-xppax>'ax>'",
#  '(dark)',
#  '"kay"',
#  'taking).',
#  'p.i.m.i.',
#  'violate.',
#  'mcgeachie,',
#  '16),',
#  '818/246-5618.',
#  'piercingly',
#  'shape..',
#  'survey,complaints',
#  'brown-nosers',
#  '(primitive)',
#  'even"]',
#  'caravans.',
#  'steel.',
#  '_ccc_c_#_|__#_ccc_c_____chumphre@comp.vuw.ac.nz_______________________________',
#  "'93-'94",
#  '<1993apr19.235430.6097@mnemosyne.cs.du.edu>',
#  'gussar',
#  'observed',
#  'nf(ws;mfh:vc456_',
#  'm_cp@dt<!w""lg-4+23t*gco@_0&/',
#  'drozinst@db.erau.edu',
#  '"race-related"',
#  'omega,',
#  'mc$o$lr@=+qj],',
#  '290-9744',
#  'arrange',
#  '132.206.41.1',
#  'admonition',
#  'non-coercion,',
#  'box"',
#  'nauseum.',
#  '(jhawk@panix.com)',
#  'productivity,',
#  'your_name',
#  '"ballistic',
#  'gull',
#  '/[i9',
#  'cubs!!!',
#  '(theta+96.0)*pi/180.0;',
#  'performance.',
#  'thorlacius',
#  '>palestine?',
#  'blankenship',
#  'sake),',
#  'mini-trikes',
#  'cartridge,',
#  'agate.1pr5u2$t0b',
#  'receivers',
#  'edo:',
#  '>>syndrome.',
#  'cd-technology:',
#  'pshanley@humsci.auburn.edu',
#  '>ross',
#  "/q'el66uq_4yb5v!rfjz'y.&m^0-hc>'i",
#  '(turns',
#  'black"',
#  'non-turbo??',
#  'a.gp.cs.cmu.edu',
#  'alaca',
#  'internet/bitnet',
#  '(194,000)',
#  'address...',
#  '(consumables)',
#  'kinesis',
#  'trades/aquisitions',
#  '5.0/6.0',
#  '1-day',
#  '2099',
#  'offline',
#  'torkel@sics.se',
#  '68bugauto-stick,',
#  'participate,',
#  'bursters',
#  'sciences"',
#  're-broadcast',
#  '1159',
#  'combination)',
#  'overlooked.',
#  'student',
#  'dyoung@netcom.com',
#  'retreived',
#  'comp.graphics.algorithms.2d',
#  '>upon',
#  "m'c??axru2xdrjh*",
#  'infante@acpub.duke.edu',
#  'dimant,',
#  '640x480/256',
#  'mb4q,3$q,3$q,b8f)3$q,b8f)b8f)b8f)b8e,3$q,3$q,3$q,3$q,3$q,#p]g',
#  'simpler,',
#  "max>'ax>'ax>'ax>'ax>'ax>'ax>'ax>',<3$q&9f9f9fq,3$q#$q,3$qax>'",
#  'aromatic',
#  'vincent@reg.triumf.ca',
#  '>"you',
#  'parallel,',
#  'mets,',
#  'coccidiomycosis.',
#  '>clone',
#  '{uunet,',
#  '(160)',
#  '>timers,',
#  '1409.7',
#  'hqn2&mv,\\>&at0t(jd8"u$4w',
#  '(800)322-3464',
#  '10th.',
#  'newsadmin',
#  'escapes',
#  'koshklu',
#  'nathan@chemres.tn.cornell.edu',
#  'heat!',
#  'lobbying.',
#  'als',
#  '[today],',
#  'microphone!',
#  'char(196)',
#  'mod,',
#  'ml+"pl+"p&1d9&1d9&1d9&5>bhj(4`eo`.&$e)76>`0&!h9]@e1,!`9zit,"j',
#  'zrcj]81yup**z,zkr6c&?ge-tl;*!9#11p8]dv%!vc*!f*jdv(',
#  '06:16:54',
#  'ltd.,',
#  '(yung',
#  'a.d.,',
#  'setwutime',
#  '21:00:00',
#  '"turning',
#  'hahn@csd4.csd.uwm.edu',
#  'xga-2!',
#  'gleeful',
#  'invertebrates',
#  'eyes...',
#  '65)!',
#  '4runners',
#  '|>french',
#  'grass-ftp-admin@moon.cecer.army.mil.',
#  '861',
#  '01',
#  'groups?',
#  'calling",',
#  'bears,',
#  'u.w.',
#  'erh0362@tesla.njit.edu',
#  'humble.',
#  'pobox',
#  '>sector.',
#  '2.1%',
#  'phones',
#  '244.',
#  'tower).',
#  'email>',
#  'k_mullin@oz.plymouth.edu',
#  'game.',
#  'dog)',
#  'capacitances)?',
#  "system'",
#  'avenge',
#  '"sell',
#  '<1993apr20.040449.19649@twg.com>,',
#  'incarceration.',
#  '23:00:00',
#  '(frans@kiwi.uia.ac.be)',
#  'argued,',
#  '...!{decvax,hplabs,ncar,purdue,rutgers}!gatech!prism!gw18',
#  'tells',
#  "m>7eyk'ey>7g]>?uy>7ey:ouy_7g]_?w]_7g]_7ey>3;]-gdv-c8v=1d,r\\o+",
#  'sunos_4.1.3,',
#  'shipping,',
#  'e-mail>>',
#  'rundqvist',
#  '1,750',
#  'atheism?"',
#  '-dollar',
#  'distant',
#  'owe',
#  'flung',
#  '2^{512}.',
#  'middle-class',
#  'mcwiggins',
#  'meredith',
#  'bayonetted,',
#  '#8;-)>',
#  'nubus)',
#  '617-956-6905',
#  'explanation',
#  "'pretending'",
#  '(tod',
#  'ninjaite',
#  'donuts',
#  'lyndon',
#  'mir.',
#  'inventoried).',
#  'recognise',
#  '158-176).',
#  'planetarium',
#  '99.6)',
#  'swerve?',
#  "jafoust@cco.caltech.edu's",
#  'jmarttila@abo.fi',
#  '>word,',
#  '|>index',
#  'm9v=gq<4tbxom4["p&7%qtm+2tct]f9d#7kn[*gk?wt=\'i:4+9f;$q,0q,8>\'',
#  'kucera',
#  'm)s0t)s0g-(6%-(6%\\(7p-/#p\\#3p-"<g-#0te30t)s3@-#0g-#0t)s0g"0d)',
#  'kssingvo@immd4.informatik.uni-erlangen.de',
#  '(tom)',
#  'dlgqwk',
#  '"troops',
#  '1.1b,',
#  't8w:s\\:<sil',
#  'colorado:',
#  'seige,',
#  'feed-through).',
#  'seals',
#  '(paolo',
#  '"assault"',
#  'mdi*2di*2di*2di*2di*2de14di*2de145%145%145%145%145%145%14%a86',
#  'overbloom',
#  'ad.,',
#  'speedo',
#  'consent.',
#  '"criminal"',
#  'mw\\v9tf17_f]$#ukht[!;',
#  '9785',
#  'reader/mailer',
#  'cards"',
#  'familiar?',
#  'edt',
#  '<4.8>',
#  'hs40',
#  'kovalev.',
#  '>birthday',
#  "isn't.",
#  "m]#c's6kg-nq7;m5>]4bo:l>vj6yev*^ljiujov2crh[m4]fq72hqj=2yy[w_",
#  'mac18@po.cwru.edu|',
#  'religion",',
#  'dl,ah',
#  'm6/-86(^/cx^/cucgc_./\\x_syx_s6.?s\\_./c^?scx^/cx_sc_/gcty8\\x_s',
#  '>>close',
#  '29*,',
#  'avahi.inria.fr',
#  ':right...some',
#  'ermianlary."',
#  'gifford@oasys.dt.navy.mil',
#  'r3000.',
#  '5.1.',
#  '>me',
#  's-104',
#  'm+kr\'w"23=kx&<9&^#[s#2"%xg.$\\*7"e/:+gnv!?',
#  '(eof_ok',
#  '>revelation',
#  '>perfect<',
#  'war...',
#  'innocents,',
#  'road.',
#  '"grace".',
#  '<1993apr16.171347.784@news.columbia.edu>',
#  'high-powered',
#  'passsage?',
#  'tt!]#6g<g(4mea4f]pc',
#  'concealed-',
#  'chop,',
#  'ambush',
#  'geomview):',
#  'departed)',
#  'rend386@sunee.waterloo.edu',
#  'wals',
#  'judah...',
#  'rec-autos/part1',
#  '`iain`',
#  '659',
#  'readily-available,',
#  'shin',
#  'mppmw%y',
#  '*everyone*',
#  '>scoring',
#  'veto-proof',
#  'ap-74;',
#  'social,',
#  '<c5t76d.2x6@news.cso.uiuc.edu>',
#  'inventors',
#  'browser,',
#  'large',
#  "m\\(=%hv5qz3j#'w?*]t!^",
#  'tattam)',
#  'changes!!!!',
#  '72227.1375@compuserve.com',
#  "m4<r4c/3:+8>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'",
#  'oyster,',
#  'confess,',
#  '"apagchw"(ie:',
#  '424-6332',
#  '>gt',
#  ':55;',
#  '(p225/70x15)',
#  'dawns',
#  'adapter)',
#  'lyall',
#  '44k.',
#  'crowell)',
#  "'commune",
#  'med-ed/msdos/incoming',
#  'not..!).',
#  'grow,"',
#  '0,-1,',
#  'wilpon',
#  'm\\ua83o-.cx^/\\_./6%cscx_sy_-.cx^/\\^?sy^>/\\x_s6%csy_/gcx_gc_/g',
#  'back-stabbing,',
#  'mtv,qrt,dbw',
#  'endometriosis.',
#  '$80)',
#  'notice,',
#  'jews...armenians',
#  '523',
#  'iocomm',
#  'certificates,',
#  'ks',
#  '"cracked"',
#  "`anarchy'",
#  'transposon',
#  'nyc-1',
#  'occurrence',
#  '<1993apr20.131800.16136@alw.nih.gov>',
#  'my_./yx_g\\x^/\\ucsy_./\\_/s\\^>/c_/scx_gc_./\\x]8c_./cua83eb/c^?g',
#  '+nyi+',
#  'jnf,',
#  'thai',
#  'barker@cs.pdx.edu',
#  '(rusty',
#  ';11000110',
#  'overheated,',
#  'kellner',
#  'blessing,',
#  'x>',
#  'w.va',
#  'chongo@toad.com.uucp',
#  'switch)',
#  'infant.',
#  'liberally.',
#  '$5000?',
#  'col,pitcher',
#  'stanly@grok11.columbiasc.ncr.com',
#  "o'neill's",
#  'macro-',
#  'blah"',
#  'bakker',
#  'image-',
#  '>specified',
#  'crankcase',
#  'graeme>',
#  'denmark.',
#  'mgg4xp!175u<46\\#`.\'5uj:eu=3c`6um;6s:jjji&)=dp,"dic(r,5i0&!@:4',
#  'understanding',
#  'lombardi,',
#  'conditioni',
#  'boobtists,',
#  'six!',
#  '(1b)',
#  'warping',
#  'optonica',
#  'floppy!',
#  '548-4800',
#  'reacting?',
#  '!h2;$$vucv?2.jr5',
#  '>>>yes,',
#  'm=z(\'.&";s]@6%,:>w(&su_.t9&i90<@[p',
#  '85',
#  'nmcglynn@axion.bt.co.uk',
#  "'lo",
#  'domingo.',
#  'hide',
#  'lineup.',
#  'quantization',
#  "'dissidents.'",
#  '-yogi',
#  'kits.',
#  'banking',
#  'fans(and',
#  'lousanne"',
#  '"waste"',
#  'colorview',
#  'syndrome"',
#  'isophotes.',
#  'contact)',
#  'reasonably.',
#  'anti-semite,"',
#  'glossies',
#  'purification',
#  '113.4',
#  'delt_xloc,',
#  '<c5hxlk.fix@andy.bgsu.edu>',
#  'perverts',
#  'newbie.',
#  'twice?',
#  '(wes',
#  'z-300',
#  '>ovation',
#  'chargeing',
#  'sublime',
#  '+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++',
#  'proven?',
#  'promise.)',
#  'p31-44.',
#  'rainier.ho.att.com',
#  'accused',
#  'great!),',
#  'village.',
#  'fathered',
#  "mu&s6n/@$'(6",
#  'lojack',
#  '<bissda.4.734849678@saturn.wwc.edu>,',
#  'kovalenko',
#  'swaim',
#  "'92.",
#  '12-4',
#  'coach):',
#  'vhs"',
#  'exclusivity',
#  'scanner),',
#  '49ers',
#  'mizzou1.missouri.edu',
#  'crashed,',
#  'hellbound.',
#  'essensa',
#  'non-passenger',
#  'kortelainen',
#  'erotica?',
#  '-chris',
#  'kfl@access.digex.com',
#  '<1993apr2.171819.1@ulkyvx.louisville.edu>',
#  'm$4',
#  'accrodingly.',
#  'whoah!!!',
#  "misfortune'",
#  'schimmrich)',
#  'c.g.',
#  'his/her/undefined',
#  'numbers)',
#  'man-oh-man',
#  'machines}.',
#  'escalation',
#  '(nill',
#  'xxxxdraft',
#  'circassians,',
#  'toelle@evansville.edu',
#  'internal-',
#  'clamshell',
#  'better?)',
#  '(notably:',
#  '+-----------------------------------------------+',
#  'q?',
#  'impelling',
#  '/usr/local/lib/organization',
#  'how!',
#  'extinguisher"',
#  '/pub/ghostview-1.4.1.tar.z',
#  'zone',
#  '~5',
#  'estsc',
#  'subjective.',
#  '258',
#  '*prove',
#  'propulsion',
#  'calories).',
#  'nuisance',
#  'bytes;',
#  '$19.00',
#  'enabling',
#  '>617/',
#  'chiu)',
#  'useless?',
#  'god!!!!',
#  '<1993apr15.192231.27574@abo.fi>,',
#  '"since',
#  "i'll",
#  'mhz)',
#  'drag).',
#  '(410)-272-6763',
#  'neilsen',
#  'reign',
#  'shredder@telerama.pgh.pa.us',
#  'irrigation',
#  '#muscle',
#  'called.',
#  '135-141',
#  'myname@mysite"',
#  're-boost.',
#  'solun.',
#  'sergei_bautin',
#  'proceed,',
#  'msdos,',
#  'lunch;',
#  'kenney',
#  '>ira-500ii.',
#  'supported',
#  'scupper',
#  'rumor',
#  'suggestion...go',
#  'extralibraries',
#  'kurland',
#  '<8813@blue.cis.pitt.edu>',
#  'slow.)',
#  'ud156844@ndsuvm1.bitnet',
#  "mv,k8rlk*ri$zd3k8rb_*.lhzd6doah:1d9$z:2^1d<?'.cho.h:1:6dzd2_'",
#  'm=w?=a86%=w>%a7>%=te)a4!`0..%a4e)0.-)27>%2>/cxt#cxte`x^-)24gc',
#  '>>drastically',
#  'incrimidate',
#  '(rcfec@westminster.ac.uk)',
#  '14:55:00',
#  'phone:(089)636-41449',
#  '1942,',
#  'guns,")',
#  '86.5',
#  'pointer,',
#  'classify',
#  'put}',
#  'nostalgia',
#  '(yik',
#  '(smaller)',
#  'coupe,',
#  'tektronics',
#  'christopher.s.weinberger@williams.edu',
#  'ms-dos?',
#  'xtcreatewidget("form_view",viewportwidgetclass,',
#  'registrar.',
#  'flock.',
#  'side.',
#  'blurb!"',
#  '>>ruled',
#  'courtyard,',
#  'indriect',
#  'lowell.',
#  '2400b',
#  'quislings',
#  'netters',
#  '<93083.215554mal112@psuvm.psu.edu>',
#  'abridgements',
#  'logitech,',
#  'peasants',
#  'lord?"',
#  '"taps"',
#  '>>health',
#  "(=.,5#lrglk3$o3gi*>l6'0_h<.p=c$m6!00f",
#  'rrrrrrr!',
#  'w/2m',
#  '4:09.',
#  'fri-noon',
#  'aids,',
#  'v4.21',
#  'xtmanage-',
#  'clearly?',
#  'sieferme@stein.u.washington.edu',
#  'voltages',
#  'mechanism?',
#  'communications....',
#  'nice',
#  'slow....',
#  'entered',
#  'bi-communal',
#  'xmnrightattachment,',
#  'asa',
#  'r-mail:',
#  '>this:',
#  'public-interest',
#  '(68)',
#  'deskjets).',
#  'omv',
#  '>(digital',
#  'm=t!w=x4c24e)a4#c=w>%=w?c24e)27=)a4gc24"%24gca4f%287c(te`24f%',
#  'britamrica',
#  'jyri',
#  'm0d&%a86.cb(bq.m;6r)6cb(bq.ok6um;6r',
#  'am229@cleveland.freenet.edu',
#  'installed)',
#  '_mechanisms_.',
#  'cwcolormap,',
#  'mon,vanderwal',
#  '(8^)-',
#  'bumf**k',
#  'mercilessly',
#  'bulging',
#  '7-1',
#  'allowed)',
#  'generation"',
#  'nixon/sanders.',
#  '<data_730956427@cs.unc.edu>',
#  'salvaging',
#  '(1m)',
#  'm"`@("`@("`@("`ao;q5o;v^h;v\\5%145;v]o;zt5%1^m%;<5m[<53zt?mzur',
#  'nonexistent.',
#  '377',
#  'it..any',
#  'united',
#  'stroboscope.',
#  '>ibm,',
#  '2-3-',
#  'heterosexuality',
#  'psalmist',
#  'deltas',
#  '>>>israel',
#  'ymodem,',
#  '14623',
#  'blitz,',
#  'this).',
#  ';01011010',
#  'get-',
#  'ptr_ident',
#  '(deliberately?)',
#  '(202)',
#  'blasted',
#  '#188',
#  'cquel@byu.edu',
#  'investigate',
#  '144-5)}.',
#  '$650.00',
#  'wrong/how',
#  '---------------------------------------',
#  '1.2,',
#  'blanks,',
#  'ethertalk',
#  '>christians"',
#  'counteract',
#  'marisa@cpa.tn.cornell.edu',
#  'xtnallowshellresize',
#  'husband',
#  '6.0.4',
#  'physiology/iu',
#  '<x11/xutil.h>',
#  'irving@happy-man.com',
#  'cobb)',
#  '_congressional',
#  "max>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax=45%145)*2di*2de14di*2",
#  'headline',
#  'yozzo',
#  'emu:',
#  'supporting.',
#  'statesmen,',
#  "mouse--it's",
#  'profession',
#  '387??-25mhz',
#  'pathnames):',
#  'pith.1qk7nu$ra8',
#  'myx].6//gcx_sy_-.\\^?s6(_s6/-8yx]8\\x_g6(_s6.>/\\^>/c^>/c^>/6%cg',
#  'identically.',
#  'cs.dal.ca',
#  'witness.',
#  'suffers',
#  '(602)-554-2685',
#  'h%te@v;([:oqv;hs9l',
#  'x-literate',
#  'serenade',
#  'happening',
#  'lighting,',
#  'prosyletizing.',
#  'nakata,',
#  'pex',
#  '(canada),',
#  "'newer'.",
#  'pgdn;',
#  'subroutines)',
#  'synthesis,',
#  'divides',
#  "max>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'azg6t+zs,'`m+8.sk*3qqcyd",
#  '(10-20)',
#  'delivering',
#  '>trigger',
#  'interview.',
#  'nooooo!',
#  'sen-sens,',
#  '.o',
#  '>applies',
#  "kubey@sgi.com's",
#  'good-natured',
#  'heinrich',
#  '>dmeier@casbah.acns.nwu.edu',
#  'exempted',
#  'pronograffitti',
#  'useful!!',
#  '40-640hz;',
#  '144.54.64.38',
#  '<c52oys.2clj@austin.ibm.com>',
#  'bacharach,',
#  'me1.k#?51s!skwf!@8#fk#?51%pt78&#>s)]r&g)r&b9r<ajw&ah@2v[dceps',
#  'radia-tion',
#  "mv,i!rck8.lhz0=amrcis;7/8.cisv'-m<]amv#k*rfw8v'-meg,\\<\\imv&us",
#  'mw7=wt45w1=w==w?=0\'?==w?1w7=w=x7=0$#=0$f%w4#=a4"%=w=wa85w0$f%',
#  '><requires',
#  'm9if/@56",c6/;%@p78c56;@jp#5.+rs\'4!:s-0i6*4h%tm/2):%41--"j<!c',
#  'vkuznetsov@mci.com',
#  'eternity,',
#  'lockheed,',
#  '"psychological',
#  'endeavoring,',
#  'aspartame-sweetened',
#  '104.',
#  '"interesting',
#  'snf,clark',
#  'light,',
#  'mutlu/argic',
#  'pepsi.eng.umd.edu',
#  'follower',
#  'palyer,',
#  'sunlight',
#  'andre_beck@irs.inf.tu-dresden.de',
#  'automaton',
#  ...]

# %%
data_category = []
for i in range(len(train.data)):
    GT_category = train.target_names[train.target[i]]
    for s in categories:  # Added a colon here
        if GT_category == s:
            print(i, train.target_names[train.target[i]])
            data_category.append([train.data[i]])
            # categories.append(train.data[i])
# Out:
# 0 rec.autos
# 1 comp.sys.mac.hardware
# 2 comp.sys.mac.hardware
# 3 comp.graphics
# 4 sci.space
# 5 talk.politics.guns
# 6 sci.med
# 7 comp.sys.ibm.pc.hardware
# 8 comp.os.ms-windows.misc
# 9 comp.sys.mac.hardware
# 10 rec.motorcycles
# 11 talk.religion.misc
# 12 comp.sys.mac.hardware
# 13 sci.space
# 14 misc.forsale
# 15 alt.atheism
# 16 comp.graphics
# 17 rec.autos
# 18 sci.electronics
# 19 comp.windows.x
# 20 alt.atheism
# 21 rec.sport.hockey
# 22 misc.forsale
# 23 comp.os.ms-windows.misc
# 24 comp.sys.mac.hardware
# 25 comp.graphics
# 26 sci.electronics
# 27 rec.sport.baseball
# 28 soc.religion.christian
# 29 rec.autos
# 30 misc.forsale
# 31 sci.med
# 32 sci.electronics
# 33 talk.politics.mideast
# 34 talk.politics.misc
# 35 rec.sport.hockey
# 36 rec.motorcycles
# 37 sci.crypt
# 38 rec.motorcycles
# 39 talk.politics.guns
# 40 rec.sport.baseball
# 41 comp.sys.mac.hardware
# 42 comp.sys.ibm.pc.hardware
# 43 rec.sport.baseball
# 44 rec.sport.baseball
# 45 comp.sys.mac.hardware
# 46 comp.sys.mac.hardware
# 47 rec.motorcycles
# 48 sci.electronics
# 49 sci.space
# 50 comp.windows.x
# 51 soc.religion.christian
# 52 comp.os.ms-windows.misc
# 53 sci.med
# 54 talk.politics.mideast
# 55 sci.crypt
# 56 rec.autos
# 57 rec.sport.hockey
# 58 comp.os.ms-windows.misc
# 59 sci.space
# 60 sci.electronics
# 61 comp.windows.x
# 62 comp.sys.mac.hardware
# 63 misc.forsale
# 64 rec.autos
# 65 alt.atheism
# 66 sci.crypt
# 67 talk.politics.guns
# 68 alt.atheism
# 69 misc.forsale
# 70 talk.politics.mideast
# 71 rec.autos
# 72 sci.electronics
# 73 rec.autos
# 74 comp.sys.ibm.pc.hardware
# 75 sci.electronics
# 76 sci.crypt
# 77 rec.autos
# 78 comp.os.ms-windows.misc
# 79 comp.os.ms-windows.misc
# 80 alt.atheism
# 81 talk.politics.guns
# 82 comp.graphics
# 83 comp.os.ms-windows.misc
# 84 rec.autos
# 85 comp.sys.ibm.pc.hardware
# 86 comp.os.ms-windows.misc
# 87 comp.graphics
# 88 rec.sport.hockey
# 89 sci.electronics
# 90 sci.electronics
# 91 talk.politics.mideast
# 92 sci.electronics
# 93 comp.os.ms-windows.misc
# 94 rec.motorcycles
# 95 rec.motorcycles
# 96 talk.politics.misc
# 97 comp.windows.x
# 98 alt.atheism
# 99 comp.graphics
# 100 misc.forsale
# 101 sci.electronics
# 102 rec.motorcycles
# 103 comp.sys.mac.hardware
# 104 talk.politics.mideast
# 105 sci.electronics
# 106 sci.electronics
# 107 sci.electronics
# 108 comp.graphics
# 109 misc.forsale
# 110 talk.politics.misc
# 111 comp.sys.mac.hardware
# 112 comp.sys.ibm.pc.hardware
# 113 rec.sport.hockey
# 114 rec.sport.baseball
# 115 alt.atheism
# 116 sci.med
# 117 sci.crypt
# 118 comp.windows.x
# 119 sci.space
# 120 soc.religion.christian
# 121 rec.motorcycles
# 122 comp.sys.mac.hardware
# 123 soc.religion.christian
# 124 soc.religion.christian
# 125 comp.graphics
# 126 alt.atheism
# 127 talk.politics.guns
# 128 rec.sport.baseball
# 129 rec.motorcycles
# 130 misc.forsale
# 131 sci.med
# 132 misc.forsale
# 133 talk.politics.mideast
# 134 sci.space
# 135 alt.atheism
# 136 rec.sport.baseball
# 137 comp.graphics
# 138 comp.os.ms-windows.misc
# 139 soc.religion.christian
# 140 sci.med
# 141 rec.sport.baseball
# 142 comp.os.ms-windows.misc
# 143 rec.motorcycles
# 144 comp.os.ms-windows.misc
# 145 sci.med
# 146 comp.os.ms-windows.misc
# 147 alt.atheism
# 148 soc.religion.christian
# 149 sci.space
# 150 comp.graphics
# 151 sci.space
# 152 talk.politics.mideast
# 153 sci.space
# 154 comp.sys.mac.hardware
# 155 comp.sys.mac.hardware
# 156 rec.autos
# 157 talk.religion.misc
# 158 comp.graphics
# 159 soc.religion.christian
# 160 talk.politics.mideast
# 161 talk.politics.guns
# 162 comp.os.ms-windows.misc
# 163 soc.religion.christian
# 164 rec.sport.baseball
# 165 sci.electronics
# 166 misc.forsale
# 167 rec.sport.baseball
# 168 misc.forsale
# 169 misc.forsale
# 170 talk.politics.misc
# 171 comp.graphics
# 172 rec.sport.hockey
# 173 misc.forsale
# 174 rec.sport.hockey
# 175 comp.windows.x
# 176 comp.os.ms-windows.misc
# 177 sci.med
# 178 comp.sys.ibm.pc.hardware
# 179 rec.sport.baseball
# 180 sci.med
# 181 sci.electronics
# 182 sci.med
# 183 rec.motorcycles
# 184 comp.sys.mac.hardware
# 185 comp.sys.ibm.pc.hardware
# 186 rec.sport.baseball
# 187 comp.graphics
# 188 sci.electronics
# 189 comp.sys.mac.hardware
# 190 comp.os.ms-windows.misc
# 191 comp.os.ms-windows.misc
# 192 sci.crypt
# 193 sci.med
# 194 comp.sys.mac.hardware
# 195 comp.graphics
# 196 sci.electronics
# 197 alt.atheism
# 198 talk.politics.guns
# 199 sci.electronics
# 200 talk.politics.guns
# 201 rec.autos
# 202 talk.politics.mideast
# 203 soc.religion.christian
# 204 sci.crypt
# 205 sci.space
# 206 comp.os.ms-windows.misc
# 207 rec.autos
# 208 rec.sport.hockey
# 209 sci.space
# 210 soc.religion.christian
# 211 comp.windows.x
# 212 talk.politics.guns
# 213 sci.crypt
# 214 comp.sys.mac.hardware
# 215 sci.med
# 216 rec.autos
# 217 comp.sys.mac.hardware
# 218 sci.med
# 219 talk.politics.mideast
# 220 comp.graphics
# 221 soc.religion.christian
# 222 talk.politics.mideast
# 223 talk.politics.mideast
# 224 rec.sport.baseball
# 225 talk.politics.guns
# 226 talk.politics.mideast
# 227 alt.atheism
# 228 talk.politics.guns
# 229 rec.motorcycles
# 230 sci.med
# 231 comp.os.ms-windows.misc
# 232 sci.space
# 233 rec.sport.hockey
# 234 comp.os.ms-windows.misc
# 235 comp.os.ms-windows.misc
# 236 rec.sport.baseball
# 237 sci.space
# 238 rec.sport.baseball
# 239 comp.os.ms-windows.misc
# 240 soc.religion.christian
# 241 soc.religion.christian
# 242 comp.sys.mac.hardware
# 243 comp.sys.mac.hardware
# 244 sci.crypt
# 245 sci.crypt
# 246 sci.crypt
# 247 sci.med
# 248 alt.atheism
# 249 misc.forsale
# 250 talk.politics.misc
# 251 sci.med
# 252 alt.atheism
# 253 talk.politics.misc
# 254 talk.politics.guns
# 255 comp.os.ms-windows.misc
# 256 rec.sport.baseball
# 257 sci.crypt
# 258 rec.sport.baseball
# 259 comp.sys.ibm.pc.hardware
# 260 alt.atheism
# 261 talk.politics.misc
# 262 rec.autos
# 263 rec.sport.baseball
# 264 sci.space
# 265 rec.sport.baseball
# 266 rec.sport.hockey
# 267 talk.politics.mideast
# 268 rec.motorcycles
# 269 comp.windows.x
# 270 comp.sys.ibm.pc.hardware
# 271 comp.os.ms-windows.misc
# 272 sci.med
# 273 misc.forsale
# 274 rec.autos
# 275 comp.graphics
# 276 sci.crypt
# 277 comp.sys.mac.hardware
# 278 sci.electronics
# 279 sci.crypt
# 280 misc.forsale
# 281 comp.os.ms-windows.misc
# 282 sci.space
# 283 rec.sport.baseball
# 284 comp.graphics
# 285 comp.sys.mac.hardware
# 286 sci.crypt
# 287 soc.religion.christian
# 288 soc.religion.christian
# 289 misc.forsale
# 290 comp.windows.x
# 291 rec.sport.hockey
# 292 rec.motorcycles
# 293 comp.sys.mac.hardware
# 294 talk.politics.guns
# 295 talk.politics.mideast
# 296 rec.sport.baseball
# 297 rec.motorcycles
# 298 rec.sport.hockey
# 299 talk.politics.mideast
# 300 rec.sport.hockey
# 301 sci.crypt
# 302 rec.motorcycles
# 303 soc.religion.christian
# 304 rec.sport.hockey
# 305 comp.sys.mac.hardware
# 306 sci.electronics
# 307 alt.atheism
# 308 comp.windows.x
# 309 comp.sys.mac.hardware
# 310 alt.atheism
# 311 talk.politics.misc
# 312 talk.politics.mideast
# 313 comp.os.ms-windows.misc
# 314 comp.sys.ibm.pc.hardware
# 315 alt.atheism
# 316 talk.religion.misc
# 317 talk.religion.misc
# 318 rec.sport.baseball
# 319 talk.religion.misc
# 320 comp.windows.x
# 321 sci.med
# 322 sci.space
# 323 rec.sport.hockey
# 324 comp.windows.x
# 325 sci.crypt
# 326 misc.forsale
# 327 misc.forsale
# 328 comp.graphics
# 329 sci.med
# 330 sci.med
# 331 talk.politics.misc
# 332 talk.politics.mideast
# 333 comp.os.ms-windows.misc
# 334 rec.sport.baseball
# 335 soc.religion.christian
# 336 comp.os.ms-windows.misc
# 337 rec.motorcycles
# 338 rec.sport.baseball
# 339 comp.os.ms-windows.misc
# 340 talk.religion.misc
# 341 sci.space
# 342 comp.windows.x
# 343 sci.space
# 344 soc.religion.christian
# 345 rec.sport.baseball
# 346 comp.sys.ibm.pc.hardware
# 347 talk.politics.misc
# 348 comp.graphics
# 349 talk.politics.misc
# 350 rec.sport.hockey
# 351 sci.med
# 352 talk.religion.misc
# 353 talk.politics.misc
# 354 soc.religion.christian
# 355 rec.sport.baseball
# 356 sci.space
# 357 comp.sys.mac.hardware
# 358 comp.sys.mac.hardware
# 359 alt.atheism
# 360 sci.electronics
# 361 talk.politics.misc
# 362 sci.space
# 363 sci.space
# 364 talk.politics.mideast
# 365 sci.med
# 366 soc.religion.christian
# 367 comp.windows.x
# 368 comp.sys.mac.hardware
# 369 talk.politics.misc
# 370 sci.electronics
# 371 rec.sport.baseball
# 372 misc.forsale
# 373 comp.graphics
# 374 comp.sys.mac.hardware
# 375 misc.forsale
# 376 rec.motorcycles
# 377 alt.atheism
# 378 talk.politics.mideast
# 379 comp.sys.ibm.pc.hardware
# 380 comp.graphics
# 381 talk.politics.misc
# 382 talk.politics.guns
# 383 talk.politics.misc
# 384 rec.motorcycles
# 385 sci.med
# 386 sci.electronics
# 387 soc.religion.christian
# 388 rec.motorcycles
# 389 misc.forsale
# 390 talk.religion.misc
# 391 sci.space
# 392 comp.sys.mac.hardware
# 393 comp.sys.mac.hardware
# 394 talk.politics.mideast
# 395 comp.windows.x
# 396 misc.forsale
# 397 comp.windows.x
# 398 sci.med
# 399 comp.sys.mac.hardware
# 400 sci.crypt
# 401 rec.sport.hockey
# 402 sci.electronics
# 403 comp.sys.ibm.pc.hardware
# 404 sci.electronics
# 405 rec.autos
# 406 rec.sport.hockey
# 407 comp.windows.x
# 408 talk.religion.misc
# 409 comp.graphics
# 410 talk.politics.guns
# 411 comp.os.ms-windows.misc
# 412 sci.crypt
# 413 sci.electronics
# 414 comp.os.ms-windows.misc
# 415 rec.autos
# 416 comp.windows.x
# 417 comp.windows.x
# 418 rec.motorcycles
# 419 comp.windows.x
# 420 sci.med
# 421 soc.religion.christian
# 422 soc.religion.christian
# 423 talk.politics.misc
# 424 alt.atheism
# 425 sci.electronics
# 426 misc.forsale
# 427 sci.electronics
# 428 comp.sys.mac.hardware
# 429 comp.sys.ibm.pc.hardware
# 430 comp.sys.ibm.pc.hardware
# 431 rec.motorcycles
# 432 sci.space
# 433 sci.crypt
# 434 talk.politics.guns
# 435 sci.med
# 436 alt.atheism
# 437 rec.sport.hockey
# 438 comp.os.ms-windows.misc
# 439 comp.windows.x
# 440 soc.religion.christian
# 441 rec.sport.hockey
# 442 soc.religion.christian
# 443 sci.space
# 444 soc.religion.christian
# 445 rec.autos
# 446 rec.motorcycles
# 447 sci.crypt
# 448 soc.religion.christian
# 449 rec.sport.baseball
# 450 comp.sys.ibm.pc.hardware
# 451 rec.motorcycles
# 452 sci.space
# 453 talk.politics.mideast
# 454 sci.crypt
# 455 sci.med
# 456 talk.politics.guns
# 457 sci.crypt
# 458 soc.religion.christian
# 459 rec.motorcycles
# 460 soc.religion.christian
# 461 rec.motorcycles
# 462 rec.autos
# 463 rec.autos
# 464 misc.forsale
# 465 comp.graphics
# 466 rec.motorcycles
# 467 sci.space
# 468 soc.religion.christian
# 469 talk.politics.mideast
# 470 misc.forsale
# 471 rec.sport.hockey
# 472 rec.sport.hockey
# 473 rec.sport.hockey
# 474 sci.space
# 475 talk.politics.mideast
# 476 soc.religion.christian
# 477 soc.religion.christian
# 478 rec.motorcycles
# 479 rec.sport.baseball
# 480 alt.atheism
# 481 sci.med
# 482 rec.sport.hockey
# 483 sci.electronics
# 484 talk.politics.misc
# 485 comp.os.ms-windows.misc
# 486 rec.motorcycles
# 487 talk.religion.misc
# 488 rec.sport.baseball
# 489 comp.sys.mac.hardware
# 490 talk.politics.guns
# 491 alt.atheism
# 492 rec.autos
# 493 comp.windows.x
# 494 rec.sport.hockey
# 495 alt.atheism
# 496 alt.atheism
# 497 sci.med
# 498 comp.os.ms-windows.misc
# 499 misc.forsale
# 500 comp.os.ms-windows.misc
# 501 comp.sys.ibm.pc.hardware
# 502 rec.sport.hockey
# 503 talk.politics.mideast
# 504 sci.med
# 505 talk.politics.guns
# 506 comp.graphics
# 507 talk.politics.mideast
# 508 alt.atheism
# 509 talk.politics.mideast
# 510 sci.space
# 511 comp.sys.ibm.pc.hardware
# 512 comp.sys.mac.hardware
# 513 comp.os.ms-windows.misc
# 514 talk.politics.guns
# 515 comp.os.ms-windows.misc
# 516 rec.sport.baseball
# 517 comp.graphics
# 518 comp.sys.mac.hardware
# 519 sci.med
# 520 sci.electronics
# 521 comp.sys.ibm.pc.hardware
# 522 sci.electronics
# 523 soc.religion.christian
# 524 soc.religion.christian
# 525 misc.forsale
# 526 rec.autos
# 527 comp.sys.ibm.pc.hardware
# 528 rec.motorcycles
# 529 talk.religion.misc
# 530 comp.graphics
# 531 comp.sys.ibm.pc.hardware
# 532 talk.politics.guns
# 533 sci.space
# 534 rec.autos
# 535 sci.electronics
# 536 talk.politics.mideast
# 537 sci.electronics
# 538 sci.crypt
# 539 comp.windows.x
# 540 rec.sport.baseball
# 541 rec.sport.baseball
# 542 soc.religion.christian
# 543 rec.sport.hockey
# 544 sci.electronics
# 545 sci.space
# 546 rec.sport.baseball
# 547 rec.autos
# 548 misc.forsale
# 549 rec.sport.hockey
# 550 comp.sys.mac.hardware
# 551 soc.religion.christian
# 552 comp.graphics
# 553 comp.sys.ibm.pc.hardware
# 554 talk.politics.misc
# 555 comp.windows.x
# 556 talk.politics.mideast
# 557 talk.politics.misc
# 558 sci.space
# 559 talk.politics.guns
# 560 sci.crypt
# 561 comp.windows.x
# 562 comp.sys.ibm.pc.hardware
# 563 talk.politics.mideast
# 564 rec.autos
# 565 comp.graphics
# 566 soc.religion.christian
# 567 misc.forsale
# 568 comp.sys.mac.hardware
# 569 comp.graphics
# 570 comp.sys.ibm.pc.hardware
# 571 talk.politics.mideast
# 572 soc.religion.christian
# 573 rec.motorcycles
# 574 talk.politics.misc
# 575 alt.atheism
# 576 comp.sys.mac.hardware
# 577 talk.religion.misc
# 578 misc.forsale
# 579 sci.space
# 580 alt.atheism
# 581 rec.motorcycles
# 582 sci.crypt
# 583 rec.sport.hockey
# 584 comp.graphics
# 585 comp.windows.x
# 586 rec.sport.baseball
# 587 talk.politics.misc
# 588 comp.sys.mac.hardware
# 589 comp.os.ms-windows.misc
# 590 talk.religion.misc
# 591 talk.politics.guns
# 592 rec.autos
# 593 sci.crypt
# 594 comp.os.ms-windows.misc
# 595 alt.atheism
# 596 rec.autos
# 597 sci.crypt
# 598 rec.autos
# 599 comp.os.ms-windows.misc
# 600 soc.religion.christian
# 601 sci.electronics
# 602 misc.forsale
# 603 rec.autos
# 604 sci.electronics
# 605 comp.sys.ibm.pc.hardware
# 606 comp.os.ms-windows.misc
# 607 sci.crypt
# 608 sci.electronics
# 609 sci.space
# 610 comp.windows.x
# 611 talk.religion.misc
# 612 sci.med
# 613 soc.religion.christian
# 614 soc.religion.christian
# 615 talk.religion.misc
# 616 misc.forsale
# 617 rec.motorcycles
# 618 rec.motorcycles
# 619 comp.windows.x
# 620 misc.forsale
# 621 rec.autos
# 622 rec.sport.hockey
# 623 comp.windows.x
# 624 comp.sys.ibm.pc.hardware
# 625 talk.politics.guns
# 626 sci.med
# 627 comp.windows.x
# 628 misc.forsale
# 629 talk.religion.misc
# 630 comp.sys.mac.hardware
# 631 rec.autos
# 632 comp.os.ms-windows.misc
# 633 rec.sport.baseball
# 634 soc.religion.christian
# 635 sci.med
# 636 rec.autos
# 637 soc.religion.christian
# 638 sci.med
# 639 comp.graphics
# 640 comp.graphics
# 641 talk.politics.misc
# 642 talk.politics.misc
# 643 talk.religion.misc
# 644 talk.politics.mideast
# 645 comp.sys.mac.hardware
# 646 sci.med
# 647 alt.atheism
# 648 alt.atheism
# 649 talk.religion.misc
# 650 soc.religion.christian
# 651 comp.os.ms-windows.misc
# 652 sci.electronics
# 653 rec.sport.baseball
# 654 comp.graphics
# 655 misc.forsale
# 656 alt.atheism
# 657 sci.crypt
# 658 talk.politics.mideast
# 659 rec.autos
# 660 comp.graphics
# 661 comp.graphics
# 662 comp.sys.ibm.pc.hardware
# 663 sci.med
# 664 rec.sport.baseball
# 665 rec.sport.baseball
# 666 rec.sport.baseball
# 667 comp.windows.x
# 668 talk.politics.misc
# 669 rec.sport.baseball
# 670 talk.politics.misc
# 671 rec.sport.baseball
# 672 misc.forsale
# 673 talk.politics.guns
# 674 talk.politics.mideast
# 675 comp.os.ms-windows.misc
# 676 rec.autos
# 677 comp.windows.x
# 678 comp.sys.ibm.pc.hardware
# 679 rec.sport.hockey
# 680 sci.electronics
# 681 soc.religion.christian
# 682 rec.autos
# 683 rec.sport.hockey
# 684 alt.atheism
# 685 comp.sys.ibm.pc.hardware
# 686 sci.electronics
# 687 talk.politics.mideast
# 688 talk.politics.misc
# 689 soc.religion.christian
# 690 alt.atheism
# 691 talk.politics.mideast
# 692 talk.religion.misc
# 693 comp.os.ms-windows.misc
# 694 sci.crypt
# 695 sci.electronics
# 696 talk.politics.misc
# 697 soc.religion.christian
# 698 comp.graphics
# 699 rec.autos
# 700 comp.graphics
# 701 rec.motorcycles
# 702 sci.crypt
# 703 sci.med
# 704 comp.sys.mac.hardware
# 705 talk.politics.misc
# 706 comp.windows.x
# 707 soc.religion.christian
# 708 comp.windows.x
# 709 comp.graphics
# 710 sci.electronics
# 711 comp.graphics
# 712 sci.crypt
# 713 comp.windows.x
# 714 rec.sport.hockey
# 715 soc.religion.christian
# 716 alt.atheism
# 717 sci.electronics
# 718 soc.religion.christian
# 719 soc.religion.christian
# 720 rec.sport.baseball
# 721 talk.religion.misc
# 722 rec.autos
# 723 comp.graphics
# 724 rec.sport.baseball
# 725 talk.politics.misc
# 726 comp.sys.mac.hardware
# 727 soc.religion.christian
# 728 talk.politics.misc
# 729 sci.med
# 730 rec.autos
# 731 talk.politics.guns
# 732 sci.crypt
# 733 rec.sport.baseball
# 734 alt.atheism
# 735 comp.windows.x
# 736 rec.sport.hockey
# 737 misc.forsale
# 738 comp.sys.mac.hardware
# 739 soc.religion.christian
# 740 sci.crypt
# 741 rec.motorcycles
# 742 talk.religion.misc
# 743 comp.windows.x
# 744 comp.graphics
# 745 comp.sys.ibm.pc.hardware
# 746 comp.os.ms-windows.misc
# 747 alt.atheism
# 748 soc.religion.christian
# 749 talk.politics.mideast
# 750 sci.med
# 751 talk.religion.misc
# 752 comp.sys.mac.hardware
# 753 rec.sport.baseball
# 754 rec.autos
# 755 rec.motorcycles
# 756 comp.sys.mac.hardware
# 757 rec.autos
# 758 sci.space
# 759 soc.religion.christian
# 760 talk.politics.misc
# 761 alt.atheism
# 762 sci.space
# 763 rec.autos
# 764 talk.politics.mideast
# 765 comp.sys.mac.hardware
# 766 rec.sport.baseball
# 767 sci.electronics
# 768 comp.windows.x
# 769 misc.forsale
# 770 talk.politics.guns
# 771 rec.autos
# 772 comp.os.ms-windows.misc
# 773 rec.motorcycles
# 774 sci.med
# 775 talk.religion.misc
# 776 comp.graphics
# 777 rec.sport.baseball
# 778 comp.graphics
# 779 comp.sys.ibm.pc.hardware
# 780 rec.sport.baseball
# 781 comp.windows.x
# 782 misc.forsale
# 783 soc.religion.christian
# 784 alt.atheism
# 785 comp.os.ms-windows.misc
# 786 talk.politics.mideast
# 787 talk.religion.misc
# 788 talk.politics.guns
# 789 sci.crypt
# 790 talk.politics.guns
# 791 alt.atheism
# 792 talk.politics.misc
# 793 sci.med
# 794 misc.forsale
# 795 rec.autos
# 796 comp.sys.mac.hardware
# 797 talk.politics.misc
# 798 alt.atheism
# 799 sci.space
# 800 rec.autos
# 801 soc.religion.christian
# 802 sci.crypt
# 803 comp.os.ms-windows.misc
# 804 comp.sys.ibm.pc.hardware
# 805 soc.religion.christian
# 806 sci.space
# 807 comp.sys.ibm.pc.hardware
# 808 misc.forsale
# 809 soc.religion.christian
# 810 rec.autos
# 811 talk.religion.misc
# 812 sci.space
# 813 comp.sys.mac.hardware
# 814 sci.med
# 815 rec.sport.hockey
# 816 comp.sys.mac.hardware
# 817 talk.politics.guns
# 818 sci.med
# 819 talk.politics.guns
# 820 comp.os.ms-windows.misc
# 821 rec.motorcycles
# 822 comp.os.ms-windows.misc
# 823 comp.sys.mac.hardware
# 824 comp.sys.ibm.pc.hardware
# 825 comp.sys.mac.hardware
# 826 rec.motorcycles
# 827 rec.autos
# 828 sci.crypt
# 829 talk.politics.mideast
# 830 misc.forsale
# 831 comp.sys.ibm.pc.hardware
# 832 talk.politics.mideast
# 833 alt.atheism
# 834 comp.windows.x
# 835 sci.electronics
# 836 sci.crypt
# 837 comp.graphics
# 838 misc.forsale
# 839 talk.politics.misc
# 840 misc.forsale
# 841 comp.sys.mac.hardware
# 842 comp.sys.ibm.pc.hardware
# 843 sci.electronics
# 844 sci.med
# 845 sci.space
# 846 misc.forsale
# 847 sci.space
# 848 alt.atheism
# 849 sci.med
# 850 rec.motorcycles
# 851 sci.space
# 852 alt.atheism
# 853 sci.crypt
# 854 rec.motorcycles
# 855 talk.politics.guns
# 856 rec.motorcycles
# 857 comp.sys.ibm.pc.hardware
# 858 talk.politics.mideast
# 859 misc.forsale
# 860 talk.politics.mideast
# 861 sci.space
# 862 misc.forsale
# 863 rec.sport.hockey
# 864 rec.sport.hockey
# 865 sci.med
# 866 sci.crypt
# 867 talk.politics.guns
# 868 comp.sys.ibm.pc.hardware
# 869 sci.med
# 870 rec.sport.hockey
# 871 comp.windows.x
# 872 alt.atheism
# 873 sci.space
# 874 misc.forsale
# 875 sci.space
# 876 rec.autos
# 877 rec.autos
# 878 talk.politics.mideast
# 879 comp.sys.ibm.pc.hardware
# 880 sci.electronics
# 881 comp.sys.mac.hardware
# 882 misc.forsale
# 883 alt.atheism
# 884 comp.graphics
# 885 sci.electronics
# 886 soc.religion.christian
# 887 comp.windows.x
# 888 sci.crypt
# 889 soc.religion.christian
# 890 comp.windows.x
# 891 soc.religion.christian
# 892 talk.politics.mideast
# 893 talk.politics.misc
# 894 talk.politics.mideast
# 895 rec.motorcycles
# 896 comp.windows.x
# 897 rec.motorcycles
# 898 talk.politics.mideast
# 899 talk.politics.mideast
# 900 alt.atheism
# 901 alt.atheism
# 902 misc.forsale
# 903 alt.atheism
# 904 rec.autos
# 905 soc.religion.christian
# 906 talk.politics.mideast
# 907 rec.sport.hockey
# 908 comp.sys.mac.hardware
# 909 sci.crypt
# 910 rec.autos
# 911 rec.sport.hockey
# 912 talk.politics.guns
# 913 alt.atheism
# 914 talk.politics.guns
# 915 sci.crypt
# 916 alt.atheism
# 917 comp.sys.ibm.pc.hardware
# 918 rec.sport.hockey
# 919 talk.politics.mideast
# 920 rec.sport.hockey
# 921 talk.politics.guns
# 922 rec.motorcycles
# 923 rec.sport.baseball
# 924 rec.autos
# 925 sci.electronics
# 926 talk.politics.guns
# 927 misc.forsale
# 928 talk.politics.mideast
# 929 comp.sys.ibm.pc.hardware
# 930 rec.sport.baseball
# 931 sci.crypt
# 932 talk.politics.mideast
# 933 misc.forsale
# 934 rec.sport.hockey
# 935 talk.religion.misc
# 936 talk.religion.misc
# 937 rec.motorcycles
# 938 talk.politics.mideast
# 939 sci.med
# 940 misc.forsale
# 941 talk.politics.misc
# 942 sci.crypt
# 943 comp.sys.ibm.pc.hardware
# 944 sci.electronics
# 945 sci.space
# 946 rec.sport.baseball
# 947 soc.religion.christian
# 948 sci.electronics
# 949 rec.sport.hockey
# 950 talk.politics.guns
# 951 rec.sport.baseball
# 952 comp.os.ms-windows.misc
# 953 sci.space
# 954 comp.os.ms-windows.misc
# 955 sci.crypt
# 956 sci.med
# 957 rec.sport.hockey
# 958 rec.autos
# 959 comp.windows.x
# 960 rec.autos
# 961 talk.religion.misc
# 962 comp.sys.ibm.pc.hardware
# 963 rec.sport.baseball
# 964 comp.windows.x
# 965 rec.sport.hockey
# 966 soc.religion.christian
# 967 talk.religion.misc
# 968 rec.sport.baseball
# 969 comp.sys.mac.hardware
# 970 sci.med
# 971 comp.os.ms-windows.misc
# 972 sci.crypt
# 973 sci.electronics
# 974 alt.atheism
# 975 comp.windows.x
# 976 talk.politics.guns
# 977 rec.motorcycles
# 978 comp.os.ms-windows.misc
# 979 rec.autos
# 980 sci.crypt
# 981 talk.politics.mideast
# 982 alt.atheism
# 983 talk.religion.misc
# 984 talk.religion.misc
# 985 comp.sys.ibm.pc.hardware
# 986 rec.sport.hockey
# 987 rec.sport.baseball
# 988 sci.space
# 989 rec.motorcycles
# 990 comp.sys.mac.hardware
# 991 rec.sport.hockey
# 992 sci.electronics
# 993 sci.space
# 994 rec.sport.hockey
# 995 misc.forsale
# 996 talk.politics.mideast
# 997 comp.sys.mac.hardware
# 998 sci.med
# 999 soc.religion.christian
# 1000 comp.os.ms-windows.misc
# 1001 rec.autos
# 1002 talk.politics.misc
# 1003 comp.graphics
# 1004 talk.politics.guns
# 1005 sci.space
# 1006 talk.religion.misc
# 1007 soc.religion.christian
# 1008 comp.sys.ibm.pc.hardware
# 1009 talk.politics.guns
# 1010 rec.autos
# 1011 sci.space
# 1012 comp.graphics
# 1013 rec.motorcycles
# 1014 talk.politics.misc
# 1015 soc.religion.christian
# 1016 talk.politics.misc
# 1017 rec.autos
# 1018 misc.forsale
# 1019 alt.atheism
# 1020 comp.sys.ibm.pc.hardware
# 1021 soc.religion.christian
# 1022 comp.os.ms-windows.misc
# 1023 sci.med
# 1024 sci.med
# 1025 rec.autos
# 1026 sci.electronics
# 1027 sci.space
# 1028 rec.sport.baseball
# 1029 sci.crypt
# 1030 comp.graphics
# 1031 soc.religion.christian
# 1032 misc.forsale
# 1033 misc.forsale
# 1034 rec.autos
# 1035 talk.politics.guns
# 1036 rec.sport.hockey
# 1037 talk.politics.mideast
# 1038 sci.electronics
# 1039 talk.politics.guns
# 1040 comp.os.ms-windows.misc
# 1041 comp.graphics
# 1042 comp.windows.x
# 1043 comp.sys.ibm.pc.hardware
# 1044 sci.electronics
# 1045 talk.religion.misc
# 1046 talk.politics.mideast
# 1047 rec.autos
# 1048 soc.religion.christian
# 1049 talk.politics.mideast
# 1050 soc.religion.christian
# 1051 comp.sys.ibm.pc.hardware
# 1052 rec.autos
# 1053 rec.motorcycles
# 1054 alt.atheism
# 1055 alt.atheism
# 1056 misc.forsale
# 1057 comp.os.ms-windows.misc
# 1058 comp.os.ms-windows.misc
# 1059 talk.politics.misc
# 1060 comp.sys.mac.hardware
# 1061 rec.autos
# 1062 comp.sys.ibm.pc.hardware
# 1063 comp.windows.x
# 1064 rec.sport.baseball
# 1065 comp.graphics
# 1066 rec.motorcycles
# 1067 talk.politics.mideast
# 1068 misc.forsale
# 1069 rec.sport.hockey
# 1070 talk.politics.guns
# 1071 sci.space
# 1072 sci.med
# 1073 sci.med
# 1074 talk.religion.misc
# 1075 sci.med
# 1076 talk.politics.guns
# 1077 misc.forsale
# 1078 comp.graphics
# 1079 rec.motorcycles
# 1080 comp.sys.mac.hardware
# 1081 comp.os.ms-windows.misc
# 1082 rec.autos
# 1083 comp.os.ms-windows.misc
# 1084 comp.windows.x
# 1085 sci.crypt
# 1086 rec.autos
# 1087 talk.politics.mideast
# 1088 rec.sport.hockey
# 1089 comp.sys.mac.hardware
# 1090 comp.graphics
# 1091 talk.politics.misc
# 1092 sci.electronics
# 1093 talk.politics.guns
# 1094 alt.atheism
# 1095 talk.politics.guns
# 1096 misc.forsale
# 1097 rec.sport.hockey
# 1098 talk.politics.misc
# 1099 rec.sport.baseball
# 1100 talk.politics.guns
# 1101 rec.motorcycles
# 1102 comp.windows.x
# 1103 rec.autos
# 1104 sci.med
# 1105 rec.sport.hockey
# 1106 talk.politics.guns
# 1107 rec.autos
# 1108 sci.electronics
# 1109 rec.motorcycles
# 1110 soc.religion.christian
# 1111 rec.autos
# 1112 rec.motorcycles
# 1113 sci.space
# 1114 talk.politics.misc
# 1115 rec.sport.hockey
# 1116 comp.graphics
# 1117 sci.electronics
# 1118 comp.windows.x
# 1119 sci.electronics
# 1120 talk.religion.misc
# 1121 comp.sys.ibm.pc.hardware
# 1122 sci.med
# 1123 rec.autos
# 1124 sci.space
# 1125 misc.forsale
# 1126 rec.autos
# 1127 soc.religion.christian
# 1128 comp.sys.ibm.pc.hardware
# 1129 soc.religion.christian
# 1130 rec.sport.hockey
# 1131 talk.politics.misc
# 1132 soc.religion.christian
# 1133 talk.politics.mideast
# 1134 sci.crypt
# 1135 rec.sport.hockey
# 1136 soc.religion.christian
# 1137 alt.atheism
# 1138 sci.crypt
# 1139 comp.windows.x
# 1140 comp.graphics
# 1141 rec.sport.baseball
# 1142 talk.religion.misc
# 1143 misc.forsale
# 1144 rec.autos
# 1145 comp.sys.mac.hardware
# 1146 comp.windows.x
# 1147 soc.religion.christian
# 1148 talk.politics.guns
# 1149 rec.sport.hockey
# 1150 comp.sys.ibm.pc.hardware
# 1151 talk.politics.mideast
# 1152 sci.electronics
# 1153 rec.sport.hockey
# 1154 soc.religion.christian
# 1155 rec.sport.hockey
# 1156 comp.graphics
# 1157 comp.windows.x
# 1158 comp.windows.x
# 1159 talk.politics.guns
# 1160 rec.autos
# 1161 comp.sys.mac.hardware
# 1162 comp.sys.ibm.pc.hardware
# 1163 sci.crypt
# 1164 rec.sport.hockey
# 1165 comp.sys.mac.hardware
# 1166 talk.politics.misc
# 1167 comp.graphics
# 1168 rec.autos
# 1169 rec.sport.baseball
# 1170 talk.politics.guns
# 1171 misc.forsale
# 1172 sci.space
# 1173 talk.politics.mideast
# 1174 rec.motorcycles
# 1175 soc.religion.christian
# 1176 sci.space
# 1177 alt.atheism
# 1178 comp.os.ms-windows.misc
# 1179 talk.politics.guns
# 1180 talk.politics.guns
# 1181 rec.motorcycles
# 1182 sci.crypt
# 1183 misc.forsale
# 1184 talk.politics.misc
# 1185 comp.sys.ibm.pc.hardware
# 1186 misc.forsale
# 1187 talk.politics.guns
# 1188 sci.crypt
# 1189 comp.windows.x
# 1190 comp.sys.ibm.pc.hardware
# 1191 talk.politics.misc
# 1192 sci.crypt
# 1193 alt.atheism
# 1194 comp.sys.ibm.pc.hardware
# 1195 sci.med
# 1196 rec.sport.hockey
# 1197 rec.sport.hockey
# 1198 soc.religion.christian
# 1199 sci.crypt
# 1200 talk.politics.misc
# 1201 misc.forsale
# 1202 rec.motorcycles
# 1203 sci.med
# 1204 comp.os.ms-windows.misc
# 1205 rec.sport.hockey
# 1206 misc.forsale
# 1207 comp.os.ms-windows.misc
# 1208 comp.sys.mac.hardware
# 1209 rec.motorcycles
# 1210 talk.politics.misc
# 1211 rec.sport.hockey
# 1212 sci.crypt
# 1213 rec.sport.hockey
# 1214 rec.autos
# 1215 misc.forsale
# 1216 comp.os.ms-windows.misc
# 1217 sci.electronics
# 1218 comp.os.ms-windows.misc
# 1219 alt.atheism
# 1220 sci.med
# 1221 comp.os.ms-windows.misc
# 1222 rec.sport.hockey
# 1223 talk.religion.misc
# 1224 rec.autos
# 1225 comp.sys.mac.hardware
# 1226 comp.windows.x
# 1227 rec.motorcycles
# 1228 soc.religion.christian
# 1229 rec.autos
# 1230 rec.sport.hockey
# 1231 misc.forsale
# 1232 rec.motorcycles
# 1233 soc.religion.christian
# 1234 talk.politics.guns
# 1235 comp.windows.x
# 1236 misc.forsale
# 1237 comp.sys.ibm.pc.hardware
# 1238 alt.atheism
# 1239 sci.space
# 1240 talk.religion.misc
# 1241 rec.motorcycles
# 1242 comp.os.ms-windows.misc
# 1243 rec.sport.hockey
# 1244 comp.os.ms-windows.misc
# 1245 soc.religion.christian
# 1246 rec.autos
# 1247 rec.motorcycles
# 1248 talk.politics.misc
# 1249 sci.med
# 1250 misc.forsale
# 1251 alt.atheism
# 1252 comp.sys.ibm.pc.hardware
# 1253 sci.crypt
# 1254 sci.electronics
# 1255 alt.atheism
# 1256 rec.sport.baseball
# 1257 sci.electronics
# 1258 sci.crypt
# 1259 sci.crypt
# 1260 sci.electronics
# 1261 talk.politics.misc
# 1262 comp.windows.x
# 1263 sci.space
# 1264 sci.space
# 1265 talk.religion.misc
# 1266 talk.religion.misc
# 1267 comp.graphics
# 1268 comp.graphics
# 1269 comp.os.ms-windows.misc
# 1270 comp.sys.mac.hardware
# 1271 sci.crypt
# 1272 comp.os.ms-windows.misc
# 1273 soc.religion.christian
# 1274 comp.windows.x
# 1275 misc.forsale
# 1276 comp.sys.mac.hardware
# 1277 comp.sys.ibm.pc.hardware
# 1278 talk.religion.misc
# 1279 talk.politics.misc
# 1280 comp.os.ms-windows.misc
# 1281 talk.politics.mideast
# 1282 rec.sport.baseball
# 1283 sci.crypt
# 1284 talk.politics.mideast
# 1285 misc.forsale
# 1286 soc.religion.christian
# 1287 rec.autos
# 1288 sci.space
# 1289 sci.med
# 1290 comp.graphics
# 1291 alt.atheism
# 1292 talk.politics.mideast
# 1293 talk.politics.misc
# 1294 sci.electronics
# 1295 comp.sys.ibm.pc.hardware
# 1296 comp.os.ms-windows.misc
# 1297 misc.forsale
# 1298 rec.motorcycles
# 1299 sci.crypt
# 1300 sci.med
# 1301 soc.religion.christian
# 1302 talk.politics.mideast
# 1303 talk.politics.misc
# 1304 comp.windows.x
# 1305 talk.politics.mideast
# 1306 talk.politics.misc
# 1307 talk.religion.misc
# 1308 comp.os.ms-windows.misc
# 1309 comp.sys.mac.hardware
# 1310 sci.med
# 1311 alt.atheism
# 1312 rec.sport.hockey
# 1313 rec.motorcycles
# 1314 rec.motorcycles
# 1315 comp.os.ms-windows.misc
# 1316 rec.sport.baseball
# 1317 sci.electronics
# 1318 rec.sport.hockey
# 1319 rec.sport.hockey
# 1320 talk.religion.misc
# 1321 talk.politics.guns
# 1322 talk.politics.guns
# 1323 sci.med
# 1324 rec.autos
# 1325 alt.atheism
# 1326 rec.sport.baseball
# 1327 comp.sys.mac.hardware
# 1328 rec.motorcycles
# 1329 sci.med
# 1330 rec.motorcycles
# 1331 sci.electronics
# 1332 talk.politics.guns
# 1333 talk.politics.mideast
# 1334 talk.politics.mideast
# 1335 comp.os.ms-windows.misc
# 1336 sci.crypt
# 1337 comp.graphics
# 1338 sci.med
# 1339 comp.sys.ibm.pc.hardware
# 1340 comp.graphics
# 1341 soc.religion.christian
# 1342 sci.crypt
# 1343 talk.politics.misc
# 1344 sci.electronics
# 1345 sci.electronics
# 1346 comp.windows.x
# 1347 talk.politics.guns
# 1348 comp.graphics
# 1349 comp.windows.x
# 1350 rec.motorcycles
# 1351 misc.forsale
# 1352 talk.politics.mideast
# 1353 sci.crypt
# 1354 sci.electronics
# 1355 comp.graphics
# 1356 rec.motorcycles
# 1357 sci.space
# 1358 comp.windows.x
# 1359 talk.religion.misc
# 1360 soc.religion.christian
# 1361 sci.crypt
# 1362 talk.politics.mideast
# 1363 rec.autos
# 1364 sci.med
# 1365 rec.sport.baseball
# 1366 talk.religion.misc
# 1367 rec.sport.baseball
# 1368 sci.crypt
# 1369 comp.os.ms-windows.misc
# 1370 comp.sys.mac.hardware
# 1371 sci.crypt
# 1372 rec.motorcycles
# 1373 comp.graphics
# 1374 rec.sport.hockey
# 1375 rec.autos
# 1376 comp.sys.mac.hardware
# 1377 comp.sys.mac.hardware
# 1378 comp.windows.x
# 1379 sci.crypt
# 1380 comp.os.ms-windows.misc
# 1381 rec.motorcycles
# 1382 rec.motorcycles
# 1383 talk.politics.mideast
# 1384 talk.politics.guns
# 1385 sci.electronics
# 1386 sci.med
# 1387 talk.politics.mideast
# 1388 sci.electronics
# 1389 sci.med
# 1390 comp.windows.x
# 1391 talk.politics.guns
# 1392 sci.crypt
# 1393 sci.crypt
# 1394 sci.med
# 1395 talk.politics.mideast
# 1396 sci.crypt
# 1397 talk.politics.guns
# 1398 sci.med
# 1399 sci.space
# 1400 sci.med
# 1401 rec.autos
# 1402 sci.space
# 1403 comp.os.ms-windows.misc
# 1404 soc.religion.christian
# 1405 comp.windows.x
# 1406 talk.politics.misc
# 1407 sci.electronics
# 1408 sci.crypt
# 1409 misc.forsale
# 1410 soc.religion.christian
# 1411 rec.motorcycles
# 1412 talk.politics.misc
# 1413 sci.space
# 1414 comp.os.ms-windows.misc
# 1415 rec.sport.baseball
# 1416 comp.os.ms-windows.misc
# 1417 sci.electronics
# 1418 sci.crypt
# 1419 comp.sys.mac.hardware
# 1420 talk.politics.misc
# 1421 comp.sys.mac.hardware
# 1422 talk.politics.misc
# 1423 comp.windows.x
# 1424 rec.sport.hockey
# 1425 comp.graphics
# 1426 comp.sys.ibm.pc.hardware
# 1427 talk.politics.mideast
# 1428 comp.sys.mac.hardware
# 1429 sci.med
# 1430 talk.politics.guns
# 1431 sci.med
# 1432 sci.electronics
# 1433 comp.windows.x
# 1434 sci.electronics
# 1435 alt.atheism
# 1436 rec.sport.hockey
# 1437 rec.motorcycles
# 1438 sci.med
# 1439 talk.religion.misc
# 1440 talk.religion.misc
# 1441 comp.windows.x
# 1442 sci.med
# 1443 talk.politics.misc
# 1444 rec.autos
# 1445 rec.motorcycles
# 1446 rec.sport.hockey
# 1447 sci.crypt
# 1448 talk.politics.mideast
# 1449 rec.sport.baseball
# 1450 sci.space
# 1451 talk.politics.misc
# 1452 talk.politics.guns
# 1453 talk.religion.misc
# 1454 rec.sport.baseball
# 1455 comp.sys.mac.hardware
# 1456 comp.sys.ibm.pc.hardware
# 1457 comp.graphics
# 1458 alt.atheism
# 1459 comp.windows.x
# 1460 sci.electronics
# 1461 rec.sport.baseball
# 1462 talk.religion.misc
# 1463 sci.electronics
# 1464 talk.politics.guns
# 1465 comp.sys.mac.hardware
# 1466 comp.sys.ibm.pc.hardware
# 1467 talk.politics.guns
# 1468 talk.politics.guns
# 1469 sci.crypt
# 1470 sci.med
# 1471 comp.graphics
# 1472 comp.graphics
# 1473 comp.sys.ibm.pc.hardware
# 1474 rec.autos
# 1475 talk.politics.guns
# 1476 sci.electronics
# 1477 sci.electronics
# 1478 talk.politics.misc
# 1479 comp.sys.ibm.pc.hardware
# 1480 comp.graphics
# 1481 talk.politics.misc
# 1482 talk.politics.mideast
# 1483 sci.space
# 1484 sci.electronics
# 1485 rec.sport.baseball
# 1486 rec.sport.baseball
# 1487 talk.politics.guns
# 1488 sci.electronics
# 1489 rec.motorcycles
# 1490 comp.os.ms-windows.misc
# 1491 talk.politics.guns
# 1492 comp.os.ms-windows.misc
# 1493 talk.politics.guns
# 1494 rec.autos
# 1495 comp.windows.x
# 1496 rec.motorcycles
# 1497 sci.crypt
# 1498 comp.windows.x
# 1499 talk.religion.misc
# 1500 rec.autos
# 1501 comp.graphics
# 1502 misc.forsale
# 1503 rec.motorcycles
# 1504 rec.sport.hockey
# 1505 talk.politics.guns
# 1506 comp.os.ms-windows.misc
# 1507 talk.politics.guns
# 1508 misc.forsale
# 1509 talk.politics.mideast
# 1510 misc.forsale
# 1511 talk.politics.misc
# 1512 comp.sys.mac.hardware
# 1513 talk.politics.mideast
# 1514 rec.autos
# 1515 comp.os.ms-windows.misc
# 1516 rec.sport.hockey
# 1517 talk.politics.mideast
# 1518 sci.crypt
# 1519 alt.atheism
# 1520 sci.electronics
# 1521 misc.forsale
# 1522 comp.sys.mac.hardware
# 1523 rec.sport.hockey
# 1524 comp.sys.mac.hardware
# 1525 comp.os.ms-windows.misc
# 1526 sci.crypt
# 1527 comp.os.ms-windows.misc
# 1528 alt.atheism
# 1529 comp.sys.mac.hardware
# 1530 talk.politics.guns
# 1531 sci.space
# 1532 rec.motorcycles
# 1533 soc.religion.christian
# 1534 alt.atheism
# 1535 comp.os.ms-windows.misc
# 1536 talk.politics.mideast
# 1537 sci.med
# 1538 comp.os.ms-windows.misc
# 1539 comp.sys.ibm.pc.hardware
# 1540 talk.politics.mideast
# 1541 comp.os.ms-windows.misc
# 1542 rec.sport.baseball
# 1543 rec.sport.hockey
# 1544 comp.sys.mac.hardware
# 1545 comp.sys.mac.hardware
# 1546 comp.sys.ibm.pc.hardware
# 1547 comp.os.ms-windows.misc
# 1548 sci.space
# 1549 soc.religion.christian
# 1550 misc.forsale
# 1551 sci.electronics
# 1552 comp.os.ms-windows.misc
# 1553 rec.sport.baseball
# 1554 sci.crypt
# 1555 talk.politics.misc
# 1556 sci.crypt
# 1557 soc.religion.christian
# 1558 talk.politics.guns
# 1559 talk.politics.misc
# 1560 sci.med
# 1561 alt.atheism
# 1562 talk.politics.guns
# 1563 rec.sport.baseball
# 1564 rec.motorcycles
# 1565 soc.religion.christian
# 1566 comp.sys.mac.hardware
# 1567 comp.graphics
# 1568 comp.sys.ibm.pc.hardware
# 1569 sci.electronics
# 1570 rec.sport.baseball
# 1571 sci.space
# 1572 rec.autos
# 1573 rec.sport.hockey
# 1574 comp.sys.ibm.pc.hardware
# 1575 sci.electronics
# 1576 misc.forsale
# 1577 talk.politics.mideast
# 1578 talk.politics.mideast
# 1579 comp.os.ms-windows.misc
# 1580 comp.sys.ibm.pc.hardware
# 1581 sci.electronics
# 1582 comp.sys.ibm.pc.hardware
# 1583 sci.space
# 1584 misc.forsale
# 1585 comp.sys.ibm.pc.hardware
# 1586 comp.graphics
# 1587 rec.sport.baseball
# 1588 sci.med
# 1589 rec.sport.baseball
# 1590 talk.politics.misc
# 1591 comp.graphics
# 1592 rec.sport.hockey
# 1593 sci.med
# 1594 sci.space
# 1595 rec.autos
# 1596 sci.electronics
# 1597 talk.politics.guns
# 1598 talk.religion.misc
# 1599 talk.politics.mideast
# 1600 talk.religion.misc
# 1601 rec.autos
# 1602 comp.windows.x
# 1603 comp.os.ms-windows.misc
# 1604 sci.electronics
# 1605 comp.sys.ibm.pc.hardware
# 1606 rec.sport.baseball
# 1607 rec.sport.baseball
# 1608 comp.windows.x
# 1609 alt.atheism
# 1610 rec.autos
# 1611 rec.autos
# 1612 talk.politics.guns
# 1613 rec.sport.hockey
# 1614 soc.religion.christian
# 1615 sci.space
# 1616 comp.graphics
# 1617 soc.religion.christian
# 1618 rec.motorcycles
# 1619 soc.religion.christian
# 1620 sci.space
# 1621 rec.motorcycles
# 1622 comp.windows.x
# 1623 rec.sport.hockey
# 1624 misc.forsale
# 1625 rec.autos
# 1626 comp.os.ms-windows.misc
# 1627 comp.sys.ibm.pc.hardware
# 1628 talk.politics.misc
# 1629 alt.atheism
# 1630 rec.sport.hockey
# 1631 rec.sport.hockey
# 1632 comp.graphics
# 1633 comp.windows.x
# 1634 comp.sys.mac.hardware
# 1635 rec.motorcycles
# 1636 sci.med
# 1637 comp.sys.ibm.pc.hardware
# 1638 sci.space
# 1639 comp.sys.mac.hardware
# 1640 rec.sport.baseball
# 1641 comp.sys.mac.hardware
# 1642 soc.religion.christian
# 1643 alt.atheism
# 1644 comp.windows.x
# 1645 rec.sport.baseball
# 1646 misc.forsale
# 1647 sci.med
# 1648 talk.politics.guns
# 1649 talk.religion.misc
# 1650 misc.forsale
# 1651 rec.sport.baseball
# 1652 comp.sys.mac.hardware
# 1653 rec.sport.hockey
# 1654 rec.autos
# 1655 rec.sport.hockey
# 1656 comp.graphics
# 1657 rec.sport.baseball
# 1658 soc.religion.christian
# 1659 rec.autos
# 1660 sci.crypt
# 1661 comp.sys.mac.hardware
# 1662 rec.motorcycles
# 1663 comp.os.ms-windows.misc
# 1664 comp.graphics
# 1665 sci.space
# 1666 sci.med
# 1667 misc.forsale
# 1668 soc.religion.christian
# 1669 rec.autos
# 1670 comp.os.ms-windows.misc
# 1671 sci.electronics
# 1672 soc.religion.christian
# 1673 comp.graphics
# 1674 rec.motorcycles
# 1675 sci.med
# 1676 sci.crypt
# 1677 comp.sys.ibm.pc.hardware
# 1678 comp.sys.ibm.pc.hardware
# 1679 sci.crypt
# 1680 sci.space
# 1681 rec.sport.baseball
# 1682 soc.religion.christian
# 1683 rec.sport.hockey
# 1684 comp.sys.mac.hardware
# 1685 sci.med
# 1686 talk.politics.mideast
# 1687 rec.autos
# 1688 rec.motorcycles
# 1689 misc.forsale
# 1690 misc.forsale
# 1691 sci.space
# 1692 sci.electronics
# 1693 comp.os.ms-windows.misc
# 1694 comp.sys.ibm.pc.hardware
# 1695 talk.politics.mideast
# 1696 talk.politics.guns
# 1697 sci.electronics
# 1698 comp.os.ms-windows.misc
# 1699 rec.sport.baseball
# 1700 sci.med
# 1701 comp.os.ms-windows.misc
# 1702 comp.windows.x
# 1703 talk.religion.misc
# 1704 comp.windows.x
# 1705 rec.motorcycles
# 1706 rec.sport.baseball
# 1707 comp.graphics
# 1708 misc.forsale
# 1709 comp.sys.ibm.pc.hardware
# 1710 sci.med
# 1711 talk.politics.mideast
# 1712 comp.windows.x
# 1713 rec.motorcycles
# 1714 comp.sys.mac.hardware
# 1715 comp.graphics
# 1716 comp.os.ms-windows.misc
# 1717 comp.windows.x
# 1718 rec.sport.hockey
# 1719 rec.sport.hockey
# 1720 misc.forsale
# 1721 sci.electronics
# 1722 comp.os.ms-windows.misc
# 1723 rec.motorcycles
# 1724 talk.religion.misc
# 1725 comp.graphics
# 1726 sci.crypt
# 1727 comp.os.ms-windows.misc
# 1728 talk.politics.mideast
# 1729 sci.electronics
# 1730 talk.religion.misc
# 1731 sci.electronics
# 1732 talk.politics.guns
# 1733 comp.os.ms-windows.misc
# 1734 talk.religion.misc
# 1735 sci.crypt
# 1736 misc.forsale
# 1737 talk.religion.misc
# 1738 sci.space
# 1739 misc.forsale
# 1740 talk.politics.misc
# 1741 talk.politics.misc
# 1742 misc.forsale
# 1743 comp.sys.mac.hardware
# 1744 misc.forsale
# 1745 sci.med
# 1746 sci.crypt
# 1747 rec.sport.baseball
# 1748 rec.autos
# 1749 soc.religion.christian
# 1750 rec.motorcycles
# 1751 talk.politics.mideast
# 1752 talk.politics.guns
# 1753 sci.med
# 1754 rec.sport.hockey
# 1755 comp.graphics
# 1756 talk.politics.misc
# 1757 rec.sport.baseball
# 1758 comp.windows.x
# 1759 rec.sport.hockey
# 1760 sci.crypt
# 1761 sci.space
# 1762 sci.electronics
# 1763 rec.motorcycles
# 1764 comp.graphics
# 1765 rec.sport.baseball
# 1766 rec.motorcycles
# 1767 talk.politics.guns
# 1768 sci.crypt
# 1769 sci.space
# 1770 sci.electronics
# 1771 misc.forsale
# 1772 comp.graphics
# 1773 soc.religion.christian
# 1774 comp.windows.x
# 1775 comp.sys.mac.hardware
# 1776 sci.med
# 1777 rec.autos
# 1778 rec.motorcycles
# 1779 rec.motorcycles
# 1780 comp.windows.x
# 1781 rec.motorcycles
# 1782 comp.os.ms-windows.misc
# 1783 sci.space
# 1784 sci.med
# 1785 sci.space
# 1786 talk.politics.mideast
# 1787 sci.crypt
# 1788 rec.sport.baseball
# 1789 rec.motorcycles
# 1790 rec.motorcycles
# 1791 rec.autos
# 1792 comp.sys.mac.hardware
# 1793 soc.religion.christian
# 1794 comp.sys.ibm.pc.hardware
# 1795 comp.sys.ibm.pc.hardware
# 1796 comp.sys.ibm.pc.hardware
# 1797 sci.crypt
# 1798 comp.graphics
# 1799 rec.autos
# 1800 sci.electronics
# 1801 talk.religion.misc
# 1802 sci.crypt
# 1803 comp.graphics
# 1804 sci.electronics
# 1805 talk.politics.guns
# 1806 sci.electronics
# 1807 rec.autos
# 1808 talk.politics.mideast
# 1809 rec.sport.baseball
# 1810 alt.atheism
# 1811 comp.os.ms-windows.misc
# 1812 sci.med
# 1813 rec.motorcycles
# 1814 sci.electronics
# 1815 rec.motorcycles
# 1816 misc.forsale
# 1817 sci.electronics
# 1818 sci.space
# 1819 sci.electronics
# 1820 rec.autos
# 1821 comp.os.ms-windows.misc
# 1822 comp.sys.ibm.pc.hardware
# 1823 misc.forsale
# 1824 comp.sys.mac.hardware
# 1825 rec.autos
# 1826 soc.religion.christian
# 1827 rec.sport.baseball
# 1828 rec.sport.baseball
# 1829 comp.windows.x
# 1830 sci.space
# 1831 comp.graphics
# 1832 comp.sys.mac.hardware
# 1833 rec.sport.baseball
# 1834 sci.med
# 1835 comp.graphics
# 1836 comp.sys.mac.hardware
# 1837 rec.motorcycles
# 1838 rec.motorcycles
# 1839 sci.med
# 1840 rec.sport.hockey
# 1841 comp.sys.ibm.pc.hardware
# 1842 talk.politics.guns
# 1843 rec.motorcycles
# 1844 rec.sport.hockey
# 1845 sci.electronics
# 1846 rec.autos
# 1847 rec.sport.baseball
# 1848 comp.windows.x
# 1849 rec.motorcycles
# 1850 comp.os.ms-windows.misc
# 1851 comp.sys.ibm.pc.hardware
# 1852 rec.autos
# 1853 talk.politics.guns
# 1854 misc.forsale
# 1855 talk.politics.guns
# 1856 rec.autos
# 1857 rec.sport.baseball
# 1858 sci.crypt
# 1859 comp.sys.ibm.pc.hardware
# 1860 misc.forsale
# 1861 comp.sys.mac.hardware
# 1862 rec.sport.baseball
# 1863 comp.os.ms-windows.misc
# 1864 rec.motorcycles
# 1865 talk.politics.guns
# 1866 talk.politics.mideast
# 1867 sci.med
# 1868 rec.sport.hockey
# 1869 comp.graphics
# 1870 rec.sport.hockey
# 1871 rec.motorcycles
# 1872 sci.space
# 1873 comp.windows.x
# 1874 comp.sys.mac.hardware
# 1875 rec.sport.hockey
# 1876 alt.atheism
# 1877 misc.forsale
# 1878 sci.electronics
# 1879 sci.crypt
# 1880 rec.sport.hockey
# 1881 comp.sys.ibm.pc.hardware
# 1882 talk.politics.mideast
# 1883 alt.atheism
# 1884 sci.med
# 1885 sci.med
# 1886 comp.sys.ibm.pc.hardware
# 1887 misc.forsale
# 1888 soc.religion.christian
# 1889 alt.atheism
# 1890 talk.politics.misc
# 1891 talk.religion.misc
# 1892 comp.os.ms-windows.misc
# 1893 sci.med
# 1894 sci.electronics
# 1895 comp.sys.mac.hardware
# 1896 sci.crypt
# 1897 rec.sport.baseball
# 1898 rec.sport.hockey
# 1899 talk.politics.guns
# 1900 talk.politics.guns
# 1901 rec.autos
# 1902 talk.politics.mideast
# 1903 sci.crypt
# 1904 talk.politics.guns
# 1905 sci.electronics
# 1906 talk.politics.mideast
# 1907 comp.graphics
# 1908 talk.politics.mideast
# 1909 alt.atheism
# 1910 rec.autos
# 1911 soc.religion.christian
# 1912 talk.politics.guns
# 1913 comp.sys.ibm.pc.hardware
# 1914 soc.religion.christian
# 1915 comp.sys.ibm.pc.hardware
# 1916 rec.sport.hockey
# 1917 talk.politics.mideast
# 1918 alt.atheism
# 1919 rec.sport.hockey
# 1920 rec.sport.hockey
# 1921 comp.windows.x
# 1922 talk.politics.guns
# 1923 sci.med
# 1924 soc.religion.christian
# 1925 comp.graphics
# 1926 comp.os.ms-windows.misc
# 1927 sci.electronics
# 1928 comp.graphics
# 1929 comp.sys.mac.hardware
# 1930 misc.forsale
# 1931 rec.sport.baseball
# 1932 misc.forsale
# 1933 comp.sys.ibm.pc.hardware
# 1934 talk.politics.guns
# 1935 comp.windows.x
# 1936 alt.atheism
# 1937 sci.crypt
# 1938 rec.motorcycles
# 1939 talk.politics.mideast
# 1940 sci.crypt
# 1941 talk.politics.misc
# 1942 talk.politics.misc
# 1943 alt.atheism
# 1944 alt.atheism
# 1945 rec.motorcycles
# 1946 soc.religion.christian
# 1947 comp.windows.x
# 1948 rec.motorcycles
# 1949 comp.os.ms-windows.misc
# 1950 sci.crypt
# 1951 comp.windows.x
# 1952 rec.motorcycles
# 1953 comp.sys.mac.hardware
# 1954 sci.crypt
# 1955 sci.crypt
# 1956 soc.religion.christian
# 1957 comp.sys.mac.hardware
# 1958 comp.windows.x
# 1959 comp.sys.mac.hardware
# 1960 comp.sys.ibm.pc.hardware
# 1961 talk.politics.guns
# 1962 talk.religion.misc
# 1963 sci.space
# 1964 rec.sport.hockey
# 1965 rec.sport.hockey
# 1966 comp.sys.mac.hardware
# 1967 rec.sport.baseball
# 1968 comp.windows.x
# 1969 rec.sport.baseball
# 1970 sci.crypt
# 1971 rec.sport.baseball
# 1972 soc.religion.christian
# 1973 comp.windows.x
# 1974 talk.politics.guns
# 1975 talk.politics.guns
# 1976 talk.politics.guns
# 1977 sci.space
# 1978 soc.religion.christian
# 1979 rec.sport.hockey
# 1980 comp.windows.x
# 1981 talk.politics.guns
# 1982 comp.windows.x
# 1983 comp.sys.ibm.pc.hardware
# 1984 misc.forsale
# 1985 sci.med
# 1986 comp.windows.x
# 1987 rec.sport.hockey
# 1988 rec.sport.hockey
# 1989 soc.religion.christian
# 1990 misc.forsale
# 1991 rec.sport.baseball
# 1992 comp.windows.x
# 1993 comp.sys.ibm.pc.hardware
# 1994 comp.windows.x
# 1995 talk.politics.mideast
# 1996 rec.sport.baseball
# 1997 rec.autos
# 1998 talk.politics.mideast
# 1999 soc.religion.christian
# 2000 rec.motorcycles
# 2001 soc.religion.christian
# 2002 misc.forsale
# 2003 rec.sport.baseball
# 2004 rec.autos
# 2005 comp.os.ms-windows.misc
# 2006 talk.politics.misc
# 2007 talk.politics.mideast
# 2008 rec.autos
# 2009 sci.crypt
# 2010 rec.sport.baseball
# 2011 comp.sys.ibm.pc.hardware
# 2012 soc.religion.christian
# 2013 soc.religion.christian
# 2014 rec.autos
# 2015 rec.sport.baseball
# 2016 comp.sys.ibm.pc.hardware
# 2017 talk.politics.guns
# 2018 rec.sport.baseball
# 2019 sci.med
# 2020 sci.med
# 2021 rec.sport.hockey
# 2022 talk.religion.misc
# 2023 talk.politics.guns
# 2024 comp.windows.x
# 2025 comp.sys.ibm.pc.hardware
# 2026 sci.electronics
# 2027 sci.electronics
# 2028 misc.forsale
# 2029 rec.sport.baseball
# 2030 talk.politics.mideast
# 2031 talk.politics.misc
# 2032 rec.sport.hockey
# 2033 comp.windows.x
# 2034 rec.motorcycles
# 2035 comp.sys.mac.hardware
# 2036 comp.sys.ibm.pc.hardware
# 2037 rec.sport.baseball
# 2038 comp.os.ms-windows.misc
# 2039 sci.crypt
# 2040 misc.forsale
# 2041 comp.sys.mac.hardware
# 2042 sci.space
# 2043 soc.religion.christian
# 2044 rec.sport.baseball
# 2045 rec.motorcycles
# 2046 alt.atheism
# 2047 misc.forsale
# 2048 rec.sport.hockey
# 2049 rec.autos
# 2050 sci.space
# 2051 misc.forsale
# 2052 sci.crypt
# 2053 talk.religion.misc
# 2054 talk.politics.guns
# 2055 comp.sys.ibm.pc.hardware
# 2056 comp.windows.x
# 2057 talk.politics.guns
# 2058 sci.med
# 2059 comp.windows.x
# 2060 talk.politics.mideast
# 2061 sci.space
# 2062 comp.graphics
# 2063 rec.motorcycles
# 2064 comp.windows.x
# 2065 sci.crypt
# 2066 talk.politics.guns
# 2067 soc.religion.christian
# 2068 talk.politics.misc
# 2069 comp.sys.mac.hardware
# 2070 soc.religion.christian
# 2071 sci.space
# 2072 comp.os.ms-windows.misc
# 2073 talk.politics.guns
# 2074 comp.sys.mac.hardware
# 2075 comp.sys.ibm.pc.hardware
# 2076 talk.politics.guns
# 2077 talk.politics.mideast
# 2078 rec.sport.baseball
# 2079 rec.sport.hockey
# 2080 talk.religion.misc
# 2081 comp.os.ms-windows.misc
# 2082 comp.os.ms-windows.misc
# 2083 misc.forsale
# 2084 rec.sport.baseball
# 2085 talk.politics.guns
# 2086 rec.autos
# 2087 soc.religion.christian
# 2088 comp.sys.mac.hardware
# 2089 comp.os.ms-windows.misc
# 2090 misc.forsale
# 2091 talk.politics.guns
# 2092 rec.autos
# 2093 alt.atheism
# 2094 sci.space
# 2095 alt.atheism
# 2096 comp.os.ms-windows.misc
# 2097 sci.med
# 2098 comp.windows.x
# 2099 talk.religion.misc
# 2100 sci.electronics
# 2101 comp.windows.x
# 2102 soc.religion.christian
# 2103 sci.crypt
# 2104 sci.crypt
# 2105 misc.forsale
# 2106 comp.windows.x
# 2107 alt.atheism
# 2108 rec.motorcycles
# 2109 alt.atheism
# 2110 talk.politics.misc
# 2111 sci.space
# 2112 rec.sport.hockey
# 2113 alt.atheism
# 2114 comp.os.ms-windows.misc
# 2115 talk.politics.guns
# 2116 comp.sys.mac.hardware
# 2117 rec.sport.baseball
# 2118 soc.religion.christian
# 2119 talk.religion.misc
# 2120 talk.politics.guns
# 2121 comp.windows.x
# 2122 talk.politics.mideast
# 2123 comp.windows.x
# 2124 sci.med
# 2125 comp.graphics
# 2126 rec.autos
# 2127 rec.sport.hockey
# 2128 talk.politics.misc
# 2129 misc.forsale
# 2130 comp.os.ms-windows.misc
# 2131 misc.forsale
# 2132 misc.forsale
# 2133 comp.sys.mac.hardware
# 2134 rec.autos
# 2135 comp.windows.x
# 2136 talk.politics.guns
# 2137 rec.sport.baseball
# 2138 comp.sys.ibm.pc.hardware
# 2139 rec.autos
# 2140 comp.os.ms-windows.misc
# 2141 rec.motorcycles
# 2142 misc.forsale
# 2143 comp.os.ms-windows.misc
# 2144 comp.graphics
# 2145 alt.atheism
# 2146 comp.sys.ibm.pc.hardware
# 2147 alt.atheism
# 2148 talk.politics.misc
# 2149 talk.politics.mideast
# 2150 sci.med
# 2151 comp.graphics
# 2152 rec.motorcycles
# 2153 misc.forsale
# 2154 comp.graphics
# 2155 comp.sys.mac.hardware
# 2156 talk.politics.guns
# 2157 sci.crypt
# 2158 comp.sys.mac.hardware
# 2159 comp.os.ms-windows.misc
# 2160 sci.med
# 2161 rec.motorcycles
# 2162 rec.autos
# 2163 rec.motorcycles
# 2164 comp.sys.ibm.pc.hardware
# 2165 sci.electronics
# 2166 rec.autos
# 2167 rec.motorcycles
# 2168 sci.space
# 2169 rec.sport.hockey
# 2170 comp.os.ms-windows.misc
# 2171 rec.sport.baseball
# 2172 sci.space
# 2173 rec.sport.baseball
# 2174 soc.religion.christian
# 2175 sci.crypt
# 2176 sci.space
# 2177 talk.politics.mideast
# 2178 sci.med
# 2179 soc.religion.christian
# 2180 talk.politics.guns
# 2181 sci.med
# 2182 comp.graphics
# 2183 rec.autos
# 2184 sci.space
# 2185 talk.religion.misc
# 2186 comp.sys.mac.hardware
# 2187 talk.politics.mideast
# 2188 talk.politics.mideast
# 2189 sci.med
# 2190 talk.politics.guns
# 2191 soc.religion.christian
# 2192 talk.religion.misc
# 2193 sci.crypt
# 2194 talk.politics.mideast
# 2195 alt.atheism
# 2196 talk.politics.mideast
# 2197 alt.atheism
# 2198 comp.sys.mac.hardware
# 2199 soc.religion.christian
# 2200 talk.politics.guns
# 2201 sci.electronics
# 2202 sci.electronics
# 2203 sci.crypt
# 2204 rec.sport.baseball
# 2205 rec.sport.baseball
# 2206 comp.graphics
# 2207 rec.sport.baseball
# 2208 comp.graphics
# 2209 sci.space
# 2210 sci.med
# 2211 sci.space
# 2212 talk.politics.guns
# 2213 comp.sys.mac.hardware
# 2214 sci.med
# 2215 sci.electronics
# 2216 rec.motorcycles
# 2217 comp.sys.mac.hardware
# 2218 sci.space
# 2219 soc.religion.christian
# 2220 comp.os.ms-windows.misc
# 2221 alt.atheism
# 2222 soc.religion.christian
# 2223 soc.religion.christian
# 2224 soc.religion.christian
# 2225 alt.atheism
# 2226 rec.autos
# 2227 talk.politics.mideast
# 2228 sci.electronics
# 2229 comp.windows.x
# 2230 talk.religion.misc
# 2231 comp.sys.mac.hardware
# 2232 comp.graphics
# 2233 comp.windows.x
# 2234 talk.politics.misc
# 2235 rec.motorcycles
# 2236 sci.electronics
# 2237 talk.politics.misc
# 2238 comp.os.ms-windows.misc
# 2239 comp.windows.x
# 2240 alt.atheism
# 2241 comp.sys.ibm.pc.hardware
# 2242 talk.politics.mideast
# 2243 comp.os.ms-windows.misc
# 2244 talk.politics.mideast
# 2245 alt.atheism
# 2246 sci.electronics
# 2247 rec.sport.baseball
# 2248 talk.politics.guns
# 2249 talk.politics.guns
# 2250 rec.sport.hockey
# 2251 comp.graphics
# 2252 alt.atheism
# 2253 comp.sys.mac.hardware
# 2254 alt.atheism
# 2255 rec.autos
# 2256 sci.crypt
# 2257 soc.religion.christian
# 2258 comp.sys.mac.hardware
# 2259 misc.forsale
# 2260 rec.sport.baseball
# ...
# 10611 sci.crypt
# 10612 sci.electronics
# 10613 talk.religion.misc
# 10614 talk.politics.mideast
# 10615 misc.forsale
# 10616 comp.os.ms-windows.misc
# 10617 sci.med
# 10618 rec.sport.hockey
# 10619 sci.space
# 10620 comp.graphics
# 10621 rec.sport.hockey
# 10622 comp.os.ms-windows.misc
# 10623 talk.politics.guns
# 10624 soc.religion.christian
# 10625 rec.autos
# 10626 rec.autos
# 10627 rec.sport.baseball
# 10628 rec.motorcycles
# 10629 talk.politics.misc
# 10630 rec.motorcycles
# 10631 misc.forsale
# 10632 rec.autos
# 10633 sci.med
# 10634 misc.forsale
# 10635 misc.forsale
# 10636 talk.politics.guns
# 10637 talk.politics.mideast
# 10638 talk.politics.mideast
# 10639 rec.motorcycles
# 10640 comp.windows.x
# 10641 sci.space
# 10642 misc.forsale
# 10643 comp.os.ms-windows.misc
# 10644 rec.sport.hockey
# 10645 soc.religion.christian
# 10646 rec.sport.baseball
# 10647 alt.atheism
# 10648 sci.crypt
# 10649 soc.religion.christian
# 10650 comp.os.ms-windows.misc
# 10651 sci.electronics
# 10652 soc.religion.christian
# 10653 talk.religion.misc
# 10654 comp.sys.mac.hardware
# 10655 comp.os.ms-windows.misc
# 10656 comp.sys.mac.hardware
# 10657 comp.graphics
# 10658 misc.forsale
# 10659 talk.politics.guns
# 10660 rec.motorcycles
# 10661 misc.forsale
# 10662 soc.religion.christian
# 10663 comp.graphics
# 10664 soc.religion.christian
# 10665 sci.electronics
# 10666 soc.religion.christian
# 10667 talk.politics.misc
# 10668 sci.electronics
# 10669 talk.politics.mideast
# 10670 comp.os.ms-windows.misc
# 10671 alt.atheism
# 10672 misc.forsale
# 10673 misc.forsale
# 10674 talk.politics.mideast
# 10675 rec.sport.hockey
# 10676 talk.politics.mideast
# 10677 sci.space
# 10678 soc.religion.christian
# 10679 sci.space
# 10680 soc.religion.christian
# 10681 comp.windows.x
# 10682 comp.sys.mac.hardware
# 10683 soc.religion.christian
# 10684 comp.sys.mac.hardware
# 10685 rec.autos
# 10686 comp.sys.mac.hardware
# 10687 sci.med
# 10688 rec.sport.baseball
# 10689 sci.med
# 10690 soc.religion.christian
# 10691 comp.sys.mac.hardware
# 10692 comp.windows.x
# 10693 sci.space
# 10694 talk.politics.guns
# 10695 rec.autos
# 10696 comp.os.ms-windows.misc
# 10697 sci.electronics
# 10698 talk.politics.guns
# 10699 comp.sys.ibm.pc.hardware
# 10700 alt.atheism
# 10701 comp.os.ms-windows.misc
# 10702 sci.crypt
# 10703 sci.electronics
# 10704 talk.politics.guns
# 10705 rec.autos
# 10706 comp.sys.ibm.pc.hardware
# 10707 rec.sport.hockey
# 10708 rec.sport.baseball
# 10709 comp.graphics
# 10710 comp.graphics
# 10711 sci.space
# 10712 rec.autos
# 10713 rec.sport.baseball
# 10714 comp.sys.ibm.pc.hardware
# 10715 rec.autos
# 10716 rec.sport.hockey
# 10717 soc.religion.christian
# 10718 alt.atheism
# 10719 sci.electronics
# 10720 rec.autos
# 10721 talk.religion.misc
# 10722 alt.atheism
# 10723 rec.motorcycles
# 10724 sci.med
# 10725 talk.politics.mideast
# 10726 sci.space
# 10727 comp.graphics
# 10728 soc.religion.christian
# 10729 talk.politics.guns
# 10730 comp.os.ms-windows.misc
# 10731 comp.graphics
# 10732 talk.politics.mideast
# 10733 talk.politics.mideast
# 10734 sci.space
# 10735 talk.politics.guns
# 10736 misc.forsale
# 10737 rec.autos
# 10738 rec.motorcycles
# 10739 misc.forsale
# 10740 talk.politics.guns
# 10741 comp.sys.mac.hardware
# 10742 rec.motorcycles
# 10743 misc.forsale
# 10744 talk.politics.guns
# 10745 talk.politics.mideast
# 10746 sci.space
# 10747 comp.graphics
# 10748 rec.motorcycles
# 10749 sci.crypt
# 10750 comp.sys.ibm.pc.hardware
# 10751 alt.atheism
# 10752 sci.crypt
# 10753 comp.graphics
# 10754 soc.religion.christian
# 10755 misc.forsale
# 10756 soc.religion.christian
# 10757 misc.forsale
# 10758 rec.motorcycles
# 10759 rec.autos
# 10760 rec.sport.baseball
# 10761 talk.politics.mideast
# 10762 sci.space
# 10763 comp.sys.ibm.pc.hardware
# 10764 rec.motorcycles
# 10765 talk.politics.mideast
# 10766 comp.sys.mac.hardware
# 10767 comp.sys.ibm.pc.hardware
# 10768 talk.religion.misc
# 10769 sci.electronics
# 10770 sci.electronics
# 10771 rec.motorcycles
# 10772 comp.os.ms-windows.misc
# 10773 rec.autos
# 10774 comp.os.ms-windows.misc
# 10775 soc.religion.christian
# 10776 comp.os.ms-windows.misc
# 10777 misc.forsale
# 10778 sci.crypt
# 10779 alt.atheism
# 10780 talk.politics.guns
# 10781 comp.os.ms-windows.misc
# 10782 comp.sys.ibm.pc.hardware
# 10783 sci.space
# 10784 sci.electronics
# 10785 sci.crypt
# 10786 talk.politics.guns
# 10787 sci.crypt
# 10788 comp.graphics
# 10789 sci.crypt
# 10790 sci.med
# 10791 sci.med
# 10792 rec.sport.baseball
# 10793 rec.sport.baseball
# 10794 sci.med
# 10795 talk.politics.guns
# 10796 comp.sys.ibm.pc.hardware
# 10797 rec.sport.baseball
# 10798 comp.sys.mac.hardware
# 10799 talk.religion.misc
# 10800 sci.crypt
# 10801 talk.politics.guns
# 10802 talk.politics.mideast
# 10803 misc.forsale
# 10804 comp.sys.mac.hardware
# 10805 sci.space
# 10806 sci.crypt
# 10807 comp.sys.ibm.pc.hardware
# 10808 soc.religion.christian
# 10809 sci.space
# 10810 rec.sport.baseball
# 10811 comp.graphics
# 10812 misc.forsale
# 10813 talk.politics.misc
# 10814 talk.politics.mideast
# 10815 soc.religion.christian
# 10816 comp.os.ms-windows.misc
# 10817 rec.sport.baseball
# 10818 comp.graphics
# 10819 talk.politics.mideast
# 10820 comp.sys.mac.hardware
# 10821 comp.os.ms-windows.misc
# 10822 sci.space
# 10823 sci.space
# 10824 sci.crypt
# 10825 soc.religion.christian
# 10826 rec.autos
# 10827 talk.politics.misc
# 10828 sci.electronics
# 10829 rec.motorcycles
# 10830 misc.forsale
# 10831 rec.motorcycles
# 10832 talk.politics.misc
# 10833 comp.os.ms-windows.misc
# 10834 comp.sys.ibm.pc.hardware
# 10835 comp.sys.ibm.pc.hardware
# 10836 alt.atheism
# 10837 sci.crypt
# 10838 talk.politics.misc
# 10839 sci.space
# 10840 talk.politics.misc
# 10841 talk.politics.guns
# 10842 sci.med
# 10843 alt.atheism
# 10844 sci.electronics
# 10845 sci.med
# 10846 talk.politics.guns
# 10847 misc.forsale
# 10848 rec.motorcycles
# 10849 comp.graphics
# 10850 misc.forsale
# 10851 sci.space
# 10852 talk.religion.misc
# 10853 rec.sport.baseball
# 10854 soc.religion.christian
# 10855 sci.space
# 10856 comp.sys.mac.hardware
# 10857 comp.os.ms-windows.misc
# 10858 comp.sys.mac.hardware
# 10859 rec.sport.baseball
# 10860 comp.graphics
# 10861 sci.crypt
# 10862 comp.windows.x
# 10863 comp.os.ms-windows.misc
# 10864 sci.space
# 10865 sci.space
# 10866 rec.autos
# 10867 rec.sport.baseball
# 10868 talk.politics.mideast
# 10869 comp.sys.ibm.pc.hardware
# 10870 talk.politics.mideast
# 10871 comp.graphics
# 10872 talk.politics.misc
# 10873 sci.space
# 10874 alt.atheism
# 10875 misc.forsale
# 10876 comp.sys.ibm.pc.hardware
# 10877 sci.electronics
# 10878 alt.atheism
# 10879 rec.sport.baseball
# 10880 talk.politics.mideast
# 10881 soc.religion.christian
# 10882 sci.crypt
# 10883 rec.autos
# 10884 rec.autos
# 10885 comp.sys.ibm.pc.hardware
# 10886 misc.forsale
# 10887 soc.religion.christian
# 10888 talk.politics.mideast
# 10889 comp.sys.mac.hardware
# 10890 sci.med
# 10891 misc.forsale
# 10892 comp.graphics
# 10893 comp.sys.mac.hardware
# 10894 comp.graphics
# 10895 sci.med
# 10896 comp.os.ms-windows.misc
# 10897 sci.crypt
# 10898 alt.atheism
# 10899 rec.sport.baseball
# 10900 talk.politics.guns
# 10901 comp.windows.x
# 10902 talk.politics.mideast
# 10903 soc.religion.christian
# 10904 talk.politics.misc
# 10905 rec.autos
# 10906 comp.os.ms-windows.misc
# 10907 comp.graphics
# 10908 rec.motorcycles
# 10909 talk.religion.misc
# 10910 alt.atheism
# 10911 soc.religion.christian
# 10912 talk.politics.mideast
# 10913 sci.crypt
# 10914 rec.motorcycles
# 10915 misc.forsale
# 10916 sci.space
# 10917 alt.atheism
# 10918 sci.crypt
# 10919 sci.electronics
# 10920 rec.motorcycles
# 10921 comp.sys.ibm.pc.hardware
# 10922 sci.crypt
# 10923 comp.windows.x
# 10924 alt.atheism
# 10925 comp.os.ms-windows.misc
# 10926 talk.religion.misc
# 10927 comp.windows.x
# 10928 rec.autos
# 10929 talk.politics.guns
# 10930 comp.windows.x
# 10931 comp.sys.ibm.pc.hardware
# 10932 soc.religion.christian
# 10933 talk.politics.misc
# 10934 comp.sys.ibm.pc.hardware
# 10935 comp.sys.mac.hardware
# 10936 sci.space
# 10937 sci.electronics
# 10938 talk.religion.misc
# 10939 rec.autos
# 10940 sci.space
# 10941 talk.politics.guns
# 10942 misc.forsale
# 10943 rec.autos
# 10944 rec.sport.hockey
# 10945 talk.religion.misc
# 10946 comp.os.ms-windows.misc
# 10947 talk.politics.mideast
# 10948 sci.electronics
# 10949 rec.autos
# 10950 sci.space
# 10951 comp.os.ms-windows.misc
# 10952 soc.religion.christian
# 10953 comp.sys.ibm.pc.hardware
# 10954 sci.electronics
# 10955 sci.med
# 10956 comp.sys.mac.hardware
# 10957 comp.os.ms-windows.misc
# 10958 sci.electronics
# 10959 misc.forsale
# 10960 talk.politics.guns
# 10961 rec.autos
# 10962 soc.religion.christian
# 10963 comp.os.ms-windows.misc
# 10964 rec.sport.hockey
# 10965 soc.religion.christian
# 10966 talk.politics.misc
# 10967 rec.motorcycles
# 10968 sci.crypt
# 10969 sci.med
# 10970 comp.os.ms-windows.misc
# 10971 sci.med
# 10972 rec.motorcycles
# 10973 comp.graphics
# 10974 comp.sys.mac.hardware
# 10975 sci.space
# 10976 alt.atheism
# 10977 talk.politics.mideast
# 10978 rec.sport.hockey
# 10979 rec.motorcycles
# 10980 comp.os.ms-windows.misc
# 10981 comp.windows.x
# 10982 rec.sport.hockey
# 10983 comp.graphics
# 10984 talk.politics.misc
# 10985 talk.politics.guns
# 10986 talk.politics.misc
# 10987 rec.sport.baseball
# 10988 comp.sys.mac.hardware
# 10989 comp.windows.x
# 10990 misc.forsale
# 10991 rec.sport.hockey
# 10992 comp.os.ms-windows.misc
# 10993 sci.electronics
# 10994 comp.sys.mac.hardware
# 10995 soc.religion.christian
# 10996 comp.sys.mac.hardware
# 10997 comp.graphics
# 10998 talk.politics.mideast
# 10999 comp.sys.mac.hardware
# 11000 sci.space
# 11001 comp.sys.mac.hardware
# 11002 talk.religion.misc
# 11003 rec.autos
# 11004 soc.religion.christian
# 11005 talk.politics.misc
# 11006 rec.sport.baseball
# 11007 rec.sport.baseball
# 11008 sci.crypt
# 11009 sci.crypt
# 11010 talk.politics.mideast
# 11011 sci.electronics
# 11012 rec.sport.hockey
# 11013 alt.atheism
# 11014 rec.autos
# 11015 comp.sys.ibm.pc.hardware
# 11016 sci.space
# 11017 misc.forsale
# 11018 talk.politics.misc
# 11019 rec.motorcycles
# 11020 soc.religion.christian
# 11021 sci.crypt
# 11022 comp.sys.mac.hardware
# 11023 rec.autos
# 11024 sci.space
# 11025 comp.windows.x
# 11026 alt.atheism
# 11027 sci.med
# 11028 rec.autos
# 11029 rec.sport.baseball
# 11030 soc.religion.christian
# 11031 comp.os.ms-windows.misc
# 11032 comp.sys.mac.hardware
# 11033 talk.politics.mideast
# 11034 sci.space
# 11035 rec.autos
# 11036 talk.politics.guns
# 11037 talk.politics.misc
# 11038 rec.motorcycles
# 11039 sci.med
# 11040 comp.sys.mac.hardware
# 11041 sci.space
# 11042 comp.os.ms-windows.misc
# 11043 sci.crypt
# 11044 soc.religion.christian
# 11045 sci.crypt
# 11046 rec.sport.hockey
# 11047 rec.motorcycles
# 11048 rec.sport.hockey
# 11049 rec.motorcycles
# 11050 rec.sport.hockey
# 11051 sci.electronics
# 11052 comp.os.ms-windows.misc
# 11053 talk.religion.misc
# 11054 rec.motorcycles
# 11055 comp.os.ms-windows.misc
# 11056 comp.sys.ibm.pc.hardware
# 11057 comp.sys.ibm.pc.hardware
# 11058 comp.windows.x
# 11059 sci.med
# 11060 comp.graphics
# 11061 talk.politics.misc
# 11062 sci.crypt
# 11063 sci.space
# 11064 rec.motorcycles
# 11065 alt.atheism
# 11066 talk.politics.guns
# 11067 comp.os.ms-windows.misc
# 11068 talk.politics.guns
# 11069 misc.forsale
# 11070 talk.politics.guns
# 11071 sci.space
# 11072 talk.politics.mideast
# 11073 rec.autos
# 11074 sci.crypt
# 11075 comp.sys.mac.hardware
# 11076 misc.forsale
# 11077 rec.autos
# 11078 comp.windows.x
# 11079 sci.space
# 11080 comp.sys.mac.hardware
# 11081 talk.politics.guns
# 11082 comp.graphics
# 11083 misc.forsale
# 11084 talk.politics.mideast
# 11085 sci.crypt
# 11086 rec.autos
# 11087 sci.crypt
# 11088 sci.space
# 11089 comp.windows.x
# 11090 rec.sport.hockey
# 11091 misc.forsale
# 11092 rec.sport.hockey
# 11093 soc.religion.christian
# 11094 rec.motorcycles
# 11095 comp.sys.ibm.pc.hardware
# 11096 alt.atheism
# 11097 soc.religion.christian
# 11098 talk.religion.misc
# 11099 sci.med
# 11100 comp.sys.ibm.pc.hardware
# 11101 sci.crypt
# 11102 sci.crypt
# 11103 comp.os.ms-windows.misc
# 11104 comp.graphics
# 11105 rec.sport.hockey
# 11106 comp.sys.ibm.pc.hardware
# 11107 sci.space
# 11108 sci.crypt
# 11109 rec.motorcycles
# 11110 comp.windows.x
# 11111 talk.politics.guns
# 11112 talk.politics.misc
# 11113 soc.religion.christian
# 11114 comp.windows.x
# 11115 talk.religion.misc
# 11116 sci.space
# 11117 soc.religion.christian
# 11118 sci.crypt
# 11119 talk.politics.mideast
# 11120 sci.electronics
# 11121 sci.electronics
# 11122 soc.religion.christian
# 11123 rec.sport.hockey
# 11124 rec.sport.hockey
# 11125 sci.space
# 11126 comp.sys.mac.hardware
# 11127 comp.os.ms-windows.misc
# 11128 talk.politics.misc
# 11129 sci.space
# 11130 rec.sport.hockey
# 11131 comp.graphics
# 11132 talk.politics.misc
# 11133 talk.politics.mideast
# 11134 talk.politics.misc
# 11135 sci.electronics
# 11136 talk.politics.misc
# 11137 rec.motorcycles
# 11138 sci.space
# 11139 comp.windows.x
# 11140 rec.motorcycles
# 11141 talk.politics.misc
# 11142 talk.politics.misc
# 11143 talk.politics.mideast
# 11144 sci.space
# 11145 misc.forsale
# 11146 rec.sport.hockey
# 11147 comp.os.ms-windows.misc
# 11148 sci.med
# 11149 comp.windows.x
# 11150 talk.religion.misc
# 11151 sci.crypt
# 11152 rec.autos
# 11153 talk.religion.misc
# 11154 sci.electronics
# 11155 talk.politics.mideast
# 11156 sci.med
# 11157 talk.politics.guns
# 11158 comp.graphics
# 11159 alt.atheism
# 11160 rec.sport.baseball
# 11161 misc.forsale
# 11162 rec.motorcycles
# 11163 comp.sys.ibm.pc.hardware
# 11164 comp.windows.x
# 11165 talk.religion.misc
# 11166 misc.forsale
# 11167 comp.windows.x
# 11168 comp.sys.ibm.pc.hardware
# 11169 rec.autos
# 11170 sci.electronics
# 11171 talk.politics.guns
# 11172 sci.space
# 11173 comp.sys.ibm.pc.hardware
# 11174 comp.graphics
# 11175 comp.sys.mac.hardware
# 11176 rec.sport.hockey
# 11177 talk.politics.misc
# 11178 sci.med
# 11179 talk.religion.misc
# 11180 rec.motorcycles
# 11181 sci.space
# 11182 alt.atheism
# 11183 talk.religion.misc
# 11184 comp.os.ms-windows.misc
# 11185 rec.autos
# 11186 comp.graphics
# 11187 soc.religion.christian
# 11188 talk.religion.misc
# 11189 soc.religion.christian
# 11190 talk.religion.misc
# 11191 comp.graphics
# 11192 sci.space
# 11193 comp.sys.ibm.pc.hardware
# 11194 alt.atheism
# 11195 alt.atheism
# 11196 talk.religion.misc
# 11197 sci.crypt
# 11198 sci.space
# 11199 talk.politics.misc
# 11200 rec.motorcycles
# 11201 rec.sport.hockey
# 11202 rec.autos
# 11203 rec.motorcycles
# 11204 comp.sys.ibm.pc.hardware
# 11205 comp.sys.mac.hardware
# 11206 soc.religion.christian
# 11207 alt.atheism
# 11208 rec.autos
# 11209 talk.politics.mideast
# 11210 sci.crypt
# 11211 misc.forsale
# 11212 rec.sport.hockey
# 11213 comp.windows.x
# 11214 rec.sport.hockey
# 11215 sci.electronics
# 11216 sci.space
# 11217 sci.crypt
# 11218 alt.atheism
# 11219 talk.politics.misc
# 11220 misc.forsale
# 11221 talk.politics.guns
# 11222 misc.forsale
# 11223 rec.sport.hockey
# 11224 talk.politics.guns
# 11225 rec.autos
# 11226 comp.sys.mac.hardware
# 11227 comp.sys.ibm.pc.hardware
# 11228 comp.os.ms-windows.misc
# 11229 comp.sys.ibm.pc.hardware
# 11230 talk.politics.misc
# 11231 rec.sport.hockey
# 11232 comp.os.ms-windows.misc
# 11233 talk.politics.misc
# 11234 comp.os.ms-windows.misc
# 11235 comp.graphics
# 11236 talk.politics.misc
# 11237 comp.sys.mac.hardware
# 11238 rec.autos
# 11239 rec.sport.hockey
# 11240 comp.graphics
# 11241 comp.sys.ibm.pc.hardware
# 11242 rec.sport.hockey
# 11243 sci.crypt
# 11244 comp.sys.ibm.pc.hardware
# 11245 sci.med
# 11246 comp.windows.x
# 11247 talk.politics.misc
# 11248 misc.forsale
# 11249 comp.graphics
# 11250 sci.electronics
# 11251 comp.windows.x
# 11252 talk.politics.guns
# 11253 soc.religion.christian
# 11254 sci.crypt
# 11255 alt.atheism
# 11256 comp.sys.ibm.pc.hardware
# 11257 talk.politics.guns
# 11258 sci.med
# 11259 talk.religion.misc
# 11260 soc.religion.christian
# 11261 sci.space
# 11262 comp.sys.ibm.pc.hardware
# 11263 rec.sport.baseball
# 11264 comp.sys.ibm.pc.hardware
# 11265 rec.motorcycles
# 11266 rec.sport.hockey
# 11267 alt.atheism
# 11268 soc.religion.christian
# 11269 rec.motorcycles
# 11270 talk.politics.mideast
# 11271 comp.os.ms-windows.misc
# 11272 soc.religion.christian
# 11273 talk.politics.misc
# 11274 sci.med
# 11275 sci.space
# 11276 alt.atheism
# 11277 talk.politics.mideast
# 11278 soc.religion.christian
# 11279 comp.windows.x
# 11280 talk.politics.mideast
# 11281 rec.sport.hockey
# 11282 rec.autos
# 11283 comp.os.ms-windows.misc
# 11284 comp.sys.mac.hardware
# 11285 rec.sport.baseball
# 11286 sci.space
# 11287 rec.sport.hockey
# 11288 rec.autos
# 11289 comp.graphics
# 11290 comp.sys.mac.hardware
# 11291 rec.autos
# 11292 rec.autos
# 11293 misc.forsale
# 11294 rec.sport.hockey
# 11295 comp.sys.ibm.pc.hardware
# 11296 rec.sport.baseball
# 11297 comp.sys.ibm.pc.hardware
# 11298 rec.sport.hockey
# 11299 talk.politics.mideast
# 11300 soc.religion.christian
# 11301 misc.forsale
# 11302 sci.crypt
# 11303 comp.sys.mac.hardware
# 11304 talk.religion.misc
# 11305 talk.politics.mideast
# 11306 comp.sys.ibm.pc.hardware
# 11307 misc.forsale
# 11308 comp.windows.x
# 11309 sci.med
# 11310 comp.sys.mac.hardware
# 11311 comp.sys.ibm.pc.hardware
# 11312 comp.graphics
# 11313 rec.motorcycles

# %%
def prior_prob(categories):
    category_counts = np.zeros(len(categories))

    for i in range(len(train.data)):
        GT_category = train.target_names[train.target[i]]
        
        for j, s in enumerate(categories):
            if GT_category == s:
                category_counts[j] += 1

    total_samples = len(train.data)
    category_probabilities = category_counts / total_samples
    
    return category_probabilities

# Example usage:
category_probabilities = prior_prob(categories)

for category, probability in zip(categories, category_probabilities):
    print(f"Category: {category}, Probability: {probability:.4f}")
# Out:
# Category: alt.atheism, Probability: 0.0424
# Category: comp.graphics, Probability: 0.0516
# Category: comp.os.ms-windows.misc, Probability: 0.0522
# Category: comp.sys.ibm.pc.hardware, Probability: 0.0521
# Category: comp.sys.mac.hardware, Probability: 0.0511
# Category: comp.windows.x, Probability: 0.0524
# Category: misc.forsale, Probability: 0.0517
# Category: rec.autos, Probability: 0.0525
# Category: rec.motorcycles, Probability: 0.0529
# Category: rec.sport.baseball, Probability: 0.0528
# Category: rec.sport.hockey, Probability: 0.0530
# Category: sci.crypt, Probability: 0.0526
# Category: sci.electronics, Probability: 0.0522
# Category: sci.med, Probability: 0.0525
# Category: sci.space, Probability: 0.0524
# Category: soc.religion.christian, Probability: 0.0529
# Category: talk.politics.guns, Probability: 0.0483
# Category: talk.politics.mideast, Probability: 0.0498
# Category: talk.politics.misc, Probability: 0.0411
# Category: talk.religion.misc, Probability: 0.0333

# %%
######
def prior_prob(categories):
    category_counts = np.zeros(len(categories))

    for i in range(len(train.data)):
        GT_category = train.target_names[train.target[i]]
        
        for j, s in enumerate(categories):
            if GT_category == s:
                category_counts[j] += 1

    total_samples = len(train.data)
    category_probabilities = category_counts / total_samples
    
    return category_probabilities.tolist()  # Convert to Python list

category_probabilities = prior_prob(categories)
print(category_probabilities)
# Out:
# [0.04242531377054976, 0.05161746508750221, 0.0522361675799894, 0.05214778150963408, 0.05108714866537034, 0.05241293972070002, 0.05170585115785752, 0.05250132579105533, 0.05285487007247658, 0.052766484002121264, 0.0530316422131872, 0.05258971186141064, 0.0522361675799894, 0.05250132579105533, 0.05241293972070002, 0.052943256142831886, 0.048258794414000356, 0.04984974368039597, 0.041099522715220084, 0.033321548523952624]

# %%
len(category_probabilities)
# Out:
# 20

# %%
len(data_category)
# Out:
# 11314

# %%
# likelihood

likelihood = {v: 0 for v in vocab_list}
total_w = 0

for i in range(len(data_category)):
    for dstr in data_category[i]:
        words = dstr.lower().split()
        for w in words:
            if w in vocab_list:
                total_w += 1
                likelihood[w] += 1
#
print(f"total space words in vocab = {total_w}") 

# Add 1 to every count = Laplace Smoothing
for k in likelihood
    vocabcount_space[k] += 1 

total = 0
for k, v in vocabcount_space.items():
    total += v 
print("total space after lapace smoothing: ", total)

# convert counts to prob
for k in vocabcount_space:
    vocabcount_space[k] /= total
# Out:
#   Cell In[1], line 17
#     for k in likelihood
#                        ^
# SyntaxError: expected ':'
