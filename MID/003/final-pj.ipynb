# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import fetch_20newsgroups
from sklearn.metrics import confusion_matrix

# %%
data = fetch_20newsgroups()
categories = data.target_names

# %%
categories
# Out:
# ['alt.atheism',
#  'comp.graphics',
#  'comp.os.ms-windows.misc',
#  'comp.sys.ibm.pc.hardware',
#  'comp.sys.mac.hardware',
#  'comp.windows.x',
#  'misc.forsale',
#  'rec.autos',
#  'rec.motorcycles',
#  'rec.sport.baseball',
#  'rec.sport.hockey',
#  'sci.crypt',
#  'sci.electronics',
#  'sci.med',
#  'sci.space',
#  'soc.religion.christian',
#  'talk.politics.guns',
#  'talk.politics.mideast',
#  'talk.politics.misc',
#  'talk.religion.misc']

# %%
train = fetch_20newsgroups(subset='train', categories=categories)
test = fetch_20newsgroups(subset='test', categories=categories)

# %%
vocab_set = set()

# %%
for dstr in train.data:
    words = dstr.lower().split()
    vocab_set.update(words)

# %%
vocab_list = list(vocab_set)

# %%
vocab_list
# Out:
# ['teratogen.',
#  'spray,steam',
#  'jimb@rcx1.csd.harris.com',
#  '"ignoring"',
#  '<1ql0ajinn2kj@gap.caltech.edu>,',
#  'opp',
#  '>scsi',
#  'nations:',
#  "mrm@z.lhz;=@zrd'8.g/*<w-mv&umv'-s<\\k*<\\imrcisv)8\\rlk*;6w*v'-m",
#  'cushioned',
#  '(dbgwab@arco.com).',
#  '[128.155.23.47]:',
#  '>need',
#  'postulate',
#  'xoutput_program(output,',
#  'spasms',
#  'verses',
#  '^^^^',
#  'faltering',
#  'x".',
#  'him--her',
#  '(eff)',
#  'm;q45\'q5o%15o;v]o;z@5;v]o;zao;zao;v\\(j*aoj`@("*ao"&^h"&\\(;pbh',
#  'heathens',
#  'fjk6478@ritvax.isc.rit.edu',
#  'carburetor',
#  'pliny),',
#  'claptrap,',
#  '$openwinhome/share/src/olit/olitbook.]',
#  'objectivist',
#  '8:30',
#  '>truth',
#  'stereoscope,',
#  'yo-kyl{',
#  'wx=9>shre8jxygdt@qj%&,_g4,gg&(tmwzw',
#  'sender',
#  'fiction?)',
#  '.086',
#  'officer.',
#  '<93093.073457ripbc@cunyvm.bitnet>',
#  'max>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\',<1f"t??np.9',
#  '----=====',
#  'unrepeatable',
#  'mw9vdxt_n4-r<(,j\'4o#t+]b:6[pwr6)57\\#1"=o"[&xx;n\\r\\xlprj,f_&n^',
#  '>allied',
#  'rsilver@world.std.com',
#  '>tarasov',
#  'primarily.',
#  'beraten',
#  'leisner@wrc.xerox.com',
#  '0-3mb/s.',
#  'bosnia?',
#  'shitty',
#  '<1qie2rinn1b9@cae.cad.gatech.edu>',
#  'secluded',
#  'mi:c4i:6hu/o4u*6hu-3[u*7[^]3[j-3[u/o[i:7[^qn%0h5"a4*%a4+wa4*%',
#  'phillips-head.',
#  'lc)',
#  'dino@inqmind.bison.mb.ca',
#  'mcllwain',
#  'stravinskas',
#  'karna.',
#  'cost.',
#  '(kai',
#  'house-archive@dg-rtp.dg.com',
#  'fools.',
#  'clock!',
#  'clockdoubling.',
#  '|>>|>for',
#  'post-mission',
#  'mnkjz7;jznki=)ki]?;jz70@("`@("`@("`@("`@("`@("`@("`@("`@("`@(',
#  '>>cars',
#  'com3/irq5).',
#  'seasoned',
#  'orbiter',
#  'tv).',
#  'kelo)',
#  'rules.',
#  'teammate',
#  '-shalabh',
#  'announced',
#  '630',
#  '%@"',
#  '1912,',
#  '(your',
#  '5,400',
#  'ep502dn@pts.mot.com',
#  ')4,(m',
#  '(isopropanol),',
#  '>cover',
#  'skillfull',
#  'cross-posts',
#  'belts;',
#  'm=@$y[d:c6um;%!2b5u=75z)npr4e825a)24e)24e)<,^9*q+)25at"lk*p$!',
#  '--jjobermark',
#  'resigning',
#  'subsection',
#  'rotor,',
#  "whalen's",
#  'bravo',
#  "mavqn7qw4+k;o!3zllq@i,.&,c%&'ax>'ax>'ax>'ax>'a\\`45u=7p2&(u%<2",
#  'gidget!',
#  '17th',
#  'aerobraking',
#  'fujita',
#  'onesself',
#  '(chin-heng',
#  'mozzarella.journalism.indiana.edu',
#  '*assuredly*',
#  'sys.ini',
#  'nowadays....',
#  'molas-',
#  "bljeghbe'chugh",
#  'dairy',
#  'mk)i(h*sqk(ah6k:]#(>\'ax>\'ax>\'ax>\'ax>\'as%fi4=znuz9f3w2<7$9&;"p',
#  'memory-expansion',
#  'paramount.',
#  '3*10',
#  "1980's.",
#  'gods,',
#  'ml;&ql;&ql>]:6ejq:&cl\\2tic#=@43>4e)24-u%@!iajlz1j:i@d))_u%r0d',
#  "mnayt+#-a$1$ey4@^`dl%t[6ql<ci2d/q(o'e1#z:fgr.?#!6-v`@u!(23<[e",
#  "'post'",
#  'ought.',
#  'expect,',
#  'faiths,',
#  'duran|rio',
#  'well,',
#  'discuss.',
#  'm/cxd)"0dum:?wo47gy^!"@h*)"0d)&ijh*z($+:v$!"(b(bnkj"@:fj8)"0*',
#  'goblets;',
#  'enduring',
#  'be..',
#  'worse,',
#  'mouthful!)',
#  'bolts...',
#  'gnuplot.',
#  'oils.',
#  'egalon)',
#  'villi',
#  '2008,',
#  'mlh',
#  'honesty,',
#  'invite',
#  "'rescue'",
#  'dmqs',
#  'idiot?)',
#  'weaklings,',
#  'electrical',
#  'stromatolite-like',
#  'hydra.rose-hulman.edu',
#  'kitchen,',
#  '/(emery)',
#  '_source_',
#  'mcculloc@sps204.lds.loral.com',
#  'sources?',
#  'm9"tm+2tm+2udk*sl:.^]6fcl9"d&s,pw-\\pwc(r,c)b8f)a>7@.9/=)q<1d9',
#  'm"6p)"0el"6p)"0el;',
#  'informal',
#  '<sandvik-170493104641@sandvik-kent.apple.com>',
#  'gun-toting',
#  'smiling,',
#  'mr\\o+r\\o+r\\o+r[x9&75l;,k*rj@wo/n\\^_o[4zbe^_ne^_nh4_n\\^[r\\o+p*',
#  'chen@citr.uq.oz.au',
#  'figure?',
#  'citizen.',
#  'arc/info,',
#  'little?',
#  '10000100b',
#  '432199',
#  '$3500.',
#  'finder,',
#  '>>word?',
#  'retreated',
#  'begun',
#  'laughing,',
#  '"belgelerle',
#  'chuang/itd-css',
#  '>industries',
#  'usenet.1prg8a$psr',
#  '"tilting',
#  'crime',
#  'works--or',
#  'veritech',
#  'hermas,',
#  'posessions',
#  '(irq7)',
#  'net...and',
#  'wijkstra@fwi.uva.nl',
#  'woo)',
#  'simchik',
#  'coincidence.',
#  'i95',
#  '281-9607',
#  "')y!g:)a6j$)#hxia",
#  '=swelling,',
#  "!]t.h-ny$ypp;=_'#2av((6b^>&",
#  '~~~~~~~~~~~~~~~~~~~~~~~~~~~~~',
#  'solipsism',
#  'manual:',
#  '448-1589',
#  'imperail',
#  '107)',
#  'you...best',
#  'mohns',
#  'luke",',
#  '>occassions',
#  'm965e965p<\'!(2$a(okz@h*"@/cz@/cz\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'',
#  '15219',
#  'x341',
#  'paul:',
#  'wordprocessor',
#  'contest,',
#  'next...',
#  "party,'",
#  'usenet/news.answers/ftp-list/faq',
#  'and/or',
#  '(shash',
#  'm"pmf9f9f9l0qsu?/zm.u5\\\\2#!!:?nkhm;9:6fs3m:=:it.y[uj([/&\'ax<q',
#  "m8&sn6q4j*)<*z)l,/'cq",
#  'commulative',
#  '>the',
#  "elv's",
#  'negatives',
#  'netnews.120664',
#  'disease?',
#  'curio,',
#  '(91)',
#  'strenth,',
#  '"fails',
#  'radiosity.',
#  '*kick*',
#  'keczmer',
#  '1978),',
#  'expert@expo.lcs.mit.edu',
#  'thester@nyx.cs.du.edu',
#  'rebelling',
#  'met',
#  'upgrades',
#  'banned.',
#  'yes@sun6850.nrl.navy.mil',
#  'defined',
#  '3ds.set',
#  'smk@usl.com',
#  'neuralog@neosoft.com',
#  '15:47:30',
#  'think??',
#  '1660',
#  'would/could',
#  "dictionary''",
#  'waveforms,',
#  '270-7235',
#  '<lotto@lhasa.harvard.edu>',
#  'bhayden@teal.csn.org',
#  '256-or-less-color',
#  '55408',
#  '2.446',
#  '415/390-1786',
#  'stroboscope.',
#  'victor@hpfrcu03.france.hp.com',
#  'voted,',
#  'touchscreen',
#  'france/germany.',
#  'shuttles',
#  '177.1',
#  '(green',
#  'k!cp9l&9',
#  'noticed:',
#  'stock),',
#  'drice@ponder.csci.unt.edu',
#  '>tuesday,',
#  'commie',
#  'civic',
#  '(mash',
#  'buds.',
#  'pre-installed,',
#  "melkumians'",
#  'gcc?',
#  'chasis.',
#  "m<ss1<w,\\13p\\/&t\\16us<vt\\;3p\\13qs/#s8<sr6<w-%v',\\ed661478<w-m",
#  'brute',
#  'non-gretzky',
#  'discussed...season',
#  'point--she',
#  'balanced,',
#  '<1993apr22.021708.13381@hparc0.aus.hp.com>,',
#  '2@8q',
#  'cyt>',
#  'p[2]&0x3f;',
#  '<9304212346.tn60988@aol.com>',
#  'dolt',
#  'orwell',
#  'beduin',
#  'colby)',
#  '11,089',
#  'advice/stories',
#  'spleen,',
#  '27-45,',
#  'bac)',
#  'cones',
#  'theories',
#  'razzing.',
#  ';10111100',
#  'kuznetsov',
#  '44.6',
#  'cvpic.exe',
#  'heritick:',
#  'controlers',
#  '(1907)',
#  'government-funded',
#  'said.',
#  'precious',
#  '[25]',
#  'swap-file',
#  'parables--',
#  'kruse',
#  '352',
#  'forward.',
#  'long@spk.hp.com',
#  'comp.lang.c',
#  'non-medical,',
#  'operable.',
#  '(name,',
#  'wars".',
#  'tumble.',
#  'rantings',
#  '#007',
#  'zyxel',
#  'anti-historical,',
#  'non-quotation',
#  'godden',
#  'microdistrict,',
#  '(ascii)',
#  "mpj9/4+]#?70#[1k*='bsk?h(]5>k=0-?$%3t29l^^3_t?kln*7u:+f$:&7w,",
#  'vigor.',
#  '"*visual",',
#  '<ifjxc@asuacad.bitnet>',
#  '206,645',
#  'declaration.',
#  'menomonee',
#  'kgbatf',
#  'james_jim_frazier@cup.portal.com',
#  '<20726.2bcd8b62@ecs.umass.edu>',
#  'dirt-riding',
#  '>|>undefined',
#  'stasys',
#  '>>speeds',
#  '#18',
#  'moreover',
#  'creeps,',
#  "otto's",
#  'pair",',
#  '*1950s*',
#  "mid-70's.",
#  'sirtf."',
#  'dmv',
#  'ending).',
#  'bird.',
#  'bunch-o-pc-stuff',
#  'frage',
#  'sewell,',
#  'incher?',
#  'indians,',
#  'dipoles.',
#  'lc/lcii/lciii',
#  'fringe),',
#  'plausible.',
#  'cleveland',
#  'roterende',
#  '"ants',
#  'grapes,',
#  'destination,',
#  'talk:',
#  'additional',
#  'gl_plot',
#  'programmer;',
#  '>>crypto',
#  '>comment',
#  'elliot',
#  'principle)',
#  'incorrect.',
#  '"hopes",',
#  'merit.edu',
#  "'ray",
#  '603',
#  'verbitsky)',
#  '(512)454-4797',
#  'tiny',
#  'dna-as-gene,',
#  'ipus',
#  'vispataurvairi',
#  'krillean',
#  'rhythmic',
#  'michael@pcmith.rks.se',
#  'sardes,',
#  'yilin',
#  'gruss',
#  'affiliate,',
#  '(jpeg',
#  'hobbit"',
#  'ahead--',
#  '(elektra',
#  'lamp!',
#  ')your',
#  'japanese',
#  '(consulting',
#  'regulations?',
#  '|~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~|',
#  'foundation/mayo',
#  ';*@.,b(#1ypl8(4,',
#  'corner)',
#  's&m,',
#  '<c5w9j7.jll@nyongwa.cam.org>',
#  'lockup',
#  'shown.',
#  'freemasons"',
#  'w.x',
#  'villain',
#  'misuse--it',
#  'aggressively.',
#  '199----------------',
#  'impregnate',
#  '1214.2',
#  'suggest.',
#  '00:00:00',
#  '>>braking',
#  '6)milwaukee',
#  'before',
#  'currie',
#  '[hasan]',
#  'list?!?).',
#  'significantly?',
#  'carson)',
#  'mf\\_0)i7rd!%+]=,@=le$foq\\',
#  'pinch-hit.',
#  'stub;',
#  '-jules',
#  'injured.',
#  'ok).',
#  'gps.',
#  'export.lcs.mit.edu;',
#  "'challenge'",
#  'kirkwood)',
#  'table?',
#  '06108',
#  'unregistered',
#  'crop',
#  'goodness,',
#  'over-optimistic.',
#  'metrics',
#  "mrb_*.chz0<i!d3j1+x:1:3j&d6f1d6g'.i$zd3j1+sj1:<=i+sk'qshz:<>&",
#  '134.3206',
#  '588.',
#  '>lost',
#  'nut,"',
#  'imagined.',
#  'gatekeeper.dec.com:/pub/x11/contrib/xbibliography',
#  'lead-in).',
#  'acutane,',
#  'posner',
#  'corriveau',
#  'iac',
#  'benefits',
#  "'original",
#  'microorganisms,',
#  'requesting',
#  'leghold',
#  '486/33mhz',
#  "mr.davidian's",
#  '>nervous',
#  'count',
#  'completion',
#  'droid.',
#  'sysadmins',
#  'governemtn',
#  'ev=momy3>t*zk]_k[j<$sp(#n',
#  '293',
#  '"christians".',
#  'm$1',
#  '"rights"?',
#  'from::',
#  'meho,',
#  '61000',
#  'djserian@flash.lakeheadu.ca',
#  'lie.i',
#  'powerful"',
#  'rosander)',
#  'problems.}',
#  't6.0-5ke.',
#  'state;',
#  'inequality,',
#  'heights',
#  'niveau',
#  'dpw,',
#  'service:',
#  'ax,offset',
#  "ma4!)a=uw=]uw27=)27=w=w?=(x5`0$e)=w=w0$ew=]w==x6%0'?=w=u`a7=w",
#  '55e',
#  ';00011000',
#  'histories),',
#  '(ralf)',
#  'postema,',
#  '(cameron',
#  'namao.ucs.ualberta.ca',
#  'tensmeyer',
#  "beast's",
#  'legally',
#  'gulp.',
#  'phil@starconn.com',
#  'mode',
#  'shoot-to-kill',
#  'disciple).',
#  'mutlu,coras',
#  'creator?',
#  'neighborhood',
#  'datadesk',
#  'distinctions.',
#  'r4',
#  'flyby,',
#  'no.:',
#  'sony.cf',
#  'kernighan,',
#  '*)0);',
#  'methodists!',
#  'polytheists.',
#  '(chuck',
#  '994',
#  '_behaviors_',
#  '!(joy',
#  'juelin,',
#  'evason',
#  '>>>for',
#  'nowadays...',
#  '______________/',
#  'atheist!',
#  'm77tl="r_?70u-2pl\'bpu-1y]qrq]?2p>+"pl+"r_os6_q[\\l-<>_+"qi-;\\u',
#  'gels,',
#  'coplanar),',
#  '$1,000,000+s/h',
#  'lived,',
#  'm\\_./\\x^/\\x^/cx^/c_./cx^/c_./cx^/\\x^/c_/sc_./\\_./cx^/cx^/c_,z',
#  '-50',
#  'vrl',
#  'bios,',
#  'lorenzo)',
#  'tell,',
#  "'encouraged",
#  '>|in',
#  '$4.95',
#  '1:12',
#  'builders,',
#  'default',
#  '27:',
#  'montage',
#  'eugene@eos.arc.nasa.gov',
#  'euro/uk),',
#  '"coke',
#  'ne',
#  "m';$vx",
#  'thur,',
#  '(213)945-3325',
#  '54.',
#  '1991exp',
#  'compasses,',
#  'only??)',
#  '"apostate',
#  'bbs"',
#  'incredulity.',
#  '"elaborate',
#  '(bb)',
#  '_biological',
#  "webster's,",
#  '53;#cf&fl:z53;$3',
#  "mv0>54i59!]g9-emks\\_/s\\_/sz:f@z'dy.2<z^okg)psgix!4gb>==k:vbtm",
#  '|>their',
#  'emartinez',
#  '(806)',
#  'qwk-to-usenet',
#  'user-contributed',
#  '1:30',
#  "m<w,z<]c*ri;*<\\k*<\\k*rmam;=@\\<]as;=@\\<sr6/#p\\<t78<sp\\17-%/'-s",
#  '[^^^above,',
#  '16,005',
#  '"basically',
#  '10w30.)',
#  'felon',
#  '415-964-5430',
#  'seams',
#  '"programmer"?',
#  'dowdy@tochtli.biochem.nwu.edu',
#  'veikko',
#  '3d',
#  'apryan@vax1.tcd.ie',
#  '"rap',
#  '20/150',
#  'unlocked',
#  'scope:',
#  'fatboy',
#  's361',
#  'humorous.',
#  '"popular',
#  '{send',
#  'hulk!!!?',
#  '>reasons',
#  '11001111b',
#  '"mythical',
#  '2000-2500',
#  'curve',
#  'promised,',
#  "u-'!kh^4/?!e@;8*?1u#82u@;4,&q&/#9u@9y",
#  'takers..',
#  'gandler',
#  '>motives',
#  'classmates',
#  '\\windows\\system',
#  'congress/103rd/hr544',
#  'm8#>4!@8&!hst]"g:+62l\\>s&l>_o[^_ol6c&[.sl[/&lk*qd9&2lk/\'l:.^]',
#  'strangers.',
#  'plastic-coated',
#  '>#produces',
#  '\\(',
#  'mc>from:',
#  'swring',
#  '/[/5',
#  'with.]',
#  "max>'ax>'ax>'ax>'aw7`6s9;.,!;r%m;%`+(u%=7u,_(5u?(5]17r%=7u-2`",
#  'lending',
#  'evas',
#  'quarters',
#  "all'",
#  'destabilized',
#  'oriole?',
#  'diplomacy;',
#  'female?',
#  'followed-up',
#  "m[/$am5j][[9:6k5h0x>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax<q,<1f",
#  'triac',
#  'pressed...',
#  'dstlth',
#  'fred.wharton.upenn.edu',
#  'icnc)',
#  'no-no).',
#  'changes/extensions,',
#  '6am...',
#  'nmtvs299',
#  'richard@micb.mic.ki.se',
#  '<1993apr10.191100.16094@ultb.isc.rit.edu>',
#  'nieves,',
#  'chart?',
#  '2.5)',
#  '>>pardon',
#  'something!',
#  '>influx',
#  '(jonathon',
#  'spatula.csv.warwick.ac.uk',
#  'cosar,',
#  'norfolk',
#  '<844@rins.ryukoku.ac.jp>',
#  'trace/radiosity',
#  '_rv',
#  'r.a.l.',
#  '>(9)',
#  '<rlglendec5t133.en3@netcom.com>',
#  'calne,',
#  'series?',
#  '"bible',
#  'cheer...',
#  "m/%vznki55?)u@<[*jjh42&u$55dh*'&rvoh857t0/&$x4%6-kl:jsoh@>;:)",
#  '468,',
#  'scoop.',
#  "m)g_1#<!.hv9h9+^'71%7uab",
#  'a66',
#  'good)',
#  '128.250.1.21',
#  'sharkbite.esd.sgi.com',
#  'conspiracy?',
#  'cryptography!',
#  'history,',
#  'banks)]',
#  'commemorates',
#  'm@6!1#5&?ax>\'ax>\'ax>\'ax=75]0%tzx"6\\$[9*pmjh/6c`:4zz&?8%\'u#1=1',
#  '1>s[q',
#  '[128.113.10.2]:',
#  "m.x@f!s@0^&27_t]7+9c^'=kjtws#].@td+7n].$tt!i-;1i(#n-t",
#  "pcw@access.digex.com's",
#  'nnv.',
#  'channel).',
#  'keegan@hermes.acm.rpi.edu',
#  '18:37).',
#  '<1993mar29.190650.28940@ramsey.cs.laurentian.ca>',
#  'souvlaki?',
#  'bargains',
#  'mubarak',
#  'mu;g6!j0"94_3m&\\!^[)xrws=tmwlb)#<rvf2c4[oss5#"tp;v65[nwa!o&7;',
#  'harley.',
#  'stevevr@tt718.ecs.comm.mot.com',
#  'bucks,',
#  'castleman',
#  'fettrons,',
#  'oxidation',
#  'pkp.',
#  'miranda,',
#  'laurel,',
#  'train/52',
#  '>phil?',
#  'thanks........',
#  'j.2',
#  'sale.',
#  'stronger?',
#  'interventionists.',
#  '<15apr199321275870@cvdv99.mayo.edu>,',
#  'zero',
#  'humble,',
#  '"seeing"',
#  'sizes.',
#  'floppy.',
#  '36.0',
#  'multi-layer',
#  'non-event',
#  'top.,',
#  'roboticist-in-training',
#  'mv:eu=774u-34s]0vy4b;f]`yg-x74?4<jz&!5e9c@xy\\lsz@k*z@zyra@x-e',
#  'ridley',
#  '3/1/92',
#  'hoop.',
#  'sabretooth',
#  'm\\?\'q\\:q9=e)xgnyu*v$e)9!+;dl"?r!_(-34("#(r`)n2r70*rot-u%@8,q@',
#  'y-s.',
#  'kellermann-arthur-l.',
#  '>lifestyles?',
#  'brian,',
#  'fuhrman',
#  'rage.',
#  'apex).',
#  'crusades:',
#  'shellfish',
#  'clothes?',
#  '>negotiating',
#  'sub-brightness:',
#  'amoral.',
#  'fulcrum',
#  'evangelical.',
#  'judeo-nazism.',
#  'mmw)r&g*w<g*m<k=r<g(:)bma2tmn`m34u-34u`("`@*u2czl;dmn)1%a)9"0',
#  'chen@protostar.harvard.edu',
#  'unlimited**',
#  '<f36si@cunyvm.bitnet>',
#  'it",',
#  '(+30',
#  "catchers'",
#  '#0:',
#  'help|',
#  'hd,',
#  'sky?',
#  'c-oo',
#  '-only-',
#  'dear',
#  'klui@corp.hp.com',
#  'assertion,',
#  '>taking',
#  'best-documented',
#  '<io30436@maine.maine.edu>',
#  'caprice',
#  'doctoral',
#  '(raymond',
#  'precedents?',
#  'feared',
#  'rider_;',
#  'participate',
#  'scanners.',
#  'gooch)',
#  'p1.z',
#  '>corporation,',
#  'a5x.',
#  'jrutledg@cs.ulowell.edu',
#  "m6k&(';$bu,a+py!a84m+2vyn;fynn8a\\4e(s!p?9v=dv-fmk:\\_/s\\_/s\\_/",
#  'critical,',
#  'church...........10',
#  'sc',
#  '"combo',
#  "institution's",
#  'disproved."',
#  '9x=',
#  'karaklis',
#  'otherwise.',
#  'joan',
#  'smart)',
#  'negotiated',
#  'blanker',
#  'blood")',
#  'aurora.1993apr21.001555.1',
#  '(albeit',
#  'baldwa@antietam.adobe.com',
#  '>observation,',
#  '95127...........',
#  'hollasch)',
#  'ega/vga',
#  'clk/2(17mhz',
#  '69149',
#  "gnu's",
#  '00:53:14',
#  't0$',
#  'circle."',
#  "wonderin'.....",
#  'title;)),',
#  "cubs'",
#  'fostma@saturn.wwc.edu',
#  "won'y",
#  'see--it',
#  'email.)',
#  'otally',
#  'th-28a',
#  'xtcallconverter',
#  '%5=,zgju0#q=l#>',
#  'anti-gun?',
#  'continuing',
#  '164633',
#  'cables',
#  '"linda"',
#  'server-resident',
#  'gannon',
#  'califronia,',
#  '"recopy"',
#  "'t'.",
#  'e-mail',
#  '(so',
#  'dsnyder@falcon.aamrl.wpafb.af.mil',
#  'advancing',
#  'supercenter',
#  "'controlled'.",
#  'premise;',
#  'loads:',
#  'declarations',
#  'quad4.',
#  "'74.",
#  'know;',
#  "ma7!145%124e'+t?d1t=)25%145&%a86%)x4g)s0g-#0g-#0t-(6%0d)p44)1",
#  'single',
#  '"hyped"...i',
#  '_historia',
#  'conserved.',
#  'wynn,',
#  'bonjour',
#  'shieldings',
#  'sunday.',
#  '3,000',
#  'nosy',
#  'mbkolodn@unix.amherst.edu',
#  'stratospheric',
#  'subservient,',
#  'mu-2fu-34u-34u-34i=2ei=2ei:6eu*bh,?o4^]34u-3[^]2e^z7[i3&e^]2e',
#  'immunoglobin',
#  'study).',
#  'deem',
#  "max>'ax>'ax>'ax>'ax>'a\\#`=75u)75u=27#;a2br,byyk9^s]17r!1;)76j",
#  'jays',
#  'skeletonising',
#  'borders!!!',
#  'hander',
#  'offensive.',
#  '15,221',
#  'mm[=r<ajw<g)r)g)r<g*wmw)/<k=rm[=r<jvmk;=r&jur<jur<jvw%:urmzt5',
#  '<80416@apple.apple.com>,',
#  'comp.os.ms-windows.programmer.tools',
#  'ata@c.mssl.ucl.ac.uk',
#  'hatira',
#  'outfield|play',
#  'tender,',
#  'prohibitive',
#  "pacastro's",
#  '508-655-9191',
#  'tune-up,',
#  'compeling,',
#  'msfci,',
#  'anolog',
#  'hutterites',
#  'new-understa',
#  'blank!!!',
#  'mmk;<w-rs>`&$a(2$a(2$a(0!>)z>vbud9"w:](s,43<&c/0ivbud9&1d+=k:',
#  'university-ness',
#  'spectre,',
#  'designer?',
#  'assuredly.',
#  'solomon.technet.sg',
#  '<1993apr16.010235.14225@mtu.edu>,',
#  'jarvis?',
#  'm:ar(?"[#g0zp^w(-)g;',
#  '11:25,',
#  '>>>steveh@thor.isc-br.com',
#  'godynyuk',
#  '(17-38-6)',
#  'brett@porky.oce.orst.edu',
#  '22:01:00',
#  'armenian,',
#  'few;',
#  'emotiaonal',
#  'rectification,',
#  'g=fit',
#  '?tran-',
#  'garden-variety,',
#  'man-oh-man',
#  '..............reply:',
#  'mcglynn:',
#  '0.452',
#  'preassumes',
#  '.a!*',
#  'suspend',
#  '763',
#  'reconstructed',
#  'boutwell)',
#  'kare',
#  '(wha)',
#  'reccurence.',
#  'spots',
#  'laferriere)',
#  'biker',
#  'cross-overs',
#  '>identify',
#  '>*real*',
#  'sacrificing',
#  '"unrecognized',
#  'jim.zisfein@factory.com',
#  'unenforced',
#  'gound',
#  '961.8',
#  'quintin,',
#  'hmmn.',
#  'kukis',
#  'dramatic',
#  'algebraic',
#  '>ruled',
#  'swedes.',
#  'fbmquant,',
#  '<wb9omc.735430855@dynamo.ecn.purdue.edu>,',
#  'xclrp->pixel',
#  'have...',
#  '<93099.141148c09630gk@wuvmd.wustl.edu>,',
#  'evenzo',
#  '198.58',
#  '1.22',
#  '(refusal',
#  'useful--a',
#  '$99.99',
#  'deshaies,',
#  'leading?"',
#  'complexity.',
#  'fruit,',
#  'm$a(2$a(2$a(2$a(2$du-;&q553",s/7>)x&!um;6fyl^/cla(4i(ax>\'ax>\'',
#  'respect?',
#  '(trio).',
#  '<c5jhbp.55w@portal.hq.videocart.com>',
#  'boulder|compuserve:',
#  'recently?',
#  'hmm?',
#  "m7klj>m_?1t>ei0mfq,3$,3$qax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'",
#  "need'",
#  'win>',
#  'forgivenenss.',
#  'opportunity,',
#  'clean"',
#  'm@`+(r`)j7"0df]34u,an2w5u=75up%m;6p4%\\>slqk\'o6ei:6gy:?gy^?ei:',
#  '*greatly*',
#  '"spiritually',
#  'lerosse',
#  'pagnozzi,',
#  '11x17).',
#  'biting,',
#  'tcl/tk',
#  'high-pitched',
#  '(>',
#  'buddy,',
#  "m=kp3o`$k*rmad$m+ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'",
#  '730-3169',
#  '>>>>',
#  '#which',
#  '_s,4',
#  '"promise."',
#  '0-63',
#  'phobias,',
#  '>>#>democracies?',
#  'g\'d."',
#  '>values',
#  'game,',
#  '>canadian.',
#  '1117.7',
#  '>christmas',
#  'r*;7>ec@.p)#-x8/[xg3hm\\&x+y+$:i?&h<\\x@\\9a3tt]>md)\\+d+!=*m',
#  '>>>>only',
#  'morningside',
#  'risk',
#  '[and',
#  'thinking!',
#  '(dwk@sunsrvr2.cci.com)-northern',
#  '_they_',
#  '(ab@cc.purdue.edu)',
#  'minder,',
#  'revco',
#  "willard's",
#  'comp.off.eff.org',
#  'personel',
#  ...]

# %%
categories=['alt.atheism','comp.graphics','comp.os.ms-windows.misc',]

# %%
#prior
data_category = []
for i in range(len(train.data)):
    GT_category = train.target_names[train.target[i]]
    if GT_category == categories[train.target[i]]:
        print (i, train.target_names[train.target[i]])
        data_category.append(train.data)

# %%
# likelihood
likelihood = {v: 0 for v in vocab_list}
total_w = 0
for i in range(len(data_category)):
    for dstr in data_category[i]:
        words = dstr.lower().split()
        for w in words:
            if w in vocab_list:
                total_w += 1
                likelihood[w] += 1
#
print(f"total space words in vocab = {total_w}") 


# Add 1 to every count = Laplace Smoothing
for k in likelihood
    vocabcount_space[k] += 1 

total = 0
for k, v in vocabcount_space.items():
    total += v 
print("total space after lapace smoothing: ", total)

# convert counts to prob
for k in vocabcount_space:
    vocabcount_space[k] /= total
