# %% [markdown]
# <!--BOOK_INFORMATION-->
# <img align="left" style="padding-right:10px;" src="figures/PDSH-cover-small.png">
#
# *This notebook contains an excerpt from the [Python Data Science Handbook](http://shop.oreilly.com/product/0636920034919.do) by Jake VanderPlas; the content is available [on GitHub](https://github.com/jakevdp/PythonDataScienceHandbook).*
#
# *The text is released under the [CC-BY-NC-ND license](https://creativecommons.org/licenses/by-nc-nd/3.0/us/legalcode), and code is released under the [MIT license](https://opensource.org/licenses/MIT). If you find this content useful, please consider supporting the work by [buying the book](http://shop.oreilly.com/product/0636920034919.do)!*

# %% [markdown]
# <!--NAVIGATION-->
# < [Feature Engineering](05.04-Feature-Engineering.ipynb) | [Contents](Index.ipynb) | [In Depth: Linear Regression](05.06-Linear-Regression.ipynb) >
#
# <a href="https://colab.research.google.com/github/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/05.05-Naive-Bayes.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a>

# %% [markdown]
# # In Depth: Naive Bayes Classification

# %% [markdown]
# The previous four sections have given a general overview of the concepts of machine learning.
# In this section and the ones that follow, we will be taking a closer look at several specific algorithms for supervised and unsupervised learning, starting here with naive Bayes classification.
#
# Naive Bayes models are a group of extremely fast and simple classification algorithms that are often suitable for very high-dimensional datasets.
# Because they are so fast and have so few tunable parameters, they end up being very useful as a quick-and-dirty baseline for a classification problem.
# This section will focus on an intuitive explanation of how naive Bayes classifiers work, followed by a couple examples of them in action on some datasets.

# %% [markdown]
# ## Bayesian Classification
#
# Naive Bayes classifiers are built on Bayesian classification methods.
# These rely on Bayes's theorem, which is an equation describing the relationship of conditional probabilities of statistical quantities.
# In Bayesian classification, we're interested in finding the probability of a label given some observed features, which we can write as $P(L~|~{\rm features})$.
# Bayes's theorem tells us how to express this in terms of quantities we can compute more directly:
#
# $$
# P(L~|~{\rm features}) = \frac{P({\rm features}~|~L)P(L)}{P({\rm features})}
# $$
#
# If we are trying to decide between two labels—let's call them $L_1$ and $L_2$—then one way to make this decision is to compute the ratio of the posterior probabilities for each label:
#
# $$
# \frac{P(L_1~|~{\rm features})}{P(L_2~|~{\rm features})} = \frac{P({\rm features}~|~L_1)}{P({\rm features}~|~L_2)}\frac{P(L_1)}{P(L_2)}
# $$
#
# All we need now is some model by which we can compute $P({\rm features}~|~L_i)$ for each label.
# Such a model is called a *generative model* because it specifies the hypothetical random process that generates the data.
# Specifying this generative model for each label is the main piece of the training of such a Bayesian classifier.
# The general version of such a training step is a very difficult task, but we can make it simpler through the use of some simplifying assumptions about the form of this model.
#
# This is where the "naive" in "naive Bayes" comes in: if we make very naive assumptions about the generative model for each label, we can find a rough approximation of the generative model for each class, and then proceed with the Bayesian classification.
# Different types of naive Bayes classifiers rest on different naive assumptions about the data, and we will examine a few of these in the following sections.
#
# We begin with the standard imports:

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %% [markdown]
# ## Gaussian Naive Bayes
#
# Perhaps the easiest naive Bayes classifier to understand is Gaussian naive Bayes.
# In this classifier, the assumption is that *data from each label is drawn from a simple Gaussian distribution*.
# Imagine that you have the following data:

# %% [markdown]
# ## Multinomial Naive Bayes
#
# The Gaussian assumption just described is by no means the only simple assumption that could be used to specify the generative distribution for each label.
# Another useful example is multinomial naive Bayes, where the features are assumed to be generated from a simple multinomial distribution.
# The multinomial distribution describes the probability of observing counts among a number of categories, and thus multinomial naive Bayes is most appropriate for features that represent counts or count rates.
#
# The idea is precisely the same as before, except that instead of modeling the data distribution with the best-fit Gaussian, we model the data distribuiton with a best-fit multinomial distribution.

# %% [markdown]
# ### Example: Classifying Text
#
# One place where multinomial naive Bayes is often used is in text classification, where the features are related to word counts or frequencies within the documents to be classified.
# We discussed the extraction of such features from text in [Feature Engineering](05.04-Feature-Engineering.ipynb); here we will use the sparse word count features from the 20 Newsgroups corpus to show how we might classify these short documents into categories.
#
# Let's download the data and take a look at the target names:

# %%
from sklearn.datasets import fetch_20newsgroups
data = fetch_20newsgroups()

# %%
categories = ['talk.religion.misc', 'sci.space', 'rec.motorcycles']
train = fetch_20newsgroups(subset='train', categories=categories)
test = fetch_20newsgroups(subset='test', categories=categories)

# %%
vocab = ['Religion','God', 'Beliefs','Religious','Believers','Christ','Church','Orthodox','Muslim','Bible','Truth','Morals','Scripture','Commandments','Christian','Politics','Culture','Sin','Interpret','Mormon','prayer'] \
+ ['star', 'sun', 'sonic', 'titan', 'jupyter', 'planets', 'astronomy', 'astronomer', 'moon', 'nasa', 'earth', 'astronomical', 'space', 'spacecraft', 'planetary', 'universe', 'supersonic', 'satelite', 'orbit'] \
+ ['speed','bike','BMW','BMWRA','helmet','manufacturer','fiberglass','low-speed']

# %%
vocab = [ v.lower() for v in vocab]

# %%
train.target_names
# Out:
# ['rec.motorcycles', 'sci.space', 'talk.religion.misc']

# %%
# collect data strings only for 'space'
data_space = []
for i in range(len(train.data)):
    if train.target_names[train.target[i]] == "sci.space":
        # print (i, train.target_names[train.target[i]])
        data_space.append(train.data[i])
#
len(data_space)
# Out:
# 593

# %%
data_moto = []
for i in range(len(train.data)):
    if train.target_names[train.target[i]] == "rec.motorcycles":
        data_moto.append(train.data[i])
#
len(data_moto)
# Out:
# 598

# %%
data_reli = []
for i in range(len(train.data)):
    if train.target_names[train.target[i]] == "talk.religion.misc":
        data_reli.append(train.data[i])
#
len(data_reli)
# Out:
# 377

# %%
# let's count!
vocabcount_space = { v: 0 for v in vocab}

total_w = 0
for dstr in data_space:
    words = dstr.lower().split()
    # print(words)
    for w in words:
        if w in vocab:
            # print(w)
            total_w += 1
            vocabcount_space[w] += 1
#
print(f"total space words in vocab = {total_w}") 

total = 0
for k, v in vocabcount_space.items():
    total += v 
print(total)
# Out:
# total space words in vocab = 2508
# 2508

# %%
vocabcount_moto = { v: 0 for v in vocab}

total_w = 0
for dstr in data_moto:
    words = dstr.lower().split()
    # print(words)
    for w in words:
        if w in vocab:
            # print(w)
            total_w += 1
            vocabcount_moto[w] += 1
#
print(f"total moto words in vocab = {total_w}") 

total = 0
for k, v in vocabcount_moto.items():
    total += v 
print(total)
# Out:
# total moto words in vocab = 744
# 744

# %%
vocabcount_reli = { v: 0 for v in vocab}

total_w = 0
for dstr in data_reli:
    words = dstr.lower().split()
    # print(words)
    for w in words:
        if w in vocab:
            # print(w)
            total_w += 1
            vocabcount_reli[w] += 1
#
print(f"total reli words in vocab = {total_w}") 

total = 0
for k, v in vocabcount_reli.items():
    total += v 
print(total)
# Out:
# total reli words in vocab = 1097
# 1097

# %%
# Add 1 to every count = Laplace Smoothing
for k in vocabcount_space:
    vocabcount_space[k] += 1 

total = 0
for k, v in vocabcount_space.items():
    total += v 
print("total space after lapace smoothing: ", total)

# convert counts to prob
for k in vocabcount_space:
    vocabcount_space[k] /= total
# Out:
# total space after lapace smoothing:  2556

# %%
# Add 1 to every count = Laplace Smoothing
for k in vocabcount_moto:
    vocabcount_moto[k] += 1 

total = 0
for k, v in vocabcount_moto.items():
    total += v 
print("total moto after lapace smoothing: ", total)

# convert counts to prob
for k in vocabcount_moto:
    vocabcount_moto[k] /= total
# Out:
# total moto after lapace smoothing:  792

# %%
# Add 1 to every count = Laplace Smoothing
for k in vocabcount_reli:
    vocabcount_reli[k] += 1 

total = 0
for k, v in vocabcount_reli.items():
    total += v 
print("total reli after lapace smoothing: ", total)

# convert counts to prob
for k in vocabcount_reli:
    vocabcount_reli[k] /= total
# Out:
# total reli after lapace smoothing:  1145

# %%
# compute log-probability
vocab_space_logp = { key: np.log(value) for key, value in vocabcount_space.items() }
vocab_moto_logp = { key: np.log(value) for key, value in vocabcount_moto.items() }
vocab_reli_logp = { key: np.log(value) for key, value in vocabcount_reli.items() }

# %%
plt.bar(np.arange(len(vocabcount_space.values())), vocab_space_logp.values())
plt.bar(np.arange(len(vocabcount_moto.values())), vocab_moto_logp.values())
plt.bar(np.arange(len(vocabcount_reli.values())), vocab_reli_logp.values())
# Out:
# <BarContainer object of 48 artists>

# %%
train_true_labels = train.target
test_true_labels = test.target

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tnames = ['space', 'religion', 'moto']

correct_train_predictions = 0
predicted_labels = []

for i in range(len(test.data)):
    tsample = test.data[i]
    
    space_logp = 0
    religion_logp = 0
    moto_logp = 0
    
    for w in tsample.lower().split():
        if w in vocab:
            space_logp += vocab_space_logp[w]
    for w in tsample.lower().split():
        if w in vocab:
            religion_logp += vocab_moto_logp[w]
    for w in tsample.lower().split():
        if w in vocab:
            moto_logp += vocab_reli_logp[w]
            
    x = np.argmax([space_logp, religion_logp, moto_logp])
    predicted_label = tnames[x]
    predicted_labels.append(predicted_label)
    
    true_label = test_true_labels[i]
    
    print("Test", i, "Predicted:", predicted_label,"|" ,"True:", tnames[true_label])
    
    if predicted_label == tnames[true_label]:
        correct_train_predictions += 1

test_accuracy = correct_train_predictions / len(test.data)
print("Test Accuracy(%):", test_accuracy*100)
# Out:
# Test 0 Predicted: religion | True: space
# Test 1 Predicted: space | True: moto
# Test 2 Predicted: moto | True: moto
# Test 3 Predicted: space | True: space
# Test 4 Predicted: space | True: religion
# Test 5 Predicted: space | True: moto
# Test 6 Predicted: space | True: religion
# Test 7 Predicted: religion | True: space
# Test 8 Predicted: moto | True: moto
# Test 9 Predicted: moto | True: moto
# Test 10 Predicted: space | True: space
# Test 11 Predicted: religion | True: space
# Test 12 Predicted: moto | True: moto
# Test 13 Predicted: space | True: space
# Test 14 Predicted: space | True: religion
# Test 15 Predicted: space | True: religion
# Test 16 Predicted: space | True: religion
# Test 17 Predicted: space | True: religion
# Test 18 Predicted: moto | True: moto
# Test 19 Predicted: moto | True: moto
# Test 20 Predicted: space | True: religion
# Test 21 Predicted: space | True: space
# Test 22 Predicted: space | True: religion
# Test 23 Predicted: space | True: religion
# Test 24 Predicted: space | True: religion
# Test 25 Predicted: religion | True: space
# Test 26 Predicted: space | True: space
# Test 27 Predicted: space | True: space
# Test 28 Predicted: space | True: religion
# Test 29 Predicted: space | True: religion
# Test 30 Predicted: moto | True: moto
# Test 31 Predicted: space | True: religion
# Test 32 Predicted: space | True: religion
# Test 33 Predicted: space | True: religion
# Test 34 Predicted: religion | True: space
# Test 35 Predicted: space | True: religion
# Test 36 Predicted: space | True: religion
# Test 37 Predicted: religion | True: space
# Test 38 Predicted: religion | True: space
# Test 39 Predicted: space | True: space
# Test 40 Predicted: religion | True: space
# Test 41 Predicted: space | True: space
# Test 42 Predicted: space | True: moto
# Test 43 Predicted: religion | True: space
# Test 44 Predicted: religion | True: space
# Test 45 Predicted: moto | True: moto
# Test 46 Predicted: space | True: religion
# Test 47 Predicted: space | True: religion
# Test 48 Predicted: moto | True: moto
# Test 49 Predicted: space | True: space
# Test 50 Predicted: religion | True: space
# Test 51 Predicted: space | True: space
# Test 52 Predicted: space | True: moto
# Test 53 Predicted: moto | True: moto
# Test 54 Predicted: space | True: moto
# Test 55 Predicted: space | True: moto
# Test 56 Predicted: space | True: space
# Test 57 Predicted: space | True: religion
# Test 58 Predicted: space | True: religion
# Test 59 Predicted: moto | True: moto
# Test 60 Predicted: religion | True: space
# Test 61 Predicted: religion | True: space
# Test 62 Predicted: space | True: religion
# Test 63 Predicted: religion | True: space
# Test 64 Predicted: moto | True: moto
# Test 65 Predicted: religion | True: space
# Test 66 Predicted: space | True: religion
# Test 67 Predicted: religion | True: space
# Test 68 Predicted: religion | True: space
# Test 69 Predicted: space | True: religion
# Test 70 Predicted: space | True: religion
# Test 71 Predicted: religion | True: space
# Test 72 Predicted: space | True: religion
# Test 73 Predicted: religion | True: space
# Test 74 Predicted: moto | True: moto
# Test 75 Predicted: space | True: space
# Test 76 Predicted: space | True: moto
# Test 77 Predicted: space | True: religion
# Test 78 Predicted: religion | True: space
# Test 79 Predicted: space | True: space
# Test 80 Predicted: moto | True: moto
# Test 81 Predicted: moto | True: moto
# Test 82 Predicted: moto | True: moto
# Test 83 Predicted: religion | True: space
# Test 84 Predicted: space | True: religion
# Test 85 Predicted: space | True: religion
# Test 86 Predicted: space | True: religion
# Test 87 Predicted: space | True: space
# Test 88 Predicted: space | True: religion
# Test 89 Predicted: moto | True: moto
# Test 90 Predicted: space | True: religion
# Test 91 Predicted: religion | True: space
# Test 92 Predicted: space | True: space
# Test 93 Predicted: space | True: religion
# Test 94 Predicted: space | True: religion
# Test 95 Predicted: moto | True: moto
# Test 96 Predicted: space | True: religion
# Test 97 Predicted: space | True: religion
# Test 98 Predicted: space | True: space
# Test 99 Predicted: space | True: space
# Test 100 Predicted: moto | True: moto
# Test 101 Predicted: space | True: space
# Test 102 Predicted: religion | True: space
# Test 103 Predicted: space | True: space
# Test 104 Predicted: moto | True: moto
# Test 105 Predicted: space | True: space
# Test 106 Predicted: space | True: moto
# Test 107 Predicted: moto | True: moto
# Test 108 Predicted: space | True: moto
# Test 109 Predicted: religion | True: space
# Test 110 Predicted: space | True: moto
# Test 111 Predicted: religion | True: space
# Test 112 Predicted: space | True: religion
# Test 113 Predicted: space | True: space
# Test 114 Predicted: space | True: religion
# Test 115 Predicted: moto | True: moto
# Test 116 Predicted: religion | True: space
# Test 117 Predicted: space | True: religion
# Test 118 Predicted: space | True: religion
# Test 119 Predicted: space | True: space
# Test 120 Predicted: space | True: religion
# Test 121 Predicted: space | True: religion
# Test 122 Predicted: space | True: space
# Test 123 Predicted: space | True: moto
# Test 124 Predicted: religion | True: space
# Test 125 Predicted: space | True: religion
# Test 126 Predicted: religion | True: space
# Test 127 Predicted: religion | True: space
# Test 128 Predicted: space | True: space
# Test 129 Predicted: space | True: space
# Test 130 Predicted: space | True: space
# Test 131 Predicted: space | True: religion
# Test 132 Predicted: religion | True: space
# Test 133 Predicted: space | True: religion
# Test 134 Predicted: religion | True: space
# Test 135 Predicted: space | True: space
# Test 136 Predicted: space | True: space
# Test 137 Predicted: moto | True: religion
# Test 138 Predicted: religion | True: space
# Test 139 Predicted: religion | True: space
# Test 140 Predicted: religion | True: space
# Test 141 Predicted: space | True: space
# Test 142 Predicted: space | True: religion
# Test 143 Predicted: space | True: religion
# Test 144 Predicted: religion | True: space
# Test 145 Predicted: moto | True: moto
# Test 146 Predicted: space | True: religion
# Test 147 Predicted: space | True: religion
# Test 148 Predicted: space | True: moto
# Test 149 Predicted: space | True: moto
# Test 150 Predicted: space | True: religion
# Test 151 Predicted: religion | True: space
# Test 152 Predicted: space | True: religion
# Test 153 Predicted: space | True: moto
# Test 154 Predicted: space | True: moto
# Test 155 Predicted: space | True: moto
# Test 156 Predicted: space | True: religion
# Test 157 Predicted: space | True: religion
# Test 158 Predicted: space | True: moto
# Test 159 Predicted: space | True: religion
# Test 160 Predicted: religion | True: space
# Test 161 Predicted: space | True: space
# Test 162 Predicted: space | True: space
# Test 163 Predicted: religion | True: space
# Test 164 Predicted: space | True: religion
# Test 165 Predicted: religion | True: space
# Test 166 Predicted: religion | True: space
# Test 167 Predicted: space | True: space
# Test 168 Predicted: religion | True: moto
# Test 169 Predicted: moto | True: moto
# Test 170 Predicted: space | True: religion
# Test 171 Predicted: space | True: religion
# Test 172 Predicted: space | True: religion
# Test 173 Predicted: religion | True: space
# Test 174 Predicted: space | True: religion
# Test 175 Predicted: space | True: religion
# Test 176 Predicted: religion | True: space
# Test 177 Predicted: space | True: space
# Test 178 Predicted: religion | True: space
# Test 179 Predicted: moto | True: moto
# Test 180 Predicted: space | True: moto
# Test 181 Predicted: space | True: religion
# Test 182 Predicted: space | True: religion
# Test 183 Predicted: space | True: religion
# Test 184 Predicted: religion | True: space
# Test 185 Predicted: moto | True: moto
# Test 186 Predicted: moto | True: moto
# Test 187 Predicted: space | True: space
# Test 188 Predicted: religion | True: space
# Test 189 Predicted: moto | True: moto
# Test 190 Predicted: space | True: religion
# Test 191 Predicted: space | True: religion
# Test 192 Predicted: space | True: religion
# Test 193 Predicted: space | True: religion
# Test 194 Predicted: moto | True: moto
# Test 195 Predicted: space | True: religion
# Test 196 Predicted: space | True: religion
# Test 197 Predicted: space | True: space
# Test 198 Predicted: space | True: religion
# Test 199 Predicted: moto | True: moto
# Test 200 Predicted: space | True: religion
# Test 201 Predicted: space | True: religion
# Test 202 Predicted: space | True: religion
# Test 203 Predicted: religion | True: space
# Test 204 Predicted: moto | True: moto
# Test 205 Predicted: moto | True: moto
# Test 206 Predicted: moto | True: moto
# Test 207 Predicted: religion | True: space
# Test 208 Predicted: religion | True: space
# Test 209 Predicted: space | True: religion
# Test 210 Predicted: space | True: religion
# Test 211 Predicted: religion | True: space
# Test 212 Predicted: moto | True: moto
# Test 213 Predicted: moto | True: moto
# Test 214 Predicted: space | True: religion
# Test 215 Predicted: space | True: space
# Test 216 Predicted: moto | True: moto
# Test 217 Predicted: space | True: space
# Test 218 Predicted: space | True: space
# Test 219 Predicted: space | True: religion
# Test 220 Predicted: space | True: religion
# Test 221 Predicted: space | True: moto
# Test 222 Predicted: space | True: moto
# Test 223 Predicted: religion | True: space
# Test 224 Predicted: space | True: space
# Test 225 Predicted: moto | True: moto
# Test 226 Predicted: religion | True: religion
# Test 227 Predicted: space | True: religion
# Test 228 Predicted: space | True: space
# Test 229 Predicted: space | True: moto
# Test 230 Predicted: moto | True: moto
# Test 231 Predicted: moto | True: moto
# Test 232 Predicted: moto | True: moto
# Test 233 Predicted: space | True: moto
# Test 234 Predicted: space | True: space
# Test 235 Predicted: religion | True: space
# Test 236 Predicted: space | True: space
# Test 237 Predicted: space | True: religion
# Test 238 Predicted: religion | True: space
# Test 239 Predicted: space | True: space
# Test 240 Predicted: space | True: space
# Test 241 Predicted: moto | True: moto
# Test 242 Predicted: space | True: religion
# Test 243 Predicted: space | True: religion
# Test 244 Predicted: space | True: religion
# Test 245 Predicted: space | True: religion
# Test 246 Predicted: moto | True: space
# Test 247 Predicted: moto | True: moto
# Test 248 Predicted: space | True: moto
# Test 249 Predicted: religion | True: moto
# Test 250 Predicted: space | True: religion
# Test 251 Predicted: religion | True: space
# Test 252 Predicted: religion | True: space
# Test 253 Predicted: moto | True: moto
# Test 254 Predicted: space | True: religion
# Test 255 Predicted: religion | True: space
# Test 256 Predicted: moto | True: moto
# Test 257 Predicted: religion | True: space
# Test 258 Predicted: religion | True: space
# Test 259 Predicted: religion | True: space
# Test 260 Predicted: space | True: religion
# Test 261 Predicted: space | True: moto
# Test 262 Predicted: moto | True: moto
# Test 263 Predicted: space | True: religion
# Test 264 Predicted: religion | True: space
# Test 265 Predicted: moto | True: moto
# Test 266 Predicted: religion | True: space
# Test 267 Predicted: religion | True: space
# Test 268 Predicted: space | True: religion
# Test 269 Predicted: religion | True: space
# Test 270 Predicted: moto | True: moto
# Test 271 Predicted: space | True: religion
# Test 272 Predicted: space | True: religion
# Test 273 Predicted: space | True: moto
# Test 274 Predicted: space | True: religion
# Test 275 Predicted: space | True: space
# Test 276 Predicted: moto | True: moto
# Test 277 Predicted: space | True: religion
# Test 278 Predicted: space | True: space
# Test 279 Predicted: space | True: religion
# Test 280 Predicted: space | True: religion
# Test 281 Predicted: space | True: moto
# Test 282 Predicted: space | True: religion
# Test 283 Predicted: space | True: religion
# Test 284 Predicted: moto | True: moto
# Test 285 Predicted: moto | True: moto
# Test 286 Predicted: space | True: space
# Test 287 Predicted: space | True: space
# Test 288 Predicted: religion | True: space
# Test 289 Predicted: space | True: moto
# Test 290 Predicted: space | True: space
# Test 291 Predicted: moto | True: moto
# Test 292 Predicted: space | True: religion
# Test 293 Predicted: moto | True: moto
# Test 294 Predicted: moto | True: moto
# Test 295 Predicted: space | True: space
# Test 296 Predicted: moto | True: moto
# Test 297 Predicted: space | True: religion
# Test 298 Predicted: moto | True: moto
# Test 299 Predicted: space | True: religion
# Test 300 Predicted: space | True: space
# Test 301 Predicted: space | True: space
# Test 302 Predicted: space | True: space
# Test 303 Predicted: space | True: space
# Test 304 Predicted: space | True: space
# Test 305 Predicted: space | True: moto
# Test 306 Predicted: space | True: religion
# Test 307 Predicted: space | True: space
# Test 308 Predicted: space | True: religion
# Test 309 Predicted: space | True: religion
# Test 310 Predicted: space | True: space
# Test 311 Predicted: religion | True: space
# Test 312 Predicted: space | True: religion
# Test 313 Predicted: space | True: religion
# Test 314 Predicted: space | True: religion
# Test 315 Predicted: religion | True: space
# Test 316 Predicted: space | True: religion
# Test 317 Predicted: space | True: space
# Test 318 Predicted: space | True: religion
# Test 319 Predicted: religion | True: space
# Test 320 Predicted: religion | True: space
# Test 321 Predicted: religion | True: space
# Test 322 Predicted: space | True: space
# Test 323 Predicted: space | True: religion
# Test 324 Predicted: religion | True: space
# Test 325 Predicted: space | True: religion
# Test 326 Predicted: space | True: space
# Test 327 Predicted: space | True: space
# Test 328 Predicted: moto | True: moto
# Test 329 Predicted: religion | True: space
# Test 330 Predicted: space | True: space
# Test 331 Predicted: space | True: religion
# Test 332 Predicted: moto | True: moto
# Test 333 Predicted: religion | True: space
# Test 334 Predicted: moto | True: moto
# Test 335 Predicted: space | True: religion
# Test 336 Predicted: space | True: religion
# Test 337 Predicted: space | True: religion
# Test 338 Predicted: moto | True: moto
# Test 339 Predicted: space | True: religion
# Test 340 Predicted: space | True: religion
# Test 341 Predicted: space | True: moto
# Test 342 Predicted: religion | True: space
# Test 343 Predicted: moto | True: moto
# Test 344 Predicted: religion | True: space
# Test 345 Predicted: moto | True: moto
# Test 346 Predicted: space | True: space
# Test 347 Predicted: space | True: religion
# Test 348 Predicted: religion | True: space
# Test 349 Predicted: space | True: religion
# Test 350 Predicted: space | True: religion
# Test 351 Predicted: space | True: religion
# Test 352 Predicted: space | True: space
# Test 353 Predicted: space | True: religion
# Test 354 Predicted: space | True: religion
# Test 355 Predicted: space | True: moto
# Test 356 Predicted: moto | True: moto
# Test 357 Predicted: religion | True: space
# Test 358 Predicted: space | True: space
# Test 359 Predicted: moto | True: religion
# Test 360 Predicted: space | True: space
# Test 361 Predicted: moto | True: moto
# Test 362 Predicted: religion | True: space
# Test 363 Predicted: space | True: space
# Test 364 Predicted: space | True: space
# Test 365 Predicted: space | True: religion
# Test 366 Predicted: space | True: space
# Test 367 Predicted: moto | True: moto
# Test 368 Predicted: space | True: space
# Test 369 Predicted: space | True: space
# Test 370 Predicted: space | True: religion
# Test 371 Predicted: space | True: religion
# Test 372 Predicted: space | True: religion
# Test 373 Predicted: space | True: space
# Test 374 Predicted: religion | True: space
# Test 375 Predicted: space | True: moto
# Test 376 Predicted: religion | True: space
# Test 377 Predicted: space | True: religion
# Test 378 Predicted: moto | True: moto
# Test 379 Predicted: moto | True: moto
# Test 380 Predicted: space | True: religion
# Test 381 Predicted: space | True: religion
# Test 382 Predicted: moto | True: moto
# Test 383 Predicted: space | True: moto
# Test 384 Predicted: space | True: space
# Test 385 Predicted: space | True: space
# Test 386 Predicted: space | True: religion
# Test 387 Predicted: moto | True: moto
# Test 388 Predicted: space | True: religion
# Test 389 Predicted: space | True: space
# Test 390 Predicted: space | True: religion
# Test 391 Predicted: space | True: religion
# Test 392 Predicted: space | True: religion
# Test 393 Predicted: space | True: religion
# Test 394 Predicted: space | True: religion
# Test 395 Predicted: religion | True: space
# Test 396 Predicted: space | True: religion
# Test 397 Predicted: space | True: space
# Test 398 Predicted: moto | True: moto
# Test 399 Predicted: space | True: religion
# Test 400 Predicted: space | True: religion
# Test 401 Predicted: space | True: space
# Test 402 Predicted: space | True: space
# Test 403 Predicted: space | True: religion
# Test 404 Predicted: religion | True: space
# Test 405 Predicted: space | True: religion
# Test 406 Predicted: space | True: space
# Test 407 Predicted: space | True: religion
# Test 408 Predicted: space | True: religion
# Test 409 Predicted: space | True: religion
# Test 410 Predicted: space | True: religion
# Test 411 Predicted: space | True: religion
# Test 412 Predicted: space | True: moto
# Test 413 Predicted: space | True: space
# Test 414 Predicted: space | True: religion
# Test 415 Predicted: space | True: religion
# Test 416 Predicted: space | True: moto
# Test 417 Predicted: religion | True: space
# Test 418 Predicted: religion | True: space
# Test 419 Predicted: space | True: moto
# Test 420 Predicted: space | True: space
# Test 421 Predicted: moto | True: moto
# Test 422 Predicted: space | True: moto
# Test 423 Predicted: religion | True: space
# Test 424 Predicted: religion | True: space
# Test 425 Predicted: space | True: religion
# Test 426 Predicted: space | True: religion
# Test 427 Predicted: space | True: religion
# Test 428 Predicted: space | True: moto
# Test 429 Predicted: space | True: space
# Test 430 Predicted: space | True: religion
# Test 431 Predicted: space | True: religion
# Test 432 Predicted: religion | True: space
# Test 433 Predicted: moto | True: moto
# Test 434 Predicted: space | True: religion
# Test 435 Predicted: space | True: religion
# Test 436 Predicted: space | True: religion
# Test 437 Predicted: space | True: space
# Test 438 Predicted: space | True: moto
# Test 439 Predicted: space | True: religion
# Test 440 Predicted: religion | True: space
# Test 441 Predicted: moto | True: moto
# Test 442 Predicted: space | True: space
# Test 443 Predicted: moto | True: moto
# Test 444 Predicted: space | True: moto
# Test 445 Predicted: space | True: religion
# Test 446 Predicted: moto | True: moto
# Test 447 Predicted: space | True: space
# Test 448 Predicted: space | True: space
# Test 449 Predicted: space | True: moto
# Test 450 Predicted: space | True: space
# Test 451 Predicted: space | True: religion
# Test 452 Predicted: religion | True: space
# Test 453 Predicted: space | True: space
# Test 454 Predicted: space | True: religion
# Test 455 Predicted: religion | True: space
# Test 456 Predicted: space | True: religion
# Test 457 Predicted: space | True: moto
# Test 458 Predicted: moto | True: moto
# Test 459 Predicted: space | True: religion
# Test 460 Predicted: space | True: religion
# Test 461 Predicted: space | True: space
# Test 462 Predicted: moto | True: moto
# Test 463 Predicted: religion | True: space
# Test 464 Predicted: space | True: religion
# Test 465 Predicted: space | True: space
# Test 466 Predicted: space | True: moto
# Test 467 Predicted: space | True: space
# Test 468 Predicted: space | True: religion
# Test 469 Predicted: space | True: religion
# Test 470 Predicted: moto | True: moto
# Test 471 Predicted: space | True: religion
# Test 472 Predicted: space | True: moto
# Test 473 Predicted: space | True: religion
# Test 474 Predicted: religion | True: space
# Test 475 Predicted: space | True: religion
# Test 476 Predicted: space | True: religion
# Test 477 Predicted: space | True: space
# Test 478 Predicted: moto | True: moto
# Test 479 Predicted: space | True: religion
# Test 480 Predicted: space | True: space
# Test 481 Predicted: space | True: religion
# Test 482 Predicted: space | True: space
# Test 483 Predicted: space | True: space
# Test 484 Predicted: space | True: religion
# Test 485 Predicted: space | True: moto
# Test 486 Predicted: space | True: religion
# Test 487 Predicted: space | True: religion
# Test 488 Predicted: space | True: moto
# Test 489 Predicted: space | True: religion
# Test 490 Predicted: space | True: space
# Test 491 Predicted: space | True: religion
# Test 492 Predicted: moto | True: moto
# Test 493 Predicted: space | True: religion
# Test 494 Predicted: space | True: space
# Test 495 Predicted: space | True: religion
# Test 496 Predicted: space | True: space
# Test 497 Predicted: space | True: religion
# Test 498 Predicted: moto | True: moto
# Test 499 Predicted: space | True: religion
# Test 500 Predicted: moto | True: moto
# Test 501 Predicted: space | True: religion
# Test 502 Predicted: space | True: religion
# Test 503 Predicted: space | True: space
# Test 504 Predicted: space | True: religion
# Test 505 Predicted: moto | True: moto
# Test 506 Predicted: space | True: religion
# Test 507 Predicted: religion | True: space
# Test 508 Predicted: space | True: space
# Test 509 Predicted: space | True: moto
# Test 510 Predicted: space | True: space
# Test 511 Predicted: space | True: moto
# Test 512 Predicted: space | True: religion
# Test 513 Predicted: moto | True: moto
# Test 514 Predicted: space | True: space
# Test 515 Predicted: space | True: religion
# Test 516 Predicted: religion | True: space
# Test 517 Predicted: moto | True: moto
# Test 518 Predicted: space | True: space
# Test 519 Predicted: space | True: religion
# Test 520 Predicted: space | True: religion
# Test 521 Predicted: space | True: space
# Test 522 Predicted: religion | True: space
# Test 523 Predicted: religion | True: space
# Test 524 Predicted: space | True: space
# Test 525 Predicted: space | True: moto
# Test 526 Predicted: space | True: religion
# Test 527 Predicted: religion | True: space
# Test 528 Predicted: space | True: religion
# Test 529 Predicted: moto | True: space
# Test 530 Predicted: space | True: religion
# Test 531 Predicted: space | True: religion
# Test 532 Predicted: space | True: space
# Test 533 Predicted: space | True: religion
# Test 534 Predicted: moto | True: moto
# Test 535 Predicted: space | True: space
# Test 536 Predicted: space | True: religion
# Test 537 Predicted: space | True: moto
# Test 538 Predicted: space | True: moto
# Test 539 Predicted: moto | True: moto
# Test 540 Predicted: space | True: space
# Test 541 Predicted: space | True: moto
# Test 542 Predicted: space | True: religion
# Test 543 Predicted: religion | True: space
# Test 544 Predicted: space | True: religion
# Test 545 Predicted: space | True: religion
# Test 546 Predicted: space | True: space
# Test 547 Predicted: space | True: religion
# Test 548 Predicted: religion | True: space
# Test 549 Predicted: space | True: religion
# Test 550 Predicted: space | True: space
# Test 551 Predicted: space | True: space
# Test 552 Predicted: religion | True: religion
# Test 553 Predicted: space | True: religion
# Test 554 Predicted: religion | True: space
# Test 555 Predicted: space | True: space
# Test 556 Predicted: moto | True: moto
# Test 557 Predicted: space | True: religion
# Test 558 Predicted: religion | True: space
# Test 559 Predicted: space | True: moto
# Test 560 Predicted: space | True: religion
# Test 561 Predicted: space | True: religion
# Test 562 Predicted: space | True: space
# Test 563 Predicted: space | True: space
# Test 564 Predicted: space | True: religion
# Test 565 Predicted: space | True: religion
# Test 566 Predicted: space | True: religion
# Test 567 Predicted: moto | True: moto
# Test 568 Predicted: space | True: religion
# Test 569 Predicted: space | True: religion
# Test 570 Predicted: space | True: religion
# Test 571 Predicted: space | True: space
# Test 572 Predicted: space | True: moto
# Test 573 Predicted: space | True: religion
# Test 574 Predicted: space | True: space
# Test 575 Predicted: moto | True: moto
# Test 576 Predicted: religion | True: space
# Test 577 Predicted: religion | True: space
# Test 578 Predicted: space | True: religion
# Test 579 Predicted: space | True: religion
# Test 580 Predicted: space | True: religion
# Test 581 Predicted: space | True: religion
# Test 582 Predicted: space | True: religion
# Test 583 Predicted: moto | True: moto
# Test 584 Predicted: space | True: space
# Test 585 Predicted: space | True: space
# Test 586 Predicted: space | True: religion
# Test 587 Predicted: space | True: space
# Test 588 Predicted: space | True: religion
# Test 589 Predicted: space | True: space
# Test 590 Predicted: space | True: religion
# Test 591 Predicted: space | True: moto
# Test 592 Predicted: space | True: space
# Test 593 Predicted: space | True: religion
# Test 594 Predicted: space | True: religion
# Test 595 Predicted: moto | True: moto
# Test 596 Predicted: religion | True: space
# Test 597 Predicted: space | True: religion
# Test 598 Predicted: religion | True: space
# Test 599 Predicted: space | True: religion
# Test 600 Predicted: space | True: space
# Test 601 Predicted: space | True: religion
# Test 602 Predicted: space | True: religion
# Test 603 Predicted: space | True: religion
# Test 604 Predicted: space | True: religion
# Test 605 Predicted: space | True: space
# Test 606 Predicted: moto | True: moto
# Test 607 Predicted: space | True: space
# Test 608 Predicted: space | True: religion
# Test 609 Predicted: space | True: religion
# Test 610 Predicted: space | True: religion
# Test 611 Predicted: space | True: moto
# Test 612 Predicted: space | True: religion
# Test 613 Predicted: space | True: space
# Test 614 Predicted: religion | True: space
# Test 615 Predicted: space | True: moto
# Test 616 Predicted: moto | True: space
# Test 617 Predicted: space | True: moto
# Test 618 Predicted: space | True: religion
# Test 619 Predicted: space | True: moto
# Test 620 Predicted: moto | True: moto
# Test 621 Predicted: space | True: religion
# Test 622 Predicted: space | True: space
# Test 623 Predicted: space | True: space
# Test 624 Predicted: space | True: moto
# Test 625 Predicted: space | True: space
# Test 626 Predicted: moto | True: moto
# Test 627 Predicted: space | True: religion
# Test 628 Predicted: religion | True: space
# Test 629 Predicted: moto | True: moto
# Test 630 Predicted: space | True: space
# Test 631 Predicted: space | True: religion
# Test 632 Predicted: space | True: space
# Test 633 Predicted: space | True: religion
# Test 634 Predicted: space | True: space
# Test 635 Predicted: religion | True: space
# Test 636 Predicted: religion | True: moto
# Test 637 Predicted: space | True: moto
# Test 638 Predicted: space | True: moto
# Test 639 Predicted: space | True: religion
# Test 640 Predicted: space | True: religion
# Test 641 Predicted: moto | True: moto
# Test 642 Predicted: space | True: space
# Test 643 Predicted: space | True: religion
# Test 644 Predicted: moto | True: moto
# Test 645 Predicted: space | True: religion
# Test 646 Predicted: space | True: moto
# Test 647 Predicted: space | True: moto
# Test 648 Predicted: space | True: space
# Test 649 Predicted: space | True: religion
# Test 650 Predicted: religion | True: space
# Test 651 Predicted: moto | True: religion
# Test 652 Predicted: space | True: religion
# Test 653 Predicted: moto | True: moto
# Test 654 Predicted: religion | True: space
# Test 655 Predicted: space | True: religion
# Test 656 Predicted: religion | True: space
# Test 657 Predicted: space | True: space
# Test 658 Predicted: space | True: space
# Test 659 Predicted: space | True: religion
# Test 660 Predicted: space | True: space
# Test 661 Predicted: space | True: religion
# Test 662 Predicted: space | True: moto
# Test 663 Predicted: religion | True: space
# Test 664 Predicted: religion | True: space
# Test 665 Predicted: space | True: religion
# Test 666 Predicted: space | True: space
# Test 667 Predicted: space | True: space
# Test 668 Predicted: space | True: space
# Test 669 Predicted: religion | True: space
# Test 670 Predicted: moto | True: moto
# Test 671 Predicted: space | True: religion
# Test 672 Predicted: religion | True: space
# Test 673 Predicted: space | True: religion
# Test 674 Predicted: space | True: religion
# Test 675 Predicted: space | True: religion
# Test 676 Predicted: space | True: space
# Test 677 Predicted: space | True: space
# Test 678 Predicted: religion | True: space
# Test 679 Predicted: space | True: space
# Test 680 Predicted: religion | True: space
# Test 681 Predicted: space | True: religion
# Test 682 Predicted: moto | True: moto
# Test 683 Predicted: space | True: space
# Test 684 Predicted: moto | True: moto
# Test 685 Predicted: space | True: religion
# Test 686 Predicted: moto | True: moto
# Test 687 Predicted: space | True: religion
# Test 688 Predicted: space | True: moto
# Test 689 Predicted: space | True: moto
# Test 690 Predicted: space | True: space
# Test 691 Predicted: moto | True: religion
# Test 692 Predicted: space | True: moto
# Test 693 Predicted: space | True: moto
# Test 694 Predicted: space | True: religion
# Test 695 Predicted: space | True: religion
# Test 696 Predicted: religion | True: space
# Test 697 Predicted: space | True: religion
# Test 698 Predicted: space | True: space
# Test 699 Predicted: moto | True: moto
# Test 700 Predicted: moto | True: moto
# Test 701 Predicted: space | True: religion
# Test 702 Predicted: space | True: moto
# Test 703 Predicted: religion | True: space
# Test 704 Predicted: moto | True: moto
# Test 705 Predicted: religion | True: space
# Test 706 Predicted: religion | True: space
# Test 707 Predicted: moto | True: moto
# Test 708 Predicted: religion | True: space
# Test 709 Predicted: space | True: religion
# Test 710 Predicted: space | True: space
# Test 711 Predicted: space | True: space
# Test 712 Predicted: space | True: moto
# Test 713 Predicted: space | True: religion
# Test 714 Predicted: space | True: religion
# Test 715 Predicted: religion | True: space
# Test 716 Predicted: space | True: moto
# Test 717 Predicted: space | True: religion
# Test 718 Predicted: space | True: religion
# Test 719 Predicted: space | True: space
# Test 720 Predicted: moto | True: moto
# Test 721 Predicted: space | True: religion
# Test 722 Predicted: space | True: space
# Test 723 Predicted: religion | True: space
# Test 724 Predicted: moto | True: moto
# Test 725 Predicted: space | True: religion
# Test 726 Predicted: space | True: space
# Test 727 Predicted: religion | True: space
# Test 728 Predicted: space | True: religion
# Test 729 Predicted: space | True: religion
# Test 730 Predicted: space | True: religion
# Test 731 Predicted: religion | True: space
# Test 732 Predicted: space | True: religion
# Test 733 Predicted: moto | True: moto
# Test 734 Predicted: space | True: religion
# Test 735 Predicted: space | True: space
# Test 736 Predicted: religion | True: space
# Test 737 Predicted: space | True: space
# Test 738 Predicted: space | True: religion
# Test 739 Predicted: religion | True: space
# Test 740 Predicted: space | True: space
# Test 741 Predicted: space | True: space
# Test 742 Predicted: space | True: religion
# Test 743 Predicted: moto | True: moto
# Test 744 Predicted: religion | True: space
# Test 745 Predicted: religion | True: space
# Test 746 Predicted: space | True: religion
# Test 747 Predicted: religion | True: space
# Test 748 Predicted: space | True: religion
# Test 749 Predicted: space | True: religion
# Test 750 Predicted: space | True: religion
# Test 751 Predicted: religion | True: religion
# Test 752 Predicted: space | True: moto
# Test 753 Predicted: religion | True: space
# Test 754 Predicted: moto | True: moto
# Test 755 Predicted: moto | True: moto
# Test 756 Predicted: religion | True: space
# Test 757 Predicted: space | True: moto
# Test 758 Predicted: religion | True: space
# Test 759 Predicted: space | True: space
# Test 760 Predicted: space | True: religion
# Test 761 Predicted: space | True: space
# Test 762 Predicted: space | True: moto
# Test 763 Predicted: religion | True: space
# Test 764 Predicted: space | True: space
# Test 765 Predicted: religion | True: space
# Test 766 Predicted: moto | True: moto
# Test 767 Predicted: religion | True: space
# Test 768 Predicted: space | True: religion
# Test 769 Predicted: space | True: religion
# Test 770 Predicted: space | True: religion
# Test 771 Predicted: religion | True: space
# Test 772 Predicted: space | True: space
# Test 773 Predicted: space | True: religion
# Test 774 Predicted: moto | True: moto
# Test 775 Predicted: space | True: space
# Test 776 Predicted: space | True: religion
# Test 777 Predicted: moto | True: moto
# Test 778 Predicted: space | True: moto
# Test 779 Predicted: space | True: religion
# Test 780 Predicted: religion | True: space
# Test 781 Predicted: space | True: religion
# Test 782 Predicted: space | True: moto
# Test 783 Predicted: space | True: religion
# Test 784 Predicted: space | True: space
# Test 785 Predicted: space | True: space
# Test 786 Predicted: space | True: religion
# Test 787 Predicted: space | True: religion
# Test 788 Predicted: religion | True: space
# Test 789 Predicted: space | True: religion
# Test 790 Predicted: religion | True: space
# Test 791 Predicted: moto | True: moto
# Test 792 Predicted: space | True: religion
# Test 793 Predicted: space | True: space
# Test 794 Predicted: space | True: religion
# Test 795 Predicted: space | True: religion
# Test 796 Predicted: space | True: religion
# Test 797 Predicted: space | True: space
# Test 798 Predicted: space | True: space
# Test 799 Predicted: moto | True: moto
# Test 800 Predicted: space | True: religion
# Test 801 Predicted: space | True: religion
# Test 802 Predicted: space | True: moto
# Test 803 Predicted: space | True: religion
# Test 804 Predicted: religion | True: space
# Test 805 Predicted: religion | True: space
# Test 806 Predicted: moto | True: moto
# Test 807 Predicted: space | True: religion
# Test 808 Predicted: space | True: religion
# Test 809 Predicted: moto | True: moto
# Test 810 Predicted: space | True: religion
# Test 811 Predicted: space | True: religion
# Test 812 Predicted: space | True: space
# Test 813 Predicted: space | True: religion
# Test 814 Predicted: moto | True: moto
# Test 815 Predicted: space | True: religion
# Test 816 Predicted: space | True: religion
# Test 817 Predicted: moto | True: space
# Test 818 Predicted: moto | True: religion
# Test 819 Predicted: space | True: religion
# Test 820 Predicted: religion | True: space
# Test 821 Predicted: space | True: space
# Test 822 Predicted: space | True: religion
# Test 823 Predicted: religion | True: space
# Test 824 Predicted: space | True: religion
# Test 825 Predicted: moto | True: moto
# Test 826 Predicted: religion | True: moto
# Test 827 Predicted: space | True: religion
# Test 828 Predicted: space | True: space
# Test 829 Predicted: space | True: religion
# Test 830 Predicted: space | True: religion
# Test 831 Predicted: space | True: space
# Test 832 Predicted: space | True: space
# Test 833 Predicted: space | True: space
# Test 834 Predicted: moto | True: religion
# Test 835 Predicted: space | True: space
# Test 836 Predicted: space | True: space
# Test 837 Predicted: space | True: moto
# Test 838 Predicted: space | True: religion
# Test 839 Predicted: space | True: moto
# Test 840 Predicted: religion | True: space
# Test 841 Predicted: space | True: religion
# Test 842 Predicted: space | True: space
# Test 843 Predicted: space | True: religion
# Test 844 Predicted: religion | True: space
# Test 845 Predicted: space | True: religion
# Test 846 Predicted: space | True: religion
# Test 847 Predicted: moto | True: moto
# Test 848 Predicted: space | True: space
# Test 849 Predicted: space | True: space
# Test 850 Predicted: space | True: religion
# Test 851 Predicted: space | True: religion
# Test 852 Predicted: space | True: religion
# Test 853 Predicted: religion | True: space
# Test 854 Predicted: space | True: religion
# Test 855 Predicted: space | True: religion
# Test 856 Predicted: moto | True: moto
# Test 857 Predicted: moto | True: moto
# Test 858 Predicted: space | True: space
# Test 859 Predicted: space | True: religion
# Test 860 Predicted: space | True: religion
# Test 861 Predicted: space | True: religion
# Test 862 Predicted: religion | True: space
# Test 863 Predicted: space | True: space
# Test 864 Predicted: space | True: religion
# Test 865 Predicted: religion | True: space
# Test 866 Predicted: religion | True: space
# Test 867 Predicted: space | True: religion
# Test 868 Predicted: space | True: religion
# Test 869 Predicted: space | True: moto
# Test 870 Predicted: space | True: moto
# Test 871 Predicted: space | True: moto
# Test 872 Predicted: space | True: religion
# Test 873 Predicted: space | True: religion
# Test 874 Predicted: space | True: religion
# Test 875 Predicted: space | True: religion
# Test 876 Predicted: space | True: space
# Test 877 Predicted: space | True: religion
# Test 878 Predicted: space | True: space
# Test 879 Predicted: space | True: religion
# Test 880 Predicted: space | True: moto
# Test 881 Predicted: space | True: religion
# Test 882 Predicted: space | True: space
# Test 883 Predicted: space | True: religion
# Test 884 Predicted: moto | True: moto
# Test 885 Predicted: space | True: space
# Test 886 Predicted: moto | True: moto
# Test 887 Predicted: space | True: space
# Test 888 Predicted: space | True: space
# Test 889 Predicted: space | True: religion
# Test 890 Predicted: space | True: religion
# Test 891 Predicted: space | True: religion
# Test 892 Predicted: moto | True: moto
# Test 893 Predicted: space | True: religion
# Test 894 Predicted: religion | True: religion
# Test 895 Predicted: moto | True: moto
# Test 896 Predicted: space | True: religion
# Test 897 Predicted: space | True: religion
# Test 898 Predicted: moto | True: moto
# Test 899 Predicted: space | True: moto
# Test 900 Predicted: religion | True: space
# Test 901 Predicted: space | True: religion
# Test 902 Predicted: religion | True: space
# Test 903 Predicted: space | True: religion
# Test 904 Predicted: space | True: space
# Test 905 Predicted: space | True: religion
# Test 906 Predicted: space | True: space
# Test 907 Predicted: space | True: moto
# Test 908 Predicted: space | True: religion
# Test 909 Predicted: religion | True: space
# Test 910 Predicted: space | True: space
# Test 911 Predicted: moto | True: moto
# Test 912 Predicted: space | True: religion
# Test 913 Predicted: space | True: moto
# Test 914 Predicted: space | True: religion
# Test 915 Predicted: space | True: religion
# Test 916 Predicted: moto | True: moto
# Test 917 Predicted: space | True: moto
# Test 918 Predicted: moto | True: moto
# Test 919 Predicted: space | True: space
# Test 920 Predicted: religion | True: space
# Test 921 Predicted: moto | True: religion
# Test 922 Predicted: moto | True: moto
# Test 923 Predicted: moto | True: moto
# Test 924 Predicted: space | True: religion
# Test 925 Predicted: space | True: space
# Test 926 Predicted: religion | True: space
# Test 927 Predicted: space | True: moto
# Test 928 Predicted: space | True: religion
# Test 929 Predicted: moto | True: moto
# Test 930 Predicted: moto | True: moto
# Test 931 Predicted: space | True: space
# Test 932 Predicted: space | True: moto
# Test 933 Predicted: space | True: religion
# Test 934 Predicted: space | True: religion
# Test 935 Predicted: moto | True: moto
# Test 936 Predicted: space | True: space
# Test 937 Predicted: religion | True: space
# Test 938 Predicted: space | True: moto
# Test 939 Predicted: space | True: religion
# Test 940 Predicted: religion | True: space
# Test 941 Predicted: moto | True: moto
# Test 942 Predicted: moto | True: moto
# Test 943 Predicted: space | True: space
# Test 944 Predicted: space | True: religion
# Test 945 Predicted: space | True: space
# Test 946 Predicted: space | True: religion
# Test 947 Predicted: space | True: religion
# Test 948 Predicted: moto | True: moto
# Test 949 Predicted: moto | True: moto
# Test 950 Predicted: religion | True: space
# Test 951 Predicted: religion | True: space
# Test 952 Predicted: religion | True: space
# Test 953 Predicted: space | True: space
# Test 954 Predicted: space | True: space
# Test 955 Predicted: space | True: religion
# Test 956 Predicted: moto | True: moto
# Test 957 Predicted: space | True: religion
# Test 958 Predicted: space | True: religion
# Test 959 Predicted: space | True: space
# Test 960 Predicted: space | True: religion
# Test 961 Predicted: space | True: religion
# Test 962 Predicted: religion | True: space
# Test 963 Predicted: religion | True: space
# Test 964 Predicted: space | True: moto
# Test 965 Predicted: space | True: religion
# Test 966 Predicted: space | True: moto
# Test 967 Predicted: space | True: religion
# Test 968 Predicted: space | True: moto
# Test 969 Predicted: moto | True: moto
# Test 970 Predicted: space | True: religion
# Test 971 Predicted: moto | True: moto
# Test 972 Predicted: space | True: religion
# Test 973 Predicted: space | True: religion
# Test 974 Predicted: religion | True: religion
# Test 975 Predicted: space | True: space
# Test 976 Predicted: religion | True: space
# Test 977 Predicted: space | True: moto
# Test 978 Predicted: space | True: religion
# Test 979 Predicted: moto | True: moto
# Test 980 Predicted: space | True: moto
# Test 981 Predicted: religion | True: space
# Test 982 Predicted: religion | True: space
# Test 983 Predicted: space | True: religion
# Test 984 Predicted: space | True: religion
# Test 985 Predicted: religion | True: space
# Test 986 Predicted: space | True: space
# Test 987 Predicted: space | True: religion
# Test 988 Predicted: religion | True: space
# Test 989 Predicted: space | True: space
# Test 990 Predicted: space | True: religion
# Test 991 Predicted: space | True: space
# Test 992 Predicted: space | True: space
# Test 993 Predicted: religion | True: space
# Test 994 Predicted: space | True: space
# Test 995 Predicted: space | True: space
# Test 996 Predicted: religion | True: space
# Test 997 Predicted: religion | True: space
# Test 998 Predicted: space | True: moto
# Test 999 Predicted: space | True: space
# Test 1000 Predicted: space | True: space
# Test 1001 Predicted: space | True: moto
# Test 1002 Predicted: space | True: religion
# Test 1003 Predicted: space | True: space
# Test 1004 Predicted: space | True: religion
# Test 1005 Predicted: space | True: space
# Test 1006 Predicted: moto | True: moto
# Test 1007 Predicted: space | True: space
# Test 1008 Predicted: space | True: space
# Test 1009 Predicted: space | True: religion
# Test 1010 Predicted: space | True: religion
# Test 1011 Predicted: space | True: space
# Test 1012 Predicted: space | True: religion
# Test 1013 Predicted: space | True: religion
# Test 1014 Predicted: religion | True: space
# Test 1015 Predicted: space | True: religion
# Test 1016 Predicted: moto | True: moto
# Test 1017 Predicted: space | True: religion
# Test 1018 Predicted: religion | True: space
# Test 1019 Predicted: moto | True: moto
# Test 1020 Predicted: space | True: religion
# Test 1021 Predicted: religion | True: space
# Test 1022 Predicted: religion | True: space
# Test 1023 Predicted: moto | True: moto
# Test 1024 Predicted: space | True: religion
# Test 1025 Predicted: space | True: religion
# Test 1026 Predicted: space | True: space
# Test 1027 Predicted: space | True: space
# Test 1028 Predicted: religion | True: space
# Test 1029 Predicted: space | True: space
# Test 1030 Predicted: space | True: space
# Test 1031 Predicted: space | True: religion
# Test 1032 Predicted: religion | True: space
# Test 1033 Predicted: space | True: religion
# Test 1034 Predicted: religion | True: religion
# Test 1035 Predicted: space | True: religion
# Test 1036 Predicted: space | True: space
# Test 1037 Predicted: religion | True: space
# Test 1038 Predicted: moto | True: moto
# Test 1039 Predicted: space | True: space
# Test 1040 Predicted: space | True: space
# Test 1041 Predicted: space | True: space
# Test 1042 Predicted: space | True: space
# Test Accuracy(%): 35.858101629913705

# %%
# Create confusion matrix
conf_matrix = confusion_matrix(test_true_labels, [tnames.index(label) for label in predicted_labels])

# Plot confusion matrix
sns.heatmap(conf_matrix.T, square=True, annot=True, fmt='d', cbar=False,
            xticklabels=tnames, yticklabels=tnames)
plt.xlabel('True Label')
plt.ylabel('Predicted Label')
plt.show()
