# %%
#IMPORT LIBRARY
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
from sklearn.metrics import confusion_matrix
from sklearn.datasets import fetch_20newsgroups

# %%
#FETCH DATA
data = fetch_20newsgroups()
categories = data.target_names
train = fetch_20newsgroups(subset='train', categories=categories)
test = fetch_20newsgroups(subset='test', categories=categories)

# %%
#MAKE A VOCA SET
vocab_set = set()
for dstr in train.data:
    words = dstr.lower().split()
    vocab_set.update(words)
new_vocab = list(vocab_set)

# %%
#CREATE DIC FOR STORING LOG_P
vocabcount_category = {category: {v: 0 for v in new_vocab} for category in categories}
vocab_logp_category = {category: {key: 0 for key in new_vocab} for category in categories}

# %%
vocab_logp_category
# Out:
# {'alt.atheism': {'coolant': 0,
#   's3,': 0,
#   '80186': 0,
#   'office.)': 0,
#   'reconsider.': 0,
#   'down-shifts.': 0,
#   '(301)227-1340': 0,
#   '(barium,': 0,
#   '"infamous,"': 0,
#   "malhz.i%!.h:1.chz.chz.lhz.ma!.fw*v,hz.m@z0=c8;=amv'/8/&t\\;6w*": 0,
#   'primordial': 0,
#   'doug.1993apr6.133257.14570': 0,
#   'year!!!!!': 0,
#   'reporter".': 0,
#   '_annals_': 0,
#   'maisonneuve': 0,
#   'agriculturalists.': 0,
#   '>>accurate': 0,
#   '139.': 0,
#   'tell)': 0,
#   "m.,!;%%=75u=75u=75u=75q1;6\\#`6q175u=7%%lx=77i!`3-*#d<'#dhs03.": 0,
#   'nice,': 0,
#   'diet,': 0,
#   '>f350': 0,
#   'perdition': 0,
#   'omitted.': 0,
#   '<jbc9+@andrew.cmu.edu>': 0,
#   'verschuldigde': 0,
#   'imately': 0,
#   '(glx': 0,
#   '-necessarily-': 0,
#   'inflammatory': 0,
#   'subsidises': 0,
#   '9..que': 0,
#   '(380': 0,
#   'parade': 0,
#   'xorg:': 0,
#   '<1qnav4$r3l@transfer.stratus.com>,': 0,
#   'unverzagt)': 0,
#   'greats': 0,
#   "c.b'1:l)j/9k2b/8": 0,
#   'organised': 0,
#   'flux.': 0,
#   '{se,': 0,
#   'xtclosedisplay().': 0,
#   'vf': 0,
#   'sharedx"': 0,
#   'simsh@rpi.edu': 0,
#   'serbs?': 0,
#   'lazer': 0,
#   '1-mar-93': 0,
#   "xbm's": 0,
#   'changed".': 0,
#   'head,"': 0,
#   '(america),': 0,
#   'anticipate': 0,
#   '<1qev18innnk7@early-bird.think.com>,': 0,
#   '<glenn@cs.utexas.edu>': 0,
#   'fil.sapienza@med.umich.edu': 0,
#   'staffan': 0,
#   'h.sync': 0,
#   'cents..': 0,
#   's)")': 0,
#   '>modems;': 0,
#   'nagorno-': 0,
#   'chiropractor.': 0,
#   's.edu': 0,
#   '>>>(given': 0,
#   '(megan@cs.uq.oz.au)': 0,
#   'm`>f/gwj4]8[#.oe&^b&*4^cgk%^q3@c1m+i\'6][ssg"u.[\'zy5^kvp@#6ho=': 0,
#   'disadvantage?': 0,
#   'mounting;': 0,
#   "states''.": 0,
#   'heterosexuals,': 0,
#   'confrontation.': 0,
#   'racing/motocycle': 0,
#   '778': 0,
#   '"xplaces"': 0,
#   '>mjs>you': 0,
#   '$2,899': 0,
#   'real--particularly': 0,
#   'dc,': 0,
#   '(1-800-338-0531).': 0,
#   'dcg6759@uxa.cso.uiuc.edu': 0,
#   'kazimir,': 0,
#   'konstantinople': 0,
#   'unlimited?': 0,
#   'jews!': 0,
#   'ellett)': 0,
#   '>conference': 0,
#   'turnbull': 0,
#   'shortage.': 0,
#   'vi-daevo-data,': 0,
#   'difinitive': 0,
#   '<steve@cs.hw.ac.uk>': 0,
#   'trachtenberg': 0,
#   'pnmconvol': 0,
#   'school....now': 0,
#   'bv>bidder?': 0,
#   'sorehand': 0,
#   'gambarian.': 0,
#   'gigabit': 0,
#   'licenseplatedatabase': 0,
#   'h(m).': 0,
#   'm(1hfr;q..a[:0)))=%m9^p)05xk87&h7"%s@=1z': 0,
#   "'psudo'": 0,
#   'canakkale': 0,
#   'beav)': 0,
#   'sympathies': 0,
#   '(big': 0,
#   'winthrop': 0,
#   "'throwing'": 0,
#   'wire-wrap': 0,
#   'mechanistic': 0,
#   'ever?': 0,
#   '*n-7*l/f4qf?6syk+)5ayzf,w_t?qj"e,mk;p]i2&3y,': 0,
#   'outcome': 0,
#   'evening-bird': 0,
#   '"velcro"': 0,
#   'minsky@media.mit.edu': 0,
#   'ae2000': 0,
#   'dad)': 0,
#   'ftp.ai.mit.edu': 0,
#   'mw.\'/i[vd?1y_0,o%j!_c39*1&6!le1:ro<;*$->%f!!#"1yv@-u0,<9/l</h': 0,
#   'line-in': 0,
#   'x(2$': 0,
#   'kaplow:': 0,
#   'agnostic': 0,
#   'cd:': 0,
#   '>pour': 0,
#   'o@6(': 0,
#   'hijaak.': 0,
#   'legged': 0,
#   'yy': 0,
#   '_mechanisms_.': 0,
#   'mknewman@blkbox.com': 0,
#   '`passwd': 0,
#   'novel': 0,
#   'sg@$@/lt->rramw7,\\ea#=![0?8q': 0,
#   'mcx_sc^?scx_gc_/scx_sy_./\\x^/c_/scx^/\\x^/c^?scx_gcx^/\\_/sc_/g': 0,
#   'three-fourths': 0,
#   '10011110b': 0,
#   'ninth-': 0,
#   'fits:': 0,
#   '<c4zwc0.6lk@acsu.buffalo.edu>': 0,
#   '1.0|1.1.2': 0,
#   'm4\\v7:m9[s;3c8w+1!jr/?7': 0,
#   'division/ncar,': 0,
#   '(10-': 0,
#   'hudel)': 0,
#   'barcelona': 0,
#   '(ahl).': 0,
#   'j3david@sms.business.uwo.ca': 0,
#   'priors': 0,
#   'technician,': 0,
#   '>>mike': 0,
#   '2:14-19.': 0,
#   'layer.': 0,
#   'babylonian': 0,
#   'fairgrounds.': 0,
#   '[israeli]': 0,
#   'startrek': 0,
#   'mtcv9`uz[*gk?1z4+"v;$q#&\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'': 0,
#   '1/10,000th': 0,
#   '>...even': 0,
#   'raisers,': 0,
#   'getbdf': 0,
#   'standby': 0,
#   'longer..': 0,
#   '90024-1596': 0,
#   'assenmacher': 0,
#   'emacs-style': 0,
#   'sunny,': 0,
#   '&w,': 0,
#   'survivour': 0,
#   '8c[fle==0-p=$-2hylqt/#0z': 0,
#   '.$00%m!0b!(mf&/qq?9:s;@': 0,
#   'rwf2@ns1.cc.lehigh.edu': 0,
#   'escrows': 0,
#   'at&tnet:': 0,
#   'past...': 0,
#   '"henrik': 0,
#   'bullcrap': 0,
#   'give-away': 0,
#   'castaways': 0,
#   "'at": 0,
#   'veritech': 0,
#   "#define'ed": 0,
#   'mx^/c27ocxte[xwocx^/c>te`x^/cxt#cx^-)2==`2>.%24gca>-`285w2>/c': 0,
#   'frank': 0,
#   'growth"': 0,
#   'csspab@mail-gw.ncsl.nist.gov,': 0,
#   'virtue.': 0,
#   'documented.': 0,
#   '>--gun': 0,
#   'many),': 0,
#   "'write'": 0,
#   "ups's": 0,
#   'reintegration': 0,
#   'ussell': 0,
#   'mcm%6%q(e)u3jg!wj[q[v#isrv0#jp_9p;-,=]y"v?z)': 0,
#   'mahsus': 0,
#   '<afi9shs00vohmrylee@andrew.cmu.edu>,': 0,
#   'vfr700': 0,
#   'wins)': 0,
#   '1600x1200x256': 0,
#   '>he-he.': 0,
#   'zurich': 0,
#   '4.04,': 0,
#   'farra': 0,
#   '4th-dimensional': 0,
#   'clamping': 0,
#   'pizza8.cs.itc.hp.com': 0,
#   'io.nosc.mil': 0,
#   'paller@fedunix.org,': 0,
#   '~scare': 0,
#   'm\\x^/y_/sy_-8\\x_sc^>/cx]8y^?g6/-8cx_s3ea8c^?s\\ub/c_./\\_-.3h]8': 0,
#   '...!{allegra,amd,hplabs,seismo,ut-ngp}!gatech!prism!re4': 0,
#   'profit,': 0,
#   '1.:': 0,
#   'setter': 0,
#   'proventil': 0,
#   'men".': 0,
#   'locle': 0,
#   'calibrator': 0,
#   'n.y.yankees,': 0,
#   '1243': 0,
#   'rfc-1421:': 0,
#   'powerful".': 0,
#   'anti-tax': 0,
#   'p00168@psilink.com': 0,
#   "max>'ax>'ax>'ax>'ax>'ax>'ax>'as$q,3'$q,3$q&8+i4??>giz*bj[7ey>": 0,
#   'spacewarn': 0,
#   '312-321-6830;': 0,
#   '"rambling': 0,
#   '>claire,': 0,
#   'buddy@optics.ece.wisc.edu': 0,
#   "max>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'!p$!*z-d\\<:q": 0,
#   'ptg2351@uxa.cso.uiuc.edu': 0,
#   '65201': 0,
#   '01001010b': 0,
#   '<1993apr12.235334.25031@ptdcs2.intel.com>': 0,
#   'gregory;': 0,
#   'sharan': 0,
#   'rfc-1423:': 0,
#   '1005.5': 0,
#   '..deleted...': 0,
#   '(#susanne': 0,
#   'written:': 0,
#   'modifications.': 0,
#   '#>that': 0,
#   'embers': 0,
#   'michael,': 0,
#   '(finland?)': 0,
#   'waldensoftware.': 0,
#   'action".': 0,
#   'lousier': 0,
#   'scriptur': 0,
#   '10100100b': 0,
#   'roehm': 0,
#   'dissaproves': 0,
#   'm6//sbea.3n?s\\ua86$[s3d[g6/-8y_-8\\txr\\_-.\\x].c_-.c_/gyub/6(].': 0,
#   '398-8236': 0,
#   'csm': 0,
#   "m/#q%em$\\t='1t3q%<y;1t=%%<ss11=%%145st466<t4\\/);1/'/1<t5s<t7=": 0,
#   '1346.3': 0,
#   'safe],': 0,
#   '7-3': 0,
#   'natural.': 0,
#   'antoine': 0,
#   'commandment?': 0,
#   '"type': 0,
#   'mechanisms,': 0,
#   'ashdown': 0,
#   '<1993apr14.144015.18175@vax5.cit.cornell.edu>': 0,
#   'possible': 0,
#   "(yn2&it,\\:'at8w(": 0,
#   'elijah.': 0,
#   '1923': 0,
#   'jameco,': 0,
#   "mclane's": 0,
#   'canvas(see': 0,
#   'recur': 0,
#   'chicken,': 0,
#   '415-962-0494': 0,
#   '35mm,': 0,
#   'brits': 0,
#   'message].': 0,
#   "'my'": 0,
#   'thermocouples': 0,
#   'mt-"xj2n>!w:$gjg`6x>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'': 0,
#   '(ikegami)': 0,
#   '[____@@@@@@____________________@@_______][------------------------------------]': 0,
#   'gis/remote': 0,
#   'society*,': 0,
#   '472;': 0,
#   'gsfc:': 0,
#   'b58$*!6@#h!wa?8lz!$@"d!kbc#': 0,
#   'hal.1r4cej$1jc8': 0,
#   'thus-and-so,': 0,
#   'whiney': 0,
#   'explain': 0,
#   '513bct,': 0,
#   '(124)': 0,
#   'deck,': 0,
#   'will,': 0,
#   'gap,': 0,
#   'championships",': 0,
#   'tfarrell@lynx.dac.northeastern.edu': 0,
#   '--after': 0,
#   '5."': 0,
#   'absol.absol.com!rsb@panix.com': 0,
#   'earth-based': 0,
#   '26*,': 0,
#   'quasars,': 0,
#   'pixmap8,': 0,
#   'collision.': 0,
#   '>>cal': 0,
#   '``public-key': 0,
#   'mj&^h;z@("`bhj&\\(j*@(j*aoj*bhj*bhj&^hj&]oj&\\5;q5o%14("`@("`@(': 0,
#   'offices.': 0,
#   '\\--------/': 0,
#   'sq': 0,
#   'above-mentioned': 0,
#   '-jon.': 0,
#   'winner4000': 0,
#   'triplets,': 0,
#   'alternator.': 0,
#   'dilemma.': 0,
#   'roenick': 0,
#   'alleviated': 0,
#   'archon': 0,
#   'undisputed.': 0,
#   'm>bj[n[m>7@.9f9f9`p,#`p,#`p->7kn[nrhj*biz>ghj*bhj*bhj*kn[7@,#': 0,
#   'management:': 0,
#   'potomac': 0,
#   'plkg_ltd@uhura.cc.rochester.edu': 0,
#   'entropic': 0,
#   'my^?g6.?s6//gy^?s\\tz/\\ub/y_./\\x_sctz/y_-8\\ua86(^/\\_./yx_gcx^/': 0,
#   'options?': 0,
#   'violations': 0,
#   'preach,': 0,
#   'counties': 0,
#   'smiling,': 0,
#   'takeshi)': 0,
#   'lacin': 0,
#   'anarch-cryptists': 0,
#   'splendidly.': 0,
#   'brew': 0,
#   'reed.1993apr21.032905.29286': 0,
#   '$379': 0,
#   'learn?': 0,
#   'audit': 0,
#   'timestep': 0,
#   "delorme's": 0,
#   'manual."': 0,
#   'mv-c8rmc*.fw8v#ho.b_8.lk8.mc8rlhormc*;<hzv#ho.ck8+sk*.b\\ov#k8': 0,
#   '"start': 0,
#   "nazi's": 0,
#   'digitizedlength': 0,
#   'graphics_exposures': 0,
#   'mach32': 0,
#   '*ximage;': 0,
#   'bibles': 0,
#   '27-28': 0,
#   'xchongo': 0,
#   'tdk)': 0,
#   'gun-talk': 0,
#   '4meg': 0,
#   'scepticism;': 0,
#   'vision.': 0,
#   'helpimontreal': 0,
#   '(310)420-9327': 0,
#   'denktas': 0,
#   '(respective': 0,
#   'aksin,': 0,
#   '(265ms)': 0,
#   'provider': 0,
#   'stamber': 0,
#   'pocock@math.utah.edu': 0,
#   'jiggles.': 0,
#   'comparision': 0,
#   'puzzlement.': 0,
#   'theorie': 0,
#   '<7480237@hpfcso.fc.hp.com>': 0,
#   '227.': 0,
#   'proliferation': 0,
#   '>inadequate': 0,
#   'jv': 0,
#   'releases."': 0,
#   'thinner': 0,
#   'page-mode': 0,
#   'suter)': 0,
#   'milligrams': 0,
#   '/>on': 0,
#   'processor?': 0,
#   "'a'.": 0,
#   'ignore': 0,
#   "posting'": 0,
#   '>heck': 0,
#   'anvance.': 0,
#   'excise': 0,
#   'surfmodel': 0,
#   'weave,': 0,
#   'xyz': 0,
#   '>tough': 0,
#   "m_7d@o<6u:5k;xmi:%!/'$<^faq4;[#7": 0,
#   'j-4': 0,
#   're-entry': 0,
#   '16339': 0,
#   '>settlement': 0,
#   'james.mollica%pics@twwells.com': 0,
#   '<12426@sun13.scri.fsu.edu>': 0,
#   'garbled': 0,
#   '>>unless': 0,
#   '|>it': 0,
#   'srg3sir@grv.grace.cri.nz': 0,
#   'trappings...': 0,
#   'mbhd,': 0,
#   'selectionrequest': 0,
#   'winter,': 0,
#   '>truth': 0,
#   '<[@f&[wv^fo)>bx2#': 0,
#   'thinks/wants.': 0,
#   'unenfluenced': 0,
#   'germany!").': 0,
#   'naca': 0,
#   '"world"': 0,
#   '"team",': 0,
#   '$$$$),': 0,
#   'distance)?': 0,
#   'started,': 0,
#   'exile': 0,
#   'selfserving': 0,
#   'reimer)': 0,
#   'kenny)': 0,
#   'js1@isis.msstate.edu': 0,
#   "m-#0t-#0t-#0t-#0t-#1z>gizw]]'1t='1t='wt='i:4+9l3$,3$q,3$qq,3$": 0,
#   'burglars,': 0,
#   'htanabe@ponder.csci.unt.edu': 0,
#   '(contents)': 0,
#   "p-(#'h": 0,
#   '&"#u(q;p;_[$w?5o$\']x\\': 0,
#   'post-conditions': 0,
#   '4fge': 0,
#   'inexact': 0,
#   "m6q2'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'": 0,
#   "'xdpyinfo'": 0,
#   'non-winner': 0,
#   'flashflood.cs.odu.edu': 0,
#   'beretta.': 0,
#   'really?': 0,
#   'g+g': 0,
#   '(pete@egh-qc.co.uk);': 0,
#   'aantal_snijpunten,': 0,
#   'dejesus': 0,
#   '\\|p3': 0,
#   'hbcr-2010': 0,
#   'cpus?': 0,
#   'crucifix.': 0,
#   '[oy]': 0,
#   'm"`@("`@("`@("`a]?72znazz75t>?7t("`@("`@("`@("`@("`@("`@("`@(': 0,
#   'contributions.': 0,
#   'vector-valued': 0,
#   'yielded': 0,
#   '],m/j2om0$!h@"tm>$@': 0,
#   'identity:': 0,
#   '90064': 0,
#   "jumpers'": 0,
#   'phishnet:': 0,
#   'his/': 0,
#   'peri)': 0,
#   'display}.': 0,
#   '>>monitor': 0,
#   'isaiah,': 0,
#   '>4': 0,
#   '6th': 0,
#   'azathioprine.': 0,
#   '<raveling@venera.isi.edu>,': 0,
#   '>@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@': 0,
#   'narinian,': 0,
#   'collection*,': 0,
#   '>production.': 0,
#   'russian/czech/etc': 0,
#   'willis"': 0,
#   'ry:c+a*(3(!q[[_t3%-6?7<"?_jl5j;6s67v0j': 0,
#   '6h#3c$(4.:c=j@': 0,
#   'righthanded,': 0,
#   'sheathed': 0,
#   'timor': 0,
#   "m%a86%a86%a86%a86%a;)r<g)b8e,#v<tb^vp&=*97bk?i6;$ax>'ax>'ax>'": 0,
#   'enc': 0,
#   '@(*^o"z\\+"pl+"pl+"xyg!xxb': 0,
#   'homeopaths,': 0,
#   'accgsg@hofstra.bitnet': 0,
#   'network.1ps4a8$oi3': 0,
#   'mispresented.': 0,
#   '"common': 0,
#   '|not': 0,
#   'getgeometry': 0,
#   '508-263-6437': 0,
#   'christian': 0,
#   'substance)': 0,
#   'ariyak,': 0,
#   'economists': 0,
#   '2444': 0,
#   'done),': 0,
#   'griffey': 0,
#   '"humanism").': 0,
#   'beckhaus)': 0,
#   'whatever)': 0,
#   'ellens@bnr.ca': 0,
#   'samosota,': 0,
#   'cview,': 0,
#   '-board': 0,
#   'volvo).': 0,
#   '>128': 0,
#   'movers': 0,
#   'x11r5/mwm.': 0,
#   'bobby-': 0,
#   'td@alice.uucp': 0,
#   "`gentlemen',": 0,
#   '#>faith",': 0,
#   'changer:': 0,
#   '(perganol,': 0,
#   'auteur': 0,
#   'fd/hd': 0,
#   'freethought.': 0,
#   '_national': 0,
#   'gassed.': 0,
#   'quad4s?': 0,
#   'thester@nyx.cs.du.edu': 0,
#   'non-va_list': 0,
#   'meaning.': 0,
#   'citizen"?': 0,
#   'propounds': 0,
#   '04-01': 0,
#   '+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++': 0,
#   'carve': 0,
#   '(801)750-3268': 0,
#   '4.:': 0,
#   'webb@itu1': 0,
#   'globular/spherical.': 0,
#   'report",': 0,
#   'mouthings."': 0,
#   '>gm': 0,
#   "animals'": 0,
#   '(selfish)': 0,
#   'paper.': 0,
#   'est).': 0,
#   'replace.': 0,
#   'dunno...': 0,
#   '>>that': 0,
#   'tract,': 0,
#   '(33': 0,
#   'genome': 0,
#   "sandberg's.": 0,
#   'alavi)': 0,
#   'jtozer@sdcc3.ucsd.edu': 0,
#   'demonstrably': 0,
#   'dsg,': 0,
#   'arriving.': 0,
#   'w20-575-72.mit.edu': 0,
#   '<1qjmf6$d0i@sixgun.east.sun.com>': 0,
#   'essays': 0,
#   'smiling': 0,
#   'mcs213c.cs.umr.edu': 0,
#   '>>disagrees': 0,
#   'knowable': 0,
#   'xtsetarg(args[n],xtnusestringinplace,true);': 0,
#   'stressed': 0,
#   'ñaustin': 0,
#   '300kb': 0,
#   'phono-plug-to-optical': 0,
#   'acsys,': 0,
#   'prophtets.': 0,
#   '<1q1jshinn4v1@rodan.uu.net>:': 0,
#   '(mit-shm).': 0,
#   'pem-dev-request@tis.com.': 0,
#   'wreck.motorcycles?': 0,
#   'm$[rk#9_,s#f<x0i67,va&%pp?!b;,#";,%:m&g)rmzvmmv^m%:w+u-2-$.^$': 0,
#   ':sivap-s@cs.buffalo.edu': 0,
#   'mo:?@mej]i[e:o1"]#(>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'': 0,
#   'edowdy@vax1.umkc.edu': 0,
#   'suspiciously': 0,
#   '148k': 0,
#   '110': 0,
#   'attr;': 0,
#   'xtpointer)': 0,
#   'lockable': 0,
#   'q1:': 0,
#   '"followup-to"': 0,
#   'orc': 0,
#   'lumpkin': 0,
#   'jahn': 0,
#   'lip"': 0,
#   'pellets.': 0,
#   'predictor,': 0,
#   '>provokes': 0,
#   'm3$q,3$r)b8f)3$r)b8f)b8f)b8g)r<g)r<g)r<d6%a86%a86%a86%a86%a86': 0,
#   'ray-traces': 0,
#   'g&c': 0,
#   'billson)': 0,
#   'arrogance': 0,
#   '==========================': 0,
#   'number=3,': 0,
#   'typing-injury-faq/software': 0,
#   "'latter'": 0,
#   "`nameservers';": 0,
#   "mv%cm;[y)a?ycw^9??jm_0y*_x3^+1>'zwp4q<": 0,
#   'slash-cut': 0,
#   'w/200': 0,
#   'antarctic.': 0,
#   'month...': 0,
#   'm<ah:<a-2e3,k8z$**s,hh8%6,&\'-ikz:(fc!+a"q:*r;lyhp,%8:)ahf&g)r': 0,
#   'omnipotency': 0,
#   'coverpage):': 0,
#   '/-|-\\': 0,
#   'akerman@bill.phy.queensu.ca': 0,
#   '(art@cs.ualberta.ca);': 0,
#   'pseudoprime': 0,
#   'async': 0,
#   '33mhz,': 0,
#   'gf': 0,
#   'tactix': 0,
#   'pistol;': 0,
#   'kenny.': 0,
#   '10%': 0,
#   'kms': 0,
#   'backroad': 0,
#   '|at': 0,
#   'arrogance.': 0,
#   'mq<7%q30t-#0t-#0t-#0t-(n+bxn+bxn+bxn+bxn+bxn+bxn+bxn+bxlt-#0t': 0,
#   '(rthomson@dsd.es.com)': 0,
#   'pela.': 0,
#   'hairenik,': 0,
#   '(2-2-2,': 0,
#   'venkateswar': 0,
#   'adequate.': 0,
#   '**of': 0,
#   'cb750)': 0,
#   'multi-strategy': 0,
#   'm>ry+9l%(>t_[mv#r0s': 0,
#   '1177.4': 0,
#   "mu-34:]34u-34;fz0$7q65lq1]5$w5e967%q<7%q<7%q65e:_ovg'd36&q[]i": 0,
#   'tait)': 0,
#   'host': 0,
#   'or=6.0;': 0,
#   '787': 0,
#   'gun-legislation.': 0,
#   'ilmenau': 0,
#   '(nlpers': 0,
#   'interantional': 0,
#   'm$pu1s.%d\\64b[[;oo;6q.xe,3&=&-c84hm2`7prv?m3j7t,=:!v`p2&l[.s!': 0,
#   'care.': 0,
#   'door)': 0,
#   'reichenbach,': 0,
#   '>fanged': 0,
#   'partial.': 0,
#   'buses': 0,
#   'artistic': 0,
#   "patty's": 0,
#   'neccities': 0,
#   'enhancement': 0,
#   '50pin': 0,
#   'patches,': 0,
#   'cory.berkeley.edu': 0,
#   '(wscrawl)': 0,
#   '(mst3k#17': 0,
#   'wa6omi': 0,
#   'gringort@tantalus.pa.dec.com': 0,
#   'besarkatu': 0,
#   'coincided': 0,
#   '"rent"': 0,
#   '(bulent': 0,
#   'bigshot.': 0,
#   'fati,': 0,
#   'ml5(#gj&5f&z75pnq': 0,
#   '1.44mb).': 0,
#   'intercession': 0,
#   'outraged.': 0,
#   'deportees,': 0,
#   'two;': 0,
#   '28:1ff,': 0,
#   'tread.': 0,
#   "paper's,": 0,
#   'walveranta)': 0,
#   'wingdings)': 0,
#   'beirut,': 0,
#   'personalize': 0,
#   'expressivity.': 0,
#   '<1993apr16.001321.3692@natasha.portal.com>': 0,
#   'me55a': 0,
#   '<>constitution.': 0,
#   "7*v6'!p=_c6": 0,
#   'apostles.': 0,
#   'sanguine/choleric/melencholic/phlegmatic': 0,
#   "bureaucrat's": 0,
#   'lagged': 0,
#   "-'=isfuap8": 0,
#   'peredo)': 0,
#   'ever."': 0,
#   'cherokee': 0,
#   ':details,': 0,
#   '6:17': 0,
#   'anyways???': 0,
#   'practise': 0,
#   'driveway?': 0,
#   'zane!!rescue': 0,
#   'non-removable.': 0,
#   '617/981-2575': 0,
#   'axp': 0,
#   'observer)': 0,
#   '(1.04)^65': 0,
#   "m-(om4[`9&7'2tm(]f0-,3$q,3$q,3$q,3$q,3$q,3$r)3$q,3$q,#v=g9\\7%": 0,
#   'countersteering.': 0,
#   '>mccullou@snake2.cs.wisc.edu': 0,
#   'xchess': 0,
#   'graeme>': 0,
#   'visits.': 0,
#   'max>\'ax>\'ax>\'ax>\'ax>\'a\\!;p#au)75u=24e)3c`;fzntq"qs]17r%=7u%>`': 0,
#   'flopticals': 0,
#   '000773b9': 0,
#   'yulaev': 0,
#   'jarkko': 0,
#   '108)': 0,
#   'ld++': 0,
#   'illustrator?': 0,
#   'starvation,': 0,
#   'azerbadjan)': 0,
#   '>good': 0,
#   'corollary:': 0,
#   'rubberband': 0,
#   'rsa': 0,
#   'socialism': 0,
#   'brosnan': 0,
#   'mm2e"e@^h:j0#y%93)+ni#7)0.pmgnd><.)d': 0,
#   'kaan,timucin': 0,
#   '4100': 0,
#   'wast': 0,
#   'flakes': 0,
#   'u-turn': 0,
#   'beemers.': 0,
#   'extremist,': 0,
#   '>>morris': 0,
#   'carbon/kevlar': 0,
#   'boost...': 0,
#   '10666': 0,
#   '0.200': 0,
#   '"fusetron")': 0,
#   '#actually,': 0,
#   'armed.': 0,
#   '136,739,000': 0,
#   '(harry': 0,
#   'mayflies,': 0,
#   'hci-newsletter': 0,
#   '300k': 0,
#   '>goaltending': 0,
#   'shocks': 0,
#   '1:376/74.0': 0,
#   'verse?': 0,
#   '16187': 0,
#   'm5g*5>5".3galale': 0,
#   'uname);': 0,
#   'does,': 0,
#   '<cliu@silver.ucs.indiana.edu>': 0,
#   'kid?': 0,
#   'vorld': 0,
#   'maryland.': 0,
#   'arsenaul@ere.umontreal.ca': 0,
#   '17.14-21,': 0,
#   'true??/': 0,
#   '<1993apr2.212405.5213@head-cfa.harvard.edu>': 0,
#   '375': 0,
#   '.074': 0,
#   '.forward': 0,
#   'public-interest': 0,
#   'die!"': 0,
#   'twelve,': 0,
#   'phi,incaviglia': 0,
#   '24:4-14).': 0,
#   'opto-isolators': 0,
#   'whic': 0,
#   'max>\'ax>\'ax>\'ax>\'ax=qtcv9f0.[*gk?wt>e"pmfq,0qax>\'ax>\'ax>\'ax>\'': 0,
#   'pooltable': 0,
#   'utah).': 0,
#   "howen's": 0,
#   'reactions).': 0,
#   'matyas,': 0,
#   'tremor.': 0,
#   'movements': 0,
#   'vigilantism.': 0,
#   'm)"36ui_>]?7>g]8d)"1j:fij:fij:j"@khb(-c8v:vl)"0g/"0ek-c9n;mg9': 0,
#   'jacobson': 0,
#   'colombo@bronco.fnal.gov': 0,
#   'benz..': 0,
#   'traitorously': 0,
#   '20:52': 0,
#   '(essential)': 0,
#   '14:40:15': 0,
#   '>meter.': 0,
#   'distinguishing': 0,
#   'play,': 0,
#   '"braves': 0,
#   'pa-2': 0,
#   'hydra.rose-hulman.edu': 0,
#   '(speed': 0,
#   '*win;': 0,
#   'heederik,': 0,
#   'n.t.': 0,
#   'dyanimic': 0,
#   '(efficency': 0,
#   '[arnie]': 0,
#   'technician(dr.': 0,
#   '1kspt=17.28%': 0,
#   '<jrobbins.93apr15103031@kingston.cs.ucla.edu>': 0,
#   'folta@zen.holonet.net': 0,
#   'contagiosem.': 0,
#   '<1483500355@igc.apc.org>': 0,
#   "mi:4+q#&'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'": 0,
#   'lodges': 0,
#   'nanny-nanny-boo-boo': 0,
#   'push,': 0,
#   'maidenhead,': 0,
#   'stacks=10,256': 0,
#   '(processor': 0,
#   'boltzman': 0,
#   'g-3,': 0,
#   'applicable.': 0,
#   'portugals': 0,
#   'mqbnaiqxytkaaaecalfehyp0yc80s1scfvjspj5escao+hihtnefrrn+vuecsavh': 0,
#   'wilkes-barre,': 0,
#   'stinks,': 0,
#   'darkness': 0,
#   'disclaimer,': 0,
#   '(hans': 0,
#   '<p00421@psilink.com>': 0,
#   'server"': 0,
#   'alcohol,': 0,
#   '`sports': 0,
#   '>thirdly': 0,
#   '>capability,': 0,
#   '>carcinogens': 0,
#   'boast': 0,
#   'nuclear.med.bcm.tmc.edu': 0,
#   'iud': 0,
#   'xtlasttimestampprocessed()': 0,
#   'landmarks': 0,
#   'errr....': 0,
#   'woofing!': 0,
#   'oofgm,': 0,
#   'mistaken,': 0,
#   "m71y]+'u]?7tlngvz'gu=pkjz)k)=)eu=)etflkhfnkhf)ah:lahf<k)r<b:z": 0,
#   'mx^-[x^/cxxi[x^-[bn/cbdf*xxj*>tgcbn/c>s+cxxkcxxj*xwocxwlrxxkc': 0,
#   '>attributes.': 0,
#   '/\\/\\artin': 0,
#   'buckle': 0,
#   '50b/2239': 0,
#   'alludes': 0,
#   "max>'ax>'wb>?@=;6um;6um;6um;6um;6um;6um;6um;6um;6um;6uh&!@8'6": 0,
#   "mu-34r!045u=75z);p'4x.'6>gi[-*&!@gy\\w`2lks<w-4%!04%!04%!04%!0": 0,
#   'cobol;': 0,
#   'devvax.jpl.nasa.gov)': 0,
#   'rpi.zss56vm': 0,
#   'freon': 0,
#   'swissnet': 0,
#   'meetings..': 0,
#   'ices.': 0,
#   '"ferigner"': 0,
#   'pins,': 0,
#   'independence.': 0,
#   '/s': 0,
#   'startled..and': 0,
#   'dissipate?': 0,
#   'fact-finding': 0,
#   '13255,': 0,
#   'steel-o-': 0,
#   '$.50': 0,
#   '>involved': 0,
#   '(ghz)......': 0,
#   'tichauer"': 0,
#   "m@0;t@8s6ax>'ax>'az:f@^3/5\\@%2j`ej>0g8&!1'.o>45'ujpwu46!1#5%1": 0,
#   'spit': 0,
#   '"xl"': 0,
#   'nightfall': 0,
#   '(_)/(_)': 0,
#   '>gilmour': 0,
#   "m%a86%lg)r<g)b8f)b8f)3$p/q32+[5.pl!eqtcv9`uz[nriz1z5fq#&'ax>'": 0,
#   'mingle': 0,
#   'incandescent': 0,
#   'paedophilia': 0,
#   'patti,': 0,
#   'sovereignty': 0,
#   'konfessionslosen': 0,
#   '>>religions.': 0,
#   'b@+g5ar;]**#n;huv^@$': 0,
#   '10c': 0,
#   '>(pope': 0,
#   '>forty-two': 0,
#   'affairs.': 0,
#   'tirelessly.': 0,
#   'm*h8@2m><\']"<2!><j)$afppc0eg\'wg$pl': 0,
#   'davis,': 0,
#   'staring': 0,
#   'rationalistic.': 0,
#   'soundtool,': 0,
#   'ma2<t830t-#1g0!j4091a': 0,
#   'mcnab': 0,
#   '6819@sol.ctr.columbia.edu,': 0,
#   '.drw': 0,
#   'ns16550af,': 0,
#   'd<\\n^),5s)(h3rpp': 0,
#   'lethal.': 0,
#   'specialists...': 0,
#   'axe,': 0,
#   '\\\\-\\dave': 0,
#   'stanza,': 0,
#   'su-27': 0,
#   '2nd,...': 0,
#   'cavgeoe@yalevm.ycc.yale.': 0,
#   '1m3l(t:=-.@tsq\'4d#\\/:ip310p01)p#[ca.@2@"*(4=y': 0,
#   'magnesium:calcium': 0,
#   '>galaxy': 0,
#   '>>>always': 0,
#   'revelant).': 0,
#   'carlos@carlos.uucp': 0,
#   'top': 0,
#   'judea,': 0,
#   '"months': 0,
#   'present_,': 0,
#   '#15/15': 0,
#   'carbon-nitrogen-oxygen': 0,
#   '>>listen': 0,
#   'gts1000': 0,
#   'perihelions': 0,
#   'rik.': 0,
#   'suiss,': 0,
#   'ray_whitney': 0,
#   'belliard': 0,
#   'smartdrv,': 0,
#   'dot-3': 0,
#   'to."': 0,
#   'warner': 0,
#   'treatment?': 0,
#   'm@("`@*jjjc8vh^[n[@<\'!udy.1p<\'!py.3f7.6!1]?51s#<w!@8d"@h*)"0d': 0,
#   'hst.': 0,
#   'willdye@helios.unl.edu': 0,
#   'statues,': 0,
#   'rosa@ghost.dsi.unimi.it': 0,
#   'pillsbury': 0,
#   '>>primary': 0,
#   'dense.': 0,
#   'prisons]': 0,
#   '(68)': 0,
#   '1.1': 0,
#   'callihan"': 0,
#   'm867r[6;]7&;rhhlmjp<0u\'xk^@su"/4(]1gj=z@_4]j=*+/!d:*>hny$i0u5': 0,
#   'mra': 0,
#   "m$q,3$[qv=g9v4c,sax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'": 0,
#   'stifling': 0,
#   'pb.': 0,
#   '(212mb).': 0,
#   '(harleys,': 0,
#   'unpublished': 0,
#   'depression;': 0,
#   'baud,': 0,
#   'hackett': 0,
#   'forsale,': 0,
#   "harris'": 0,
#   'mmh:': 0,
#   '\\$<!6t+h:>=5]%[s/]': 0,
#   'xview...': 0,
#   'have)': 0,
#   'judeo-': 0,
#   'serf': 0,
#   'dobbin,': 0,
#   'm"`@("`@("`@("`@("`@("`@("`@("`@("`@("`@("`@("`@("`@("`@(;v\\5': 0,
#   'old-earth': 0,
#   'provide...).': 0,
#   'stafford@vax2.winona.msus.edu': 0,
#   'mf;+nc*u_!6pg%?>y)i)s\'hh:gw<&2ubdt;%_*>uk8"4[v1g%;&(-u,ly!y8p': 0,
#   'saw.': 0,
#   'distinctive': 0,
#   'turkish.': 0,
#   'snide': 0,
#   '-n)y[<3u&j@<,6">u_.a2dpn/)b&")](y+[z;=.#\\q?x906:h,t>3c(d*': 0,
#   'hp-9000,': 0,
#   "'djul": 0,
#   '(quality)': 0,
#   'subsampling': 0,
#   'olsen': 0,
#   'carbonneau': 0,
#   'tds32845@uxa.cso.uiuc.edu': 0,
#   'don.hancock@f303.n105.z1.fidonet.org': 0,
#   '==========================================================================': 0,
#   "m#f/((<4*p?'_70d((4!'/&e;'.q76?0jb6pwzasj$hc0": 0,
#   '(1787),': 0,
#   'sating': 0,
#   'neurons.': 0,
#   'not-so-quick': 0,
#   ...},
#  'comp.graphics': {'coolant': 0,
#   's3,': 0,
#   '80186': 0,
#   'office.)': 0,
#   'reconsider.': 0,
#   'down-shifts.': 0,
#   '(301)227-1340': 0,
#   '(barium,': 0,
#   '"infamous,"': 0,
#   "malhz.i%!.h:1.chz.chz.lhz.ma!.fw*v,hz.m@z0=c8;=amv'/8/&t\\;6w*": 0,
#   'primordial': 0,
#   'doug.1993apr6.133257.14570': 0,
#   'year!!!!!': 0,
#   'reporter".': 0,
#   '_annals_': 0,
#   'maisonneuve': 0,
#   'agriculturalists.': 0,
#   '>>accurate': 0,
#   '139.': 0,
#   'tell)': 0,
#   "m.,!;%%=75u=75u=75u=75q1;6\\#`6q175u=7%%lx=77i!`3-*#d<'#dhs03.": 0,
#   'nice,': 0,
#   'diet,': 0,
#   '>f350': 0,
#   'perdition': 0,
#   'omitted.': 0,
#   '<jbc9+@andrew.cmu.edu>': 0,
#   'verschuldigde': 0,
#   'imately': 0,
#   '(glx': 0,
#   '-necessarily-': 0,
#   'inflammatory': 0,
#   'subsidises': 0,
#   '9..que': 0,
#   '(380': 0,
#   'parade': 0,
#   'xorg:': 0,
#   '<1qnav4$r3l@transfer.stratus.com>,': 0,
#   'unverzagt)': 0,
#   'greats': 0,
#   "c.b'1:l)j/9k2b/8": 0,
#   'organised': 0,
#   'flux.': 0,
#   '{se,': 0,
#   'xtclosedisplay().': 0,
#   'vf': 0,
#   'sharedx"': 0,
#   'simsh@rpi.edu': 0,
#   'serbs?': 0,
#   'lazer': 0,
#   '1-mar-93': 0,
#   "xbm's": 0,
#   'changed".': 0,
#   'head,"': 0,
#   '(america),': 0,
#   'anticipate': 0,
#   '<1qev18innnk7@early-bird.think.com>,': 0,
#   '<glenn@cs.utexas.edu>': 0,
#   'fil.sapienza@med.umich.edu': 0,
#   'staffan': 0,
#   'h.sync': 0,
#   'cents..': 0,
#   's)")': 0,
#   '>modems;': 0,
#   'nagorno-': 0,
#   'chiropractor.': 0,
#   's.edu': 0,
#   '>>>(given': 0,
#   '(megan@cs.uq.oz.au)': 0,
#   'm`>f/gwj4]8[#.oe&^b&*4^cgk%^q3@c1m+i\'6][ssg"u.[\'zy5^kvp@#6ho=': 0,
#   'disadvantage?': 0,
#   'mounting;': 0,
#   "states''.": 0,
#   'heterosexuals,': 0,
#   'confrontation.': 0,
#   'racing/motocycle': 0,
#   '778': 0,
#   '"xplaces"': 0,
#   '>mjs>you': 0,
#   '$2,899': 0,
#   'real--particularly': 0,
#   'dc,': 0,
#   '(1-800-338-0531).': 0,
#   'dcg6759@uxa.cso.uiuc.edu': 0,
#   'kazimir,': 0,
#   'konstantinople': 0,
#   'unlimited?': 0,
#   'jews!': 0,
#   'ellett)': 0,
#   '>conference': 0,
#   'turnbull': 0,
#   'shortage.': 0,
#   'vi-daevo-data,': 0,
#   'difinitive': 0,
#   '<steve@cs.hw.ac.uk>': 0,
#   'trachtenberg': 0,
#   'pnmconvol': 0,
#   'school....now': 0,
#   'bv>bidder?': 0,
#   'sorehand': 0,
#   'gambarian.': 0,
#   'gigabit': 0,
#   'licenseplatedatabase': 0,
#   'h(m).': 0,
#   'm(1hfr;q..a[:0)))=%m9^p)05xk87&h7"%s@=1z': 0,
#   "'psudo'": 0,
#   'canakkale': 0,
#   'beav)': 0,
#   'sympathies': 0,
#   '(big': 0,
#   'winthrop': 0,
#   "'throwing'": 0,
#   'wire-wrap': 0,
#   'mechanistic': 0,
#   'ever?': 0,
#   '*n-7*l/f4qf?6syk+)5ayzf,w_t?qj"e,mk;p]i2&3y,': 0,
#   'outcome': 0,
#   'evening-bird': 0,
#   '"velcro"': 0,
#   'minsky@media.mit.edu': 0,
#   'ae2000': 0,
#   'dad)': 0,
#   'ftp.ai.mit.edu': 0,
#   'mw.\'/i[vd?1y_0,o%j!_c39*1&6!le1:ro<;*$->%f!!#"1yv@-u0,<9/l</h': 0,
#   'line-in': 0,
#   'x(2$': 0,
#   'kaplow:': 0,
#   'agnostic': 0,
#   'cd:': 0,
#   '>pour': 0,
#   'o@6(': 0,
#   'hijaak.': 0,
#   'legged': 0,
#   'yy': 0,
#   '_mechanisms_.': 0,
#   'mknewman@blkbox.com': 0,
#   '`passwd': 0,
#   'novel': 0,
#   'sg@$@/lt->rramw7,\\ea#=![0?8q': 0,
#   'mcx_sc^?scx_gc_/scx_sy_./\\x^/c_/scx^/\\x^/c^?scx_gcx^/\\_/sc_/g': 0,
#   'three-fourths': 0,
#   '10011110b': 0,
#   'ninth-': 0,
#   'fits:': 0,
#   '<c4zwc0.6lk@acsu.buffalo.edu>': 0,
#   '1.0|1.1.2': 0,
#   'm4\\v7:m9[s;3c8w+1!jr/?7': 0,
#   'division/ncar,': 0,
#   '(10-': 0,
#   'hudel)': 0,
#   'barcelona': 0,
#   '(ahl).': 0,
#   'j3david@sms.business.uwo.ca': 0,
#   'priors': 0,
#   'technician,': 0,
#   '>>mike': 0,
#   '2:14-19.': 0,
#   'layer.': 0,
#   'babylonian': 0,
#   'fairgrounds.': 0,
#   '[israeli]': 0,
#   'startrek': 0,
#   'mtcv9`uz[*gk?1z4+"v;$q#&\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'': 0,
#   '1/10,000th': 0,
#   '>...even': 0,
#   'raisers,': 0,
#   'getbdf': 0,
#   'standby': 0,
#   'longer..': 0,
#   '90024-1596': 0,
#   'assenmacher': 0,
#   'emacs-style': 0,
#   'sunny,': 0,
#   '&w,': 0,
#   'survivour': 0,
#   '8c[fle==0-p=$-2hylqt/#0z': 0,
#   '.$00%m!0b!(mf&/qq?9:s;@': 0,
#   'rwf2@ns1.cc.lehigh.edu': 0,
#   'escrows': 0,
#   'at&tnet:': 0,
#   'past...': 0,
#   '"henrik': 0,
#   'bullcrap': 0,
#   'give-away': 0,
#   'castaways': 0,
#   "'at": 0,
#   'veritech': 0,
#   "#define'ed": 0,
#   'mx^/c27ocxte[xwocx^/c>te`x^/cxt#cx^-)2==`2>.%24gca>-`285w2>/c': 0,
#   'frank': 0,
#   'growth"': 0,
#   'csspab@mail-gw.ncsl.nist.gov,': 0,
#   'virtue.': 0,
#   'documented.': 0,
#   '>--gun': 0,
#   'many),': 0,
#   "'write'": 0,
#   "ups's": 0,
#   'reintegration': 0,
#   'ussell': 0,
#   'mcm%6%q(e)u3jg!wj[q[v#isrv0#jp_9p;-,=]y"v?z)': 0,
#   'mahsus': 0,
#   '<afi9shs00vohmrylee@andrew.cmu.edu>,': 0,
#   'vfr700': 0,
#   'wins)': 0,
#   '1600x1200x256': 0,
#   '>he-he.': 0,
#   'zurich': 0,
#   '4.04,': 0,
#   'farra': 0,
#   '4th-dimensional': 0,
#   'clamping': 0,
#   'pizza8.cs.itc.hp.com': 0,
#   'io.nosc.mil': 0,
#   'paller@fedunix.org,': 0,
#   '~scare': 0,
#   'm\\x^/y_/sy_-8\\x_sc^>/cx]8y^?g6/-8cx_s3ea8c^?s\\ub/c_./\\_-.3h]8': 0,
#   '...!{allegra,amd,hplabs,seismo,ut-ngp}!gatech!prism!re4': 0,
#   'profit,': 0,
#   '1.:': 0,
#   'setter': 0,
#   'proventil': 0,
#   'men".': 0,
#   'locle': 0,
#   'calibrator': 0,
#   'n.y.yankees,': 0,
#   '1243': 0,
#   'rfc-1421:': 0,
#   'powerful".': 0,
#   'anti-tax': 0,
#   'p00168@psilink.com': 0,
#   "max>'ax>'ax>'ax>'ax>'ax>'ax>'as$q,3'$q,3$q&8+i4??>giz*bj[7ey>": 0,
#   'spacewarn': 0,
#   '312-321-6830;': 0,
#   '"rambling': 0,
#   '>claire,': 0,
#   'buddy@optics.ece.wisc.edu': 0,
#   "max>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'!p$!*z-d\\<:q": 0,
#   'ptg2351@uxa.cso.uiuc.edu': 0,
#   '65201': 0,
#   '01001010b': 0,
#   '<1993apr12.235334.25031@ptdcs2.intel.com>': 0,
#   'gregory;': 0,
#   'sharan': 0,
#   'rfc-1423:': 0,
#   '1005.5': 0,
#   '..deleted...': 0,
#   '(#susanne': 0,
#   'written:': 0,
#   'modifications.': 0,
#   '#>that': 0,
#   'embers': 0,
#   'michael,': 0,
#   '(finland?)': 0,
#   'waldensoftware.': 0,
#   'action".': 0,
#   'lousier': 0,
#   'scriptur': 0,
#   '10100100b': 0,
#   'roehm': 0,
#   'dissaproves': 0,
#   'm6//sbea.3n?s\\ua86$[s3d[g6/-8y_-8\\txr\\_-.\\x].c_-.c_/gyub/6(].': 0,
#   '398-8236': 0,
#   'csm': 0,
#   "m/#q%em$\\t='1t3q%<y;1t=%%<ss11=%%145st466<t4\\/);1/'/1<t5s<t7=": 0,
#   '1346.3': 0,
#   'safe],': 0,
#   '7-3': 0,
#   'natural.': 0,
#   'antoine': 0,
#   'commandment?': 0,
#   '"type': 0,
#   'mechanisms,': 0,
#   'ashdown': 0,
#   '<1993apr14.144015.18175@vax5.cit.cornell.edu>': 0,
#   'possible': 0,
#   "(yn2&it,\\:'at8w(": 0,
#   'elijah.': 0,
#   '1923': 0,
#   'jameco,': 0,
#   "mclane's": 0,
#   'canvas(see': 0,
#   'recur': 0,
#   'chicken,': 0,
#   '415-962-0494': 0,
#   '35mm,': 0,
#   'brits': 0,
#   'message].': 0,
#   "'my'": 0,
#   'thermocouples': 0,
#   'mt-"xj2n>!w:$gjg`6x>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'': 0,
#   '(ikegami)': 0,
#   '[____@@@@@@____________________@@_______][------------------------------------]': 0,
#   'gis/remote': 0,
#   'society*,': 0,
#   '472;': 0,
#   'gsfc:': 0,
#   'b58$*!6@#h!wa?8lz!$@"d!kbc#': 0,
#   'hal.1r4cej$1jc8': 0,
#   'thus-and-so,': 0,
#   'whiney': 0,
#   'explain': 0,
#   '513bct,': 0,
#   '(124)': 0,
#   'deck,': 0,
#   'will,': 0,
#   'gap,': 0,
#   'championships",': 0,
#   'tfarrell@lynx.dac.northeastern.edu': 0,
#   '--after': 0,
#   '5."': 0,
#   'absol.absol.com!rsb@panix.com': 0,
#   'earth-based': 0,
#   '26*,': 0,
#   'quasars,': 0,
#   'pixmap8,': 0,
#   'collision.': 0,
#   '>>cal': 0,
#   '``public-key': 0,
#   'mj&^h;z@("`bhj&\\(j*@(j*aoj*bhj*bhj&^hj&]oj&\\5;q5o%14("`@("`@(': 0,
#   'offices.': 0,
#   '\\--------/': 0,
#   'sq': 0,
#   'above-mentioned': 0,
#   '-jon.': 0,
#   'winner4000': 0,
#   'triplets,': 0,
#   'alternator.': 0,
#   'dilemma.': 0,
#   'roenick': 0,
#   'alleviated': 0,
#   'archon': 0,
#   'undisputed.': 0,
#   'm>bj[n[m>7@.9f9f9`p,#`p,#`p->7kn[nrhj*biz>ghj*bhj*bhj*kn[7@,#': 0,
#   'management:': 0,
#   'potomac': 0,
#   'plkg_ltd@uhura.cc.rochester.edu': 0,
#   'entropic': 0,
#   'my^?g6.?s6//gy^?s\\tz/\\ub/y_./\\x_sctz/y_-8\\ua86(^/\\_./yx_gcx^/': 0,
#   'options?': 0,
#   'violations': 0,
#   'preach,': 0,
#   'counties': 0,
#   'smiling,': 0,
#   'takeshi)': 0,
#   'lacin': 0,
#   'anarch-cryptists': 0,
#   'splendidly.': 0,
#   'brew': 0,
#   'reed.1993apr21.032905.29286': 0,
#   '$379': 0,
#   'learn?': 0,
#   'audit': 0,
#   'timestep': 0,
#   "delorme's": 0,
#   'manual."': 0,
#   'mv-c8rmc*.fw8v#ho.b_8.lk8.mc8rlhormc*;<hzv#ho.ck8+sk*.b\\ov#k8': 0,
#   '"start': 0,
#   "nazi's": 0,
#   'digitizedlength': 0,
#   'graphics_exposures': 0,
#   'mach32': 0,
#   '*ximage;': 0,
#   'bibles': 0,
#   '27-28': 0,
#   'xchongo': 0,
#   'tdk)': 0,
#   'gun-talk': 0,
#   '4meg': 0,
#   'scepticism;': 0,
#   'vision.': 0,
#   'helpimontreal': 0,
#   '(310)420-9327': 0,
#   'denktas': 0,
#   '(respective': 0,
#   'aksin,': 0,
#   '(265ms)': 0,
#   'provider': 0,
#   'stamber': 0,
#   'pocock@math.utah.edu': 0,
#   'jiggles.': 0,
#   'comparision': 0,
#   'puzzlement.': 0,
#   'theorie': 0,
#   '<7480237@hpfcso.fc.hp.com>': 0,
#   '227.': 0,
#   'proliferation': 0,
#   '>inadequate': 0,
#   'jv': 0,
#   'releases."': 0,
#   'thinner': 0,
#   'page-mode': 0,
#   'suter)': 0,
#   'milligrams': 0,
#   '/>on': 0,
#   'processor?': 0,
#   "'a'.": 0,
#   'ignore': 0,
#   "posting'": 0,
#   '>heck': 0,
#   'anvance.': 0,
#   'excise': 0,
#   'surfmodel': 0,
#   'weave,': 0,
#   'xyz': 0,
#   '>tough': 0,
#   "m_7d@o<6u:5k;xmi:%!/'$<^faq4;[#7": 0,
#   'j-4': 0,
#   're-entry': 0,
#   '16339': 0,
#   '>settlement': 0,
#   'james.mollica%pics@twwells.com': 0,
#   '<12426@sun13.scri.fsu.edu>': 0,
#   'garbled': 0,
#   '>>unless': 0,
#   '|>it': 0,
#   'srg3sir@grv.grace.cri.nz': 0,
#   'trappings...': 0,
#   'mbhd,': 0,
#   'selectionrequest': 0,
#   'winter,': 0,
#   '>truth': 0,
#   '<[@f&[wv^fo)>bx2#': 0,
#   'thinks/wants.': 0,
#   'unenfluenced': 0,
#   'germany!").': 0,
#   'naca': 0,
#   '"world"': 0,
#   '"team",': 0,
#   '$$$$),': 0,
#   'distance)?': 0,
#   'started,': 0,
#   'exile': 0,
#   'selfserving': 0,
#   'reimer)': 0,
#   'kenny)': 0,
#   'js1@isis.msstate.edu': 0,
#   "m-#0t-#0t-#0t-#0t-#1z>gizw]]'1t='1t='wt='i:4+9l3$,3$q,3$qq,3$": 0,
#   'burglars,': 0,
#   'htanabe@ponder.csci.unt.edu': 0,
#   '(contents)': 0,
#   "p-(#'h": 0,
#   '&"#u(q;p;_[$w?5o$\']x\\': 0,
#   'post-conditions': 0,
#   '4fge': 0,
#   'inexact': 0,
#   "m6q2'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'": 0,
#   "'xdpyinfo'": 0,
#   'non-winner': 0,
#   'flashflood.cs.odu.edu': 0,
#   'beretta.': 0,
#   'really?': 0,
#   'g+g': 0,
#   '(pete@egh-qc.co.uk);': 0,
#   'aantal_snijpunten,': 0,
#   'dejesus': 0,
#   '\\|p3': 0,
#   'hbcr-2010': 0,
#   'cpus?': 0,
#   'crucifix.': 0,
#   '[oy]': 0,
#   'm"`@("`@("`@("`a]?72znazz75t>?7t("`@("`@("`@("`@("`@("`@("`@(': 0,
#   'contributions.': 0,
#   'vector-valued': 0,
#   'yielded': 0,
#   '],m/j2om0$!h@"tm>$@': 0,
#   'identity:': 0,
#   '90064': 0,
#   "jumpers'": 0,
#   'phishnet:': 0,
#   'his/': 0,
#   'peri)': 0,
#   'display}.': 0,
#   '>>monitor': 0,
#   'isaiah,': 0,
#   '>4': 0,
#   '6th': 0,
#   'azathioprine.': 0,
#   '<raveling@venera.isi.edu>,': 0,
#   '>@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@': 0,
#   'narinian,': 0,
#   'collection*,': 0,
#   '>production.': 0,
#   'russian/czech/etc': 0,
#   'willis"': 0,
#   'ry:c+a*(3(!q[[_t3%-6?7<"?_jl5j;6s67v0j': 0,
#   '6h#3c$(4.:c=j@': 0,
#   'righthanded,': 0,
#   'sheathed': 0,
#   'timor': 0,
#   "m%a86%a86%a86%a86%a;)r<g)b8e,#v<tb^vp&=*97bk?i6;$ax>'ax>'ax>'": 0,
#   'enc': 0,
#   '@(*^o"z\\+"pl+"pl+"xyg!xxb': 0,
#   'homeopaths,': 0,
#   'accgsg@hofstra.bitnet': 0,
#   'network.1ps4a8$oi3': 0,
#   'mispresented.': 0,
#   '"common': 0,
#   '|not': 0,
#   'getgeometry': 0,
#   '508-263-6437': 0,
#   'christian': 0,
#   'substance)': 0,
#   'ariyak,': 0,
#   'economists': 0,
#   '2444': 0,
#   'done),': 0,
#   'griffey': 0,
#   '"humanism").': 0,
#   'beckhaus)': 0,
#   'whatever)': 0,
#   'ellens@bnr.ca': 0,
#   'samosota,': 0,
#   'cview,': 0,
#   '-board': 0,
#   'volvo).': 0,
#   '>128': 0,
#   'movers': 0,
#   'x11r5/mwm.': 0,
#   'bobby-': 0,
#   'td@alice.uucp': 0,
#   "`gentlemen',": 0,
#   '#>faith",': 0,
#   'changer:': 0,
#   '(perganol,': 0,
#   'auteur': 0,
#   'fd/hd': 0,
#   'freethought.': 0,
#   '_national': 0,
#   'gassed.': 0,
#   'quad4s?': 0,
#   'thester@nyx.cs.du.edu': 0,
#   'non-va_list': 0,
#   'meaning.': 0,
#   'citizen"?': 0,
#   'propounds': 0,
#   '04-01': 0,
#   '+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++': 0,
#   'carve': 0,
#   '(801)750-3268': 0,
#   '4.:': 0,
#   'webb@itu1': 0,
#   'globular/spherical.': 0,
#   'report",': 0,
#   'mouthings."': 0,
#   '>gm': 0,
#   "animals'": 0,
#   '(selfish)': 0,
#   'paper.': 0,
#   'est).': 0,
#   'replace.': 0,
#   'dunno...': 0,
#   '>>that': 0,
#   'tract,': 0,
#   '(33': 0,
#   'genome': 0,
#   "sandberg's.": 0,
#   'alavi)': 0,
#   'jtozer@sdcc3.ucsd.edu': 0,
#   'demonstrably': 0,
#   'dsg,': 0,
#   'arriving.': 0,
#   'w20-575-72.mit.edu': 0,
#   '<1qjmf6$d0i@sixgun.east.sun.com>': 0,
#   'essays': 0,
#   'smiling': 0,
#   'mcs213c.cs.umr.edu': 0,
#   '>>disagrees': 0,
#   'knowable': 0,
#   'xtsetarg(args[n],xtnusestringinplace,true);': 0,
#   'stressed': 0,
#   'ñaustin': 0,
#   '300kb': 0,
#   'phono-plug-to-optical': 0,
#   'acsys,': 0,
#   'prophtets.': 0,
#   '<1q1jshinn4v1@rodan.uu.net>:': 0,
#   '(mit-shm).': 0,
#   'pem-dev-request@tis.com.': 0,
#   'wreck.motorcycles?': 0,
#   'm$[rk#9_,s#f<x0i67,va&%pp?!b;,#";,%:m&g)rmzvmmv^m%:w+u-2-$.^$': 0,
#   ':sivap-s@cs.buffalo.edu': 0,
#   'mo:?@mej]i[e:o1"]#(>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'': 0,
#   'edowdy@vax1.umkc.edu': 0,
#   'suspiciously': 0,
#   '148k': 0,
#   '110': 0,
#   'attr;': 0,
#   'xtpointer)': 0,
#   'lockable': 0,
#   'q1:': 0,
#   '"followup-to"': 0,
#   'orc': 0,
#   'lumpkin': 0,
#   'jahn': 0,
#   'lip"': 0,
#   'pellets.': 0,
#   'predictor,': 0,
#   '>provokes': 0,
#   'm3$q,3$r)b8f)3$r)b8f)b8f)b8g)r<g)r<g)r<d6%a86%a86%a86%a86%a86': 0,
#   'ray-traces': 0,
#   'g&c': 0,
#   'billson)': 0,
#   'arrogance': 0,
#   '==========================': 0,
#   'number=3,': 0,
#   'typing-injury-faq/software': 0,
#   "'latter'": 0,
#   "`nameservers';": 0,
#   "mv%cm;[y)a?ycw^9??jm_0y*_x3^+1>'zwp4q<": 0,
#   'slash-cut': 0,
#   'w/200': 0,
#   'antarctic.': 0,
#   'month...': 0,
#   'm<ah:<a-2e3,k8z$**s,hh8%6,&\'-ikz:(fc!+a"q:*r;lyhp,%8:)ahf&g)r': 0,
#   'omnipotency': 0,
#   'coverpage):': 0,
#   '/-|-\\': 0,
#   'akerman@bill.phy.queensu.ca': 0,
#   '(art@cs.ualberta.ca);': 0,
#   'pseudoprime': 0,
#   'async': 0,
#   '33mhz,': 0,
#   'gf': 0,
#   'tactix': 0,
#   'pistol;': 0,
#   'kenny.': 0,
#   '10%': 0,
#   'kms': 0,
#   'backroad': 0,
#   '|at': 0,
#   'arrogance.': 0,
#   'mq<7%q30t-#0t-#0t-#0t-(n+bxn+bxn+bxn+bxn+bxn+bxn+bxn+bxlt-#0t': 0,
#   '(rthomson@dsd.es.com)': 0,
#   'pela.': 0,
#   'hairenik,': 0,
#   '(2-2-2,': 0,
#   'venkateswar': 0,
#   'adequate.': 0,
#   '**of': 0,
#   'cb750)': 0,
#   'multi-strategy': 0,
#   'm>ry+9l%(>t_[mv#r0s': 0,
#   '1177.4': 0,
#   "mu-34:]34u-34;fz0$7q65lq1]5$w5e967%q<7%q<7%q65e:_ovg'd36&q[]i": 0,
#   'tait)': 0,
#   'host': 0,
#   'or=6.0;': 0,
#   '787': 0,
#   'gun-legislation.': 0,
#   'ilmenau': 0,
#   '(nlpers': 0,
#   'interantional': 0,
#   'm$pu1s.%d\\64b[[;oo;6q.xe,3&=&-c84hm2`7prv?m3j7t,=:!v`p2&l[.s!': 0,
#   'care.': 0,
#   'door)': 0,
#   'reichenbach,': 0,
#   '>fanged': 0,
#   'partial.': 0,
#   'buses': 0,
#   'artistic': 0,
#   "patty's": 0,
#   'neccities': 0,
#   'enhancement': 0,
#   '50pin': 0,
#   'patches,': 0,
#   'cory.berkeley.edu': 0,
#   '(wscrawl)': 0,
#   '(mst3k#17': 0,
#   'wa6omi': 0,
#   'gringort@tantalus.pa.dec.com': 0,
#   'besarkatu': 0,
#   'coincided': 0,
#   '"rent"': 0,
#   '(bulent': 0,
#   'bigshot.': 0,
#   'fati,': 0,
#   'ml5(#gj&5f&z75pnq': 0,
#   '1.44mb).': 0,
#   'intercession': 0,
#   'outraged.': 0,
#   'deportees,': 0,
#   'two;': 0,
#   '28:1ff,': 0,
#   'tread.': 0,
#   "paper's,": 0,
#   'walveranta)': 0,
#   'wingdings)': 0,
#   'beirut,': 0,
#   'personalize': 0,
#   'expressivity.': 0,
#   '<1993apr16.001321.3692@natasha.portal.com>': 0,
#   'me55a': 0,
#   '<>constitution.': 0,
#   "7*v6'!p=_c6": 0,
#   'apostles.': 0,
#   'sanguine/choleric/melencholic/phlegmatic': 0,
#   "bureaucrat's": 0,
#   'lagged': 0,
#   "-'=isfuap8": 0,
#   'peredo)': 0,
#   'ever."': 0,
#   'cherokee': 0,
#   ':details,': 0,
#   '6:17': 0,
#   'anyways???': 0,
#   'practise': 0,
#   'driveway?': 0,
#   'zane!!rescue': 0,
#   'non-removable.': 0,
#   '617/981-2575': 0,
#   'axp': 0,
#   'observer)': 0,
#   '(1.04)^65': 0,
#   "m-(om4[`9&7'2tm(]f0-,3$q,3$q,3$q,3$q,3$q,3$r)3$q,3$q,#v=g9\\7%": 0,
#   'countersteering.': 0,
#   '>mccullou@snake2.cs.wisc.edu': 0,
#   'xchess': 0,
#   'graeme>': 0,
#   'visits.': 0,
#   'max>\'ax>\'ax>\'ax>\'ax>\'a\\!;p#au)75u=24e)3c`;fzntq"qs]17r%=7u%>`': 0,
#   'flopticals': 0,
#   '000773b9': 0,
#   'yulaev': 0,
#   'jarkko': 0,
#   '108)': 0,
#   'ld++': 0,
#   'illustrator?': 0,
#   'starvation,': 0,
#   'azerbadjan)': 0,
#   '>good': 0,
#   'corollary:': 0,
#   'rubberband': 0,
#   'rsa': 0,
#   'socialism': 0,
#   'brosnan': 0,
#   'mm2e"e@^h:j0#y%93)+ni#7)0.pmgnd><.)d': 0,
#   'kaan,timucin': 0,
#   '4100': 0,
#   'wast': 0,
#   'flakes': 0,
#   'u-turn': 0,
#   'beemers.': 0,
#   'extremist,': 0,
#   '>>morris': 0,
#   'carbon/kevlar': 0,
#   'boost...': 0,
#   '10666': 0,
#   '0.200': 0,
#   '"fusetron")': 0,
#   '#actually,': 0,
#   'armed.': 0,
#   '136,739,000': 0,
#   '(harry': 0,
#   'mayflies,': 0,
#   'hci-newsletter': 0,
#   '300k': 0,
#   '>goaltending': 0,
#   'shocks': 0,
#   '1:376/74.0': 0,
#   'verse?': 0,
#   '16187': 0,
#   'm5g*5>5".3galale': 0,
#   'uname);': 0,
#   'does,': 0,
#   '<cliu@silver.ucs.indiana.edu>': 0,
#   'kid?': 0,
#   'vorld': 0,
#   'maryland.': 0,
#   'arsenaul@ere.umontreal.ca': 0,
#   '17.14-21,': 0,
#   'true??/': 0,
#   '<1993apr2.212405.5213@head-cfa.harvard.edu>': 0,
#   '375': 0,
#   '.074': 0,
#   '.forward': 0,
#   'public-interest': 0,
#   'die!"': 0,
#   'twelve,': 0,
#   'phi,incaviglia': 0,
#   '24:4-14).': 0,
#   'opto-isolators': 0,
#   'whic': 0,
#   'max>\'ax>\'ax>\'ax>\'ax=qtcv9f0.[*gk?wt>e"pmfq,0qax>\'ax>\'ax>\'ax>\'': 0,
#   'pooltable': 0,
#   'utah).': 0,
#   "howen's": 0,
#   'reactions).': 0,
#   'matyas,': 0,
#   'tremor.': 0,
#   'movements': 0,
#   'vigilantism.': 0,
#   'm)"36ui_>]?7>g]8d)"1j:fij:fij:j"@khb(-c8v:vl)"0g/"0ek-c9n;mg9': 0,
#   'jacobson': 0,
#   'colombo@bronco.fnal.gov': 0,
#   'benz..': 0,
#   'traitorously': 0,
#   '20:52': 0,
#   '(essential)': 0,
#   '14:40:15': 0,
#   '>meter.': 0,
#   'distinguishing': 0,
#   'play,': 0,
#   '"braves': 0,
#   'pa-2': 0,
#   'hydra.rose-hulman.edu': 0,
#   '(speed': 0,
#   '*win;': 0,
#   'heederik,': 0,
#   'n.t.': 0,
#   'dyanimic': 0,
#   '(efficency': 0,
#   '[arnie]': 0,
#   'technician(dr.': 0,
#   '1kspt=17.28%': 0,
#   '<jrobbins.93apr15103031@kingston.cs.ucla.edu>': 0,
#   'folta@zen.holonet.net': 0,
#   'contagiosem.': 0,
#   '<1483500355@igc.apc.org>': 0,
#   "mi:4+q#&'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'": 0,
#   'lodges': 0,
#   'nanny-nanny-boo-boo': 0,
#   'push,': 0,
#   'maidenhead,': 0,
#   'stacks=10,256': 0,
#   '(processor': 0,
#   'boltzman': 0,
#   'g-3,': 0,
#   'applicable.': 0,
#   'portugals': 0,
#   'mqbnaiqxytkaaaecalfehyp0yc80s1scfvjspj5escao+hihtnefrrn+vuecsavh': 0,
#   'wilkes-barre,': 0,
#   'stinks,': 0,
#   'darkness': 0,
#   'disclaimer,': 0,
#   '(hans': 0,
#   '<p00421@psilink.com>': 0,
#   'server"': 0,
#   'alcohol,': 0,
#   '`sports': 0,
#   '>thirdly': 0,
#   '>capability,': 0,
#   '>carcinogens': 0,
#   'boast': 0,
#   'nuclear.med.bcm.tmc.edu': 0,
#   'iud': 0,
#   'xtlasttimestampprocessed()': 0,
#   'landmarks': 0,
#   'errr....': 0,
#   'woofing!': 0,
#   'oofgm,': 0,
#   'mistaken,': 0,
#   "m71y]+'u]?7tlngvz'gu=pkjz)k)=)eu=)etflkhfnkhf)ah:lahf<k)r<b:z": 0,
#   'mx^-[x^/cxxi[x^-[bn/cbdf*xxj*>tgcbn/c>s+cxxkcxxj*xwocxwlrxxkc': 0,
#   '>attributes.': 0,
#   '/\\/\\artin': 0,
#   'buckle': 0,
#   '50b/2239': 0,
#   'alludes': 0,
#   "max>'ax>'wb>?@=;6um;6um;6um;6um;6um;6um;6um;6um;6um;6uh&!@8'6": 0,
#   "mu-34r!045u=75z);p'4x.'6>gi[-*&!@gy\\w`2lks<w-4%!04%!04%!04%!0": 0,
#   'cobol;': 0,
#   'devvax.jpl.nasa.gov)': 0,
#   'rpi.zss56vm': 0,
#   'freon': 0,
#   'swissnet': 0,
#   'meetings..': 0,
#   'ices.': 0,
#   '"ferigner"': 0,
#   'pins,': 0,
#   'independence.': 0,
#   '/s': 0,
#   'startled..and': 0,
#   'dissipate?': 0,
#   'fact-finding': 0,
#   '13255,': 0,
#   'steel-o-': 0,
#   '$.50': 0,
#   '>involved': 0,
#   '(ghz)......': 0,
#   'tichauer"': 0,
#   "m@0;t@8s6ax>'ax>'az:f@^3/5\\@%2j`ej>0g8&!1'.o>45'ujpwu46!1#5%1": 0,
#   'spit': 0,
#   '"xl"': 0,
#   'nightfall': 0,
#   '(_)/(_)': 0,
#   '>gilmour': 0,
#   "m%a86%lg)r<g)b8f)b8f)3$p/q32+[5.pl!eqtcv9`uz[nriz1z5fq#&'ax>'": 0,
#   'mingle': 0,
#   'incandescent': 0,
#   'paedophilia': 0,
#   'patti,': 0,
#   'sovereignty': 0,
#   'konfessionslosen': 0,
#   '>>religions.': 0,
#   'b@+g5ar;]**#n;huv^@$': 0,
#   '10c': 0,
#   '>(pope': 0,
#   '>forty-two': 0,
#   'affairs.': 0,
#   'tirelessly.': 0,
#   'm*h8@2m><\']"<2!><j)$afppc0eg\'wg$pl': 0,
#   'davis,': 0,
#   'staring': 0,
#   'rationalistic.': 0,
#   'soundtool,': 0,
#   'ma2<t830t-#1g0!j4091a': 0,
#   'mcnab': 0,
#   '6819@sol.ctr.columbia.edu,': 0,
#   '.drw': 0,
#   'ns16550af,': 0,
#   'd<\\n^),5s)(h3rpp': 0,
#   'lethal.': 0,
#   'specialists...': 0,
#   'axe,': 0,
#   '\\\\-\\dave': 0,
#   'stanza,': 0,
#   'su-27': 0,
#   '2nd,...': 0,
#   'cavgeoe@yalevm.ycc.yale.': 0,
#   '1m3l(t:=-.@tsq\'4d#\\/:ip310p01)p#[ca.@2@"*(4=y': 0,
#   'magnesium:calcium': 0,
#   '>galaxy': 0,
#   '>>>always': 0,
#   'revelant).': 0,
#   'carlos@carlos.uucp': 0,
#   'top': 0,
#   'judea,': 0,
#   '"months': 0,
#   'present_,': 0,
#   '#15/15': 0,
#   'carbon-nitrogen-oxygen': 0,
#   '>>listen': 0,
#   'gts1000': 0,
#   'perihelions': 0,
#   'rik.': 0,
#   'suiss,': 0,
#   'ray_whitney': 0,
#   'belliard': 0,
#   'smartdrv,': 0,
#   'dot-3': 0,
#   'to."': 0,
#   'warner': 0,
#   'treatment?': 0,
#   'm@("`@*jjjc8vh^[n[@<\'!udy.1p<\'!py.3f7.6!1]?51s#<w!@8d"@h*)"0d': 0,
#   'hst.': 0,
#   'willdye@helios.unl.edu': 0,
#   'statues,': 0,
#   'rosa@ghost.dsi.unimi.it': 0,
#   'pillsbury': 0,
#   '>>primary': 0,
#   'dense.': 0,
#   'prisons]': 0,
#   '(68)': 0,
#   '1.1': 0,
#   'callihan"': 0,
#   'm867r[6;]7&;rhhlmjp<0u\'xk^@su"/4(]1gj=z@_4]j=*+/!d:*>hny$i0u5': 0,
#   'mra': 0,
#   "m$q,3$[qv=g9v4c,sax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'": 0,
#   'stifling': 0,
#   'pb.': 0,
#   '(212mb).': 0,
#   '(harleys,': 0,
#   'unpublished': 0,
#   'depression;': 0,
#   'baud,': 0,
#   'hackett': 0,
#   'forsale,': 0,
#   "harris'": 0,
#   'mmh:': 0,
#   '\\$<!6t+h:>=5]%[s/]': 0,
#   'xview...': 0,
#   'have)': 0,
#   'judeo-': 0,
#   'serf': 0,
#   'dobbin,': 0,
#   'm"`@("`@("`@("`@("`@("`@("`@("`@("`@("`@("`@("`@("`@("`@(;v\\5': 0,
#   'old-earth': 0,
#   'provide...).': 0,
#   'stafford@vax2.winona.msus.edu': 0,
#   'mf;+nc*u_!6pg%?>y)i)s\'hh:gw<&2ubdt;%_*>uk8"4[v1g%;&(-u,ly!y8p': 0,
#   'saw.': 0,
#   'distinctive': 0,
#   'turkish.': 0,
#   'snide': 0,
#   '-n)y[<3u&j@<,6">u_.a2dpn/)b&")](y+[z;=.#\\q?x906:h,t>3c(d*': 0,
#   'hp-9000,': 0,
#   "'djul": 0,
#   '(quality)': 0,
#   'subsampling': 0,
#   'olsen': 0,
#   'carbonneau': 0,
#   'tds32845@uxa.cso.uiuc.edu': 0,
#   'don.hancock@f303.n105.z1.fidonet.org': 0,
#   '==========================================================================': 0,
#   "m#f/((<4*p?'_70d((4!'/&e;'.q76?0jb6pwzasj$hc0": 0,
#   '(1787),': 0,
#   'sating': 0,
#   'neurons.': 0,
#   'not-so-quick': 0,
#   ...},
#  'comp.os.ms-windows.misc': {'coolant': 0,
#   's3,': 0,
#   '80186': 0,
#   'office.)': 0,
#   'reconsider.': 0,
#   'down-shifts.': 0,
#   '(301)227-1340': 0,
#   '(barium,': 0,
#   '"infamous,"': 0,
#   "malhz.i%!.h:1.chz.chz.lhz.ma!.fw*v,hz.m@z0=c8;=amv'/8/&t\\;6w*": 0,
#   'primordial': 0,
#   'doug.1993apr6.133257.14570': 0,
#   'year!!!!!': 0,
#   'reporter".': 0,
#   '_annals_': 0,
#   'maisonneuve': 0,
#   'agriculturalists.': 0,
#   '>>accurate': 0,
#   '139.': 0,
#   'tell)': 0,
#   "m.,!;%%=75u=75u=75u=75q1;6\\#`6q175u=7%%lx=77i!`3-*#d<'#dhs03.": 0,
#   'nice,': 0,
#   'diet,': 0,
#   '>f350': 0,
#   'perdition': 0,
#   'omitted.': 0,
#   '<jbc9+@andrew.cmu.edu>': 0,
#   'verschuldigde': 0,
#   'imately': 0,
#   '(glx': 0,
#   '-necessarily-': 0,
#   'inflammatory': 0,
#   'subsidises': 0,
#   '9..que': 0,
#   '(380': 0,
#   'parade': 0,
#   'xorg:': 0,
#   '<1qnav4$r3l@transfer.stratus.com>,': 0,
#   'unverzagt)': 0,
#   'greats': 0,
#   "c.b'1:l)j/9k2b/8": 0,
#   'organised': 0,
#   'flux.': 0,
#   '{se,': 0,
#   'xtclosedisplay().': 0,
#   'vf': 0,
#   'sharedx"': 0,
#   'simsh@rpi.edu': 0,
#   'serbs?': 0,
#   'lazer': 0,
#   '1-mar-93': 0,
#   "xbm's": 0,
#   'changed".': 0,
#   'head,"': 0,
#   '(america),': 0,
#   'anticipate': 0,
#   '<1qev18innnk7@early-bird.think.com>,': 0,
#   '<glenn@cs.utexas.edu>': 0,
#   'fil.sapienza@med.umich.edu': 0,
#   'staffan': 0,
#   'h.sync': 0,
#   'cents..': 0,
#   's)")': 0,
#   '>modems;': 0,
#   'nagorno-': 0,
#   'chiropractor.': 0,
#   's.edu': 0,
#   '>>>(given': 0,
#   '(megan@cs.uq.oz.au)': 0,
#   'm`>f/gwj4]8[#.oe&^b&*4^cgk%^q3@c1m+i\'6][ssg"u.[\'zy5^kvp@#6ho=': 0,
#   'disadvantage?': 0,
#   'mounting;': 0,
#   "states''.": 0,
#   'heterosexuals,': 0,
#   'confrontation.': 0,
#   'racing/motocycle': 0,
#   '778': 0,
#   '"xplaces"': 0,
#   '>mjs>you': 0,
#   '$2,899': 0,
#   'real--particularly': 0,
#   'dc,': 0,
#   '(1-800-338-0531).': 0,
#   'dcg6759@uxa.cso.uiuc.edu': 0,
#   'kazimir,': 0,
#   'konstantinople': 0,
#   'unlimited?': 0,
#   'jews!': 0,
#   'ellett)': 0,
#   '>conference': 0,
#   'turnbull': 0,
#   'shortage.': 0,
#   'vi-daevo-data,': 0,
#   'difinitive': 0,
#   '<steve@cs.hw.ac.uk>': 0,
#   'trachtenberg': 0,
#   'pnmconvol': 0,
#   'school....now': 0,
#   'bv>bidder?': 0,
#   'sorehand': 0,
#   'gambarian.': 0,
#   'gigabit': 0,
#   'licenseplatedatabase': 0,
#   'h(m).': 0,
#   'm(1hfr;q..a[:0)))=%m9^p)05xk87&h7"%s@=1z': 0,
#   "'psudo'": 0,
#   'canakkale': 0,
#   'beav)': 0,
#   'sympathies': 0,
#   '(big': 0,
#   'winthrop': 0,
#   "'throwing'": 0,
#   'wire-wrap': 0,
#   'mechanistic': 0,
#   'ever?': 0,
#   '*n-7*l/f4qf?6syk+)5ayzf,w_t?qj"e,mk;p]i2&3y,': 0,
#   'outcome': 0,
#   'evening-bird': 0,
#   '"velcro"': 0,
#   'minsky@media.mit.edu': 0,
#   'ae2000': 0,
#   'dad)': 0,
#   'ftp.ai.mit.edu': 0,
#   'mw.\'/i[vd?1y_0,o%j!_c39*1&6!le1:ro<;*$->%f!!#"1yv@-u0,<9/l</h': 0,
#   'line-in': 0,
#   'x(2$': 0,
#   'kaplow:': 0,
#   'agnostic': 0,
#   'cd:': 0,
#   '>pour': 0,
#   'o@6(': 0,
#   'hijaak.': 0,
#   'legged': 0,
#   'yy': 0,
#   '_mechanisms_.': 0,
#   'mknewman@blkbox.com': 0,
#   '`passwd': 0,
#   'novel': 0,
#   'sg@$@/lt->rramw7,\\ea#=![0?8q': 0,
#   'mcx_sc^?scx_gc_/scx_sy_./\\x^/c_/scx^/\\x^/c^?scx_gcx^/\\_/sc_/g': 0,
#   'three-fourths': 0,
#   '10011110b': 0,
#   'ninth-': 0,
#   'fits:': 0,
#   '<c4zwc0.6lk@acsu.buffalo.edu>': 0,
#   '1.0|1.1.2': 0,
#   'm4\\v7:m9[s;3c8w+1!jr/?7': 0,
#   'division/ncar,': 0,
#   '(10-': 0,
#   'hudel)': 0,
#   'barcelona': 0,
#   '(ahl).': 0,
#   'j3david@sms.business.uwo.ca': 0,
#   'priors': 0,
#   'technician,': 0,
#   '>>mike': 0,
#   '2:14-19.': 0,
#   'layer.': 0,
#   'babylonian': 0,
#   'fairgrounds.': 0,
#   '[israeli]': 0,
#   'startrek': 0,
#   'mtcv9`uz[*gk?1z4+"v;$q#&\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'': 0,
#   '1/10,000th': 0,
#   '>...even': 0,
#   'raisers,': 0,
#   'getbdf': 0,
#   'standby': 0,
#   'longer..': 0,
#   '90024-1596': 0,
#   'assenmacher': 0,
#   'emacs-style': 0,
#   'sunny,': 0,
#   '&w,': 0,
#   'survivour': 0,
#   '8c[fle==0-p=$-2hylqt/#0z': 0,
#   '.$00%m!0b!(mf&/qq?9:s;@': 0,
#   'rwf2@ns1.cc.lehigh.edu': 0,
#   'escrows': 0,
#   'at&tnet:': 0,
#   'past...': 0,
#   '"henrik': 0,
#   'bullcrap': 0,
#   'give-away': 0,
#   'castaways': 0,
#   "'at": 0,
#   'veritech': 0,
#   "#define'ed": 0,
#   'mx^/c27ocxte[xwocx^/c>te`x^/cxt#cx^-)2==`2>.%24gca>-`285w2>/c': 0,
#   'frank': 0,
#   'growth"': 0,
#   'csspab@mail-gw.ncsl.nist.gov,': 0,
#   'virtue.': 0,
#   'documented.': 0,
#   '>--gun': 0,
#   'many),': 0,
#   "'write'": 0,
#   "ups's": 0,
# ...
#   'natural.': 0,
#   'antoine': 0,
#   'commandment?': 0,
#   '"type': 0,
#   'mechanisms,': 0,
#   'ashdown': 0,
#   '<1993apr14.144015.18175@vax5.cit.cornell.edu>': 0,
#   'possible': 0,
#   "(yn2&it,\\:'at8w(": 0,
#   'elijah.': 0,
#   '1923': 0,
#   'jameco,': 0,
#   "mclane's": 0,
#   'canvas(see': 0,
#   'recur': 0,
#   'chicken,': 0,
#   '415-962-0494': 0,
#   '35mm,': 0,
#   'brits': 0,
#   'message].': 0,
#   "'my'": 0,
#   'thermocouples': 0,
#   'mt-"xj2n>!w:$gjg`6x>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'': 0,
#   '(ikegami)': 0,
#   '[____@@@@@@____________________@@_______][------------------------------------]': 0,
#   'gis/remote': 0,
#   'society*,': 0,
#   '472;': 0,
#   'gsfc:': 0,
#   'b58$*!6@#h!wa?8lz!$@"d!kbc#': 0,
#   'hal.1r4cej$1jc8': 0,
#   'thus-and-so,': 0,
#   'whiney': 0,
#   'explain': 0,
#   '513bct,': 0,
#   '(124)': 0,
#   'deck,': 0,
#   'will,': 0,
#   'gap,': 0,
#   'championships",': 0,
#   'tfarrell@lynx.dac.northeastern.edu': 0,
#   '--after': 0,
#   '5."': 0,
#   'absol.absol.com!rsb@panix.com': 0,
#   'earth-based': 0,
#   '26*,': 0,
#   'quasars,': 0,
#   'pixmap8,': 0,
#   'collision.': 0,
#   '>>cal': 0,
#   '``public-key': 0,
#   'mj&^h;z@("`bhj&\\(j*@(j*aoj*bhj*bhj&^hj&]oj&\\5;q5o%14("`@("`@(': 0,
#   'offices.': 0,
#   '\\--------/': 0,
#   'sq': 0,
#   'above-mentioned': 0,
#   '-jon.': 0,
#   'winner4000': 0,
#   'triplets,': 0,
#   'alternator.': 0,
#   'dilemma.': 0,
#   'roenick': 0,
#   'alleviated': 0,
#   'archon': 0,
#   'undisputed.': 0,
#   'm>bj[n[m>7@.9f9f9`p,#`p,#`p->7kn[nrhj*biz>ghj*bhj*bhj*kn[7@,#': 0,
#   'management:': 0,
#   'potomac': 0,
#   'plkg_ltd@uhura.cc.rochester.edu': 0,
#   'entropic': 0,
#   'my^?g6.?s6//gy^?s\\tz/\\ub/y_./\\x_sctz/y_-8\\ua86(^/\\_./yx_gcx^/': 0,
#   'options?': 0,
#   'violations': 0,
#   'preach,': 0,
#   'counties': 0,
#   'smiling,': 0,
#   'takeshi)': 0,
#   'lacin': 0,
#   'anarch-cryptists': 0,
#   'splendidly.': 0,
#   'brew': 0,
#   'reed.1993apr21.032905.29286': 0,
#   '$379': 0,
#   'learn?': 0,
#   'audit': 0,
#   'timestep': 0,
#   "delorme's": 0,
#   'manual."': 0,
#   'mv-c8rmc*.fw8v#ho.b_8.lk8.mc8rlhormc*;<hzv#ho.ck8+sk*.b\\ov#k8': 0,
#   '"start': 0,
#   "nazi's": 0,
#   'digitizedlength': 0,
#   'graphics_exposures': 0,
#   'mach32': 0,
#   '*ximage;': 0,
#   'bibles': 0,
#   '27-28': 0,
#   'xchongo': 0,
#   'tdk)': 0,
#   'gun-talk': 0,
#   '4meg': 0,
#   'scepticism;': 0,
#   'vision.': 0,
#   'helpimontreal': 0,
#   '(310)420-9327': 0,
#   'denktas': 0,
#   '(respective': 0,
#   'aksin,': 0,
#   '(265ms)': 0,
#   'provider': 0,
#   'stamber': 0,
#   'pocock@math.utah.edu': 0,
#   'jiggles.': 0,
#   'comparision': 0,
#   'puzzlement.': 0,
#   'theorie': 0,
#   '<7480237@hpfcso.fc.hp.com>': 0,
#   '227.': 0,
#   'proliferation': 0,
#   '>inadequate': 0,
#   'jv': 0,
#   'releases."': 0,
#   'thinner': 0,
#   'page-mode': 0,
#   'suter)': 0,
#   'milligrams': 0,
#   '/>on': 0,
#   'processor?': 0,
#   "'a'.": 0,
#   'ignore': 0,
#   "posting'": 0,
#   '>heck': 0,
#   'anvance.': 0,
#   'excise': 0,
#   'surfmodel': 0,
#   'weave,': 0,
#   'xyz': 0,
#   '>tough': 0,
#   "m_7d@o<6u:5k;xmi:%!/'$<^faq4;[#7": 0,
#   'j-4': 0,
#   're-entry': 0,
#   '16339': 0,
#   '>settlement': 0,
#   'james.mollica%pics@twwells.com': 0,
#   '<12426@sun13.scri.fsu.edu>': 0,
#   'garbled': 0,
#   '>>unless': 0,
#   '|>it': 0,
#   'srg3sir@grv.grace.cri.nz': 0,
#   'trappings...': 0,
#   'mbhd,': 0,
#   'selectionrequest': 0,
#   'winter,': 0,
#   '>truth': 0,
#   '<[@f&[wv^fo)>bx2#': 0,
#   'thinks/wants.': 0,
#   'unenfluenced': 0,
#   'germany!").': 0,
#   'naca': 0,
#   '"world"': 0,
#   '"team",': 0,
#   '$$$$),': 0,
#   'distance)?': 0,
#   'started,': 0,
#   'exile': 0,
#   'selfserving': 0,
#   'reimer)': 0,
#   'kenny)': 0,
#   'js1@isis.msstate.edu': 0,
#   "m-#0t-#0t-#0t-#0t-#1z>gizw]]'1t='1t='wt='i:4+9l3$,3$q,3$qq,3$": 0,
#   'burglars,': 0,
#   'htanabe@ponder.csci.unt.edu': 0,
#   '(contents)': 0,
#   "p-(#'h": 0,
#   '&"#u(q;p;_[$w?5o$\']x\\': 0,
#   'post-conditions': 0,
#   '4fge': 0,
#   'inexact': 0,
#   "m6q2'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'": 0,
#   "'xdpyinfo'": 0,
#   'non-winner': 0,
#   'flashflood.cs.odu.edu': 0,
#   'beretta.': 0,
#   'really?': 0,
#   'g+g': 0,
#   '(pete@egh-qc.co.uk);': 0,
#   'aantal_snijpunten,': 0,
#   'dejesus': 0,
#   '\\|p3': 0,
#   'hbcr-2010': 0,
#   'cpus?': 0,
#   'crucifix.': 0,
#   '[oy]': 0,
#   'm"`@("`@("`@("`a]?72znazz75t>?7t("`@("`@("`@("`@("`@("`@("`@(': 0,
#   'contributions.': 0,
#   'vector-valued': 0,
#   'yielded': 0,
#   '],m/j2om0$!h@"tm>$@': 0,
#   'identity:': 0,
#   '90064': 0,
#   "jumpers'": 0,
#   'phishnet:': 0,
#   'his/': 0,
#   'peri)': 0,
#   'display}.': 0,
#   '>>monitor': 0,
#   'isaiah,': 0,
#   '>4': 0,
#   '6th': 0,
#   'azathioprine.': 0,
#   '<raveling@venera.isi.edu>,': 0,
#   '>@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@': 0,
#   'narinian,': 0,
#   'collection*,': 0,
#   '>production.': 0,
#   'russian/czech/etc': 0,
#   'willis"': 0,
#   'ry:c+a*(3(!q[[_t3%-6?7<"?_jl5j;6s67v0j': 0,
#   '6h#3c$(4.:c=j@': 0,
#   'righthanded,': 0,
#   'sheathed': 0,
#   'timor': 0,
#   "m%a86%a86%a86%a86%a;)r<g)b8e,#v<tb^vp&=*97bk?i6;$ax>'ax>'ax>'": 0,
#   'enc': 0,
#   '@(*^o"z\\+"pl+"pl+"xyg!xxb': 0,
#   'homeopaths,': 0,
#   'accgsg@hofstra.bitnet': 0,
#   'network.1ps4a8$oi3': 0,
#   'mispresented.': 0,
#   '"common': 0,
#   '|not': 0,
#   'getgeometry': 0,
#   '508-263-6437': 0,
#   'christian': 0,
#   'substance)': 0,
#   'ariyak,': 0,
#   'economists': 0,
#   '2444': 0,
#   'done),': 0,
#   'griffey': 0,
#   '"humanism").': 0,
#   'beckhaus)': 0,
#   'whatever)': 0,
#   'ellens@bnr.ca': 0,
#   'samosota,': 0,
#   'cview,': 0,
#   '-board': 0,
#   'volvo).': 0,
#   '>128': 0,
#   'movers': 0,
#   'x11r5/mwm.': 0,
#   'bobby-': 0,
#   'td@alice.uucp': 0,
#   "`gentlemen',": 0,
#   '#>faith",': 0,
#   'changer:': 0,
#   '(perganol,': 0,
#   'auteur': 0,
#   'fd/hd': 0,
#   'freethought.': 0,
#   '_national': 0,
#   'gassed.': 0,
#   'quad4s?': 0,
#   'thester@nyx.cs.du.edu': 0,
#   'non-va_list': 0,
#   'meaning.': 0,
#   'citizen"?': 0,
#   'propounds': 0,
#   '04-01': 0,
#   '+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++': 0,
#   'carve': 0,
#   '(801)750-3268': 0,
#   '4.:': 0,
#   'webb@itu1': 0,
#   'globular/spherical.': 0,
#   'report",': 0,
#   'mouthings."': 0,
#   '>gm': 0,
#   "animals'": 0,
#   '(selfish)': 0,
#   'paper.': 0,
#   'est).': 0,
#   'replace.': 0,
#   'dunno...': 0,
#   '>>that': 0,
#   'tract,': 0,
#   '(33': 0,
#   'genome': 0,
#   "sandberg's.": 0,
#   'alavi)': 0,
#   'jtozer@sdcc3.ucsd.edu': 0,
#   'demonstrably': 0,
#   'dsg,': 0,
#   'arriving.': 0,
#   'w20-575-72.mit.edu': 0,
#   '<1qjmf6$d0i@sixgun.east.sun.com>': 0,
#   'essays': 0,
#   'smiling': 0,
#   'mcs213c.cs.umr.edu': 0,
#   '>>disagrees': 0,
#   'knowable': 0,
#   'xtsetarg(args[n],xtnusestringinplace,true);': 0,
#   'stressed': 0,
#   'ñaustin': 0,
#   '300kb': 0,
#   'phono-plug-to-optical': 0,
#   'acsys,': 0,
#   'prophtets.': 0,
#   '<1q1jshinn4v1@rodan.uu.net>:': 0,
#   '(mit-shm).': 0,
#   'pem-dev-request@tis.com.': 0,
#   'wreck.motorcycles?': 0,
#   'm$[rk#9_,s#f<x0i67,va&%pp?!b;,#";,%:m&g)rmzvmmv^m%:w+u-2-$.^$': 0,
#   ':sivap-s@cs.buffalo.edu': 0,
#   'mo:?@mej]i[e:o1"]#(>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'ax>\'': 0,
#   'edowdy@vax1.umkc.edu': 0,
#   'suspiciously': 0,
#   '148k': 0,
#   '110': 0,
#   'attr;': 0,
#   'xtpointer)': 0,
#   'lockable': 0,
#   'q1:': 0,
#   '"followup-to"': 0,
#   'orc': 0,
#   'lumpkin': 0,
#   'jahn': 0,
#   'lip"': 0,
#   'pellets.': 0,
#   'predictor,': 0,
#   '>provokes': 0,
#   'm3$q,3$r)b8f)3$r)b8f)b8f)b8g)r<g)r<g)r<d6%a86%a86%a86%a86%a86': 0,
#   'ray-traces': 0,
#   'g&c': 0,
#   'billson)': 0,
#   'arrogance': 0,
#   '==========================': 0,
#   'number=3,': 0,
#   'typing-injury-faq/software': 0,
#   "'latter'": 0,
#   "`nameservers';": 0,
#   "mv%cm;[y)a?ycw^9??jm_0y*_x3^+1>'zwp4q<": 0,
#   'slash-cut': 0,
#   'w/200': 0,
#   'antarctic.': 0,
#   'month...': 0,
#   'm<ah:<a-2e3,k8z$**s,hh8%6,&\'-ikz:(fc!+a"q:*r;lyhp,%8:)ahf&g)r': 0,
#   'omnipotency': 0,
#   'coverpage):': 0,
#   '/-|-\\': 0,
#   'akerman@bill.phy.queensu.ca': 0,
#   '(art@cs.ualberta.ca);': 0,
#   'pseudoprime': 0,
#   'async': 0,
#   '33mhz,': 0,
#   'gf': 0,
#   'tactix': 0,
#   'pistol;': 0,
#   'kenny.': 0,
#   '10%': 0,
#   'kms': 0,
#   'backroad': 0,
#   '|at': 0,
#   'arrogance.': 0,
#   'mq<7%q30t-#0t-#0t-#0t-(n+bxn+bxn+bxn+bxn+bxn+bxn+bxn+bxlt-#0t': 0,
#   '(rthomson@dsd.es.com)': 0,
#   'pela.': 0,
#   'hairenik,': 0,
#   '(2-2-2,': 0,
#   'venkateswar': 0,
#   'adequate.': 0,
#   '**of': 0,
#   'cb750)': 0,
#   'multi-strategy': 0,
#   'm>ry+9l%(>t_[mv#r0s': 0,
#   '1177.4': 0,
#   "mu-34:]34u-34;fz0$7q65lq1]5$w5e967%q<7%q<7%q65e:_ovg'd36&q[]i": 0,
#   'tait)': 0,
#   'host': 0,
#   'or=6.0;': 0,
#   '787': 0,
#   'gun-legislation.': 0,
#   'ilmenau': 0,
#   '(nlpers': 0,
#   'interantional': 0,
#   'm$pu1s.%d\\64b[[;oo;6q.xe,3&=&-c84hm2`7prv?m3j7t,=:!v`p2&l[.s!': 0,
#   'care.': 0,
#   'door)': 0,
#   'reichenbach,': 0,
#   '>fanged': 0,
#   'partial.': 0,
#   'buses': 0,
#   'artistic': 0,
#   "patty's": 0,
#   'neccities': 0,
#   'enhancement': 0,
#   '50pin': 0,
#   'patches,': 0,
#   'cory.berkeley.edu': 0,
#   '(wscrawl)': 0,
#   '(mst3k#17': 0,
#   'wa6omi': 0,
#   'gringort@tantalus.pa.dec.com': 0,
#   'besarkatu': 0,
#   'coincided': 0,
#   '"rent"': 0,
#   '(bulent': 0,
#   'bigshot.': 0,
#   'fati,': 0,
#   'ml5(#gj&5f&z75pnq': 0,
#   '1.44mb).': 0,
#   'intercession': 0,
#   'outraged.': 0,
#   'deportees,': 0,
#   'two;': 0,
#   '28:1ff,': 0,
#   'tread.': 0,
#   "paper's,": 0,
#   'walveranta)': 0,
#   'wingdings)': 0,
#   'beirut,': 0,
#   'personalize': 0,
#   'expressivity.': 0,
#   '<1993apr16.001321.3692@natasha.portal.com>': 0,
#   'me55a': 0,
#   '<>constitution.': 0,
#   "7*v6'!p=_c6": 0,
#   'apostles.': 0,
#   'sanguine/choleric/melencholic/phlegmatic': 0,
#   "bureaucrat's": 0,
#   'lagged': 0,
#   "-'=isfuap8": 0,
#   'peredo)': 0,
#   'ever."': 0,
#   'cherokee': 0,
#   ':details,': 0,
#   '6:17': 0,
#   'anyways???': 0,
#   'practise': 0,
#   'driveway?': 0,
#   'zane!!rescue': 0,
#   'non-removable.': 0,
#   '617/981-2575': 0,
#   'axp': 0,
#   'observer)': 0,
#   '(1.04)^65': 0,
#   "m-(om4[`9&7'2tm(]f0-,3$q,3$q,3$q,3$q,3$q,3$r)3$q,3$q,#v=g9\\7%": 0,
#   'countersteering.': 0,
#   '>mccullou@snake2.cs.wisc.edu': 0,
#   'xchess': 0,
#   'graeme>': 0,
#   'visits.': 0,
#   'max>\'ax>\'ax>\'ax>\'ax>\'a\\!;p#au)75u=24e)3c`;fzntq"qs]17r%=7u%>`': 0,
#   'flopticals': 0,
#   '000773b9': 0,
#   'yulaev': 0,
#   'jarkko': 0,
#   '108)': 0,
#   'ld++': 0,
#   'illustrator?': 0,
#   'starvation,': 0,
#   'azerbadjan)': 0,
#   '>good': 0,
#   'corollary:': 0,
#   'rubberband': 0,
#   'rsa': 0,
#   'socialism': 0,
#   'brosnan': 0,
#   'mm2e"e@^h:j0#y%93)+ni#7)0.pmgnd><.)d': 0,
#   'kaan,timucin': 0,
#   '4100': 0,
#   'wast': 0,
#   'flakes': 0,
#   'u-turn': 0,
#   'beemers.': 0,
#   'extremist,': 0,
#   '>>morris': 0,
#   'carbon/kevlar': 0,
#   'boost...': 0,
#   '10666': 0,
#   '0.200': 0,
#   '"fusetron")': 0,
#   '#actually,': 0,
#   'armed.': 0,
#   '136,739,000': 0,
#   '(harry': 0,
#   'mayflies,': 0,
#   'hci-newsletter': 0,
#   '300k': 0,
#   '>goaltending': 0,
#   'shocks': 0,
#   '1:376/74.0': 0,
#   'verse?': 0,
#   '16187': 0,
#   'm5g*5>5".3galale': 0,
#   'uname);': 0,
#   'does,': 0,
#   '<cliu@silver.ucs.indiana.edu>': 0,
#   'kid?': 0,
#   'vorld': 0,
#   'maryland.': 0,
#   'arsenaul@ere.umontreal.ca': 0,
#   '17.14-21,': 0,
#   'true??/': 0,
#   '<1993apr2.212405.5213@head-cfa.harvard.edu>': 0,
#   '375': 0,
#   '.074': 0,
#   '.forward': 0,
#   'public-interest': 0,
#   'die!"': 0,
#   'twelve,': 0,
#   'phi,incaviglia': 0,
#   '24:4-14).': 0,
#   'opto-isolators': 0,
#   'whic': 0,
#   'max>\'ax>\'ax>\'ax>\'ax=qtcv9f0.[*gk?wt>e"pmfq,0qax>\'ax>\'ax>\'ax>\'': 0,
#   'pooltable': 0,
#   'utah).': 0,
#   "howen's": 0,
#   'reactions).': 0,
#   'matyas,': 0,
#   'tremor.': 0,
#   'movements': 0,
#   'vigilantism.': 0,
#   'm)"36ui_>]?7>g]8d)"1j:fij:fij:j"@khb(-c8v:vl)"0g/"0ek-c9n;mg9': 0,
#   'jacobson': 0,
#   'colombo@bronco.fnal.gov': 0,
#   'benz..': 0,
#   'traitorously': 0,
#   '20:52': 0,
#   '(essential)': 0,
#   '14:40:15': 0,
#   '>meter.': 0,
#   'distinguishing': 0,
#   'play,': 0,
#   '"braves': 0,
#   'pa-2': 0,
#   'hydra.rose-hulman.edu': 0,
#   '(speed': 0,
#   '*win;': 0,
#   'heederik,': 0,
#   'n.t.': 0,
#   'dyanimic': 0,
#   '(efficency': 0,
#   '[arnie]': 0,
#   'technician(dr.': 0,
#   '1kspt=17.28%': 0,
#   '<jrobbins.93apr15103031@kingston.cs.ucla.edu>': 0,
#   'folta@zen.holonet.net': 0,
#   'contagiosem.': 0,
#   '<1483500355@igc.apc.org>': 0,
#   "mi:4+q#&'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'": 0,
#   'lodges': 0,
#   'nanny-nanny-boo-boo': 0,
#   'push,': 0,
#   'maidenhead,': 0,
#   'stacks=10,256': 0,
#   '(processor': 0,
#   'boltzman': 0,
#   'g-3,': 0,
#   'applicable.': 0,
#   'portugals': 0,
#   'mqbnaiqxytkaaaecalfehyp0yc80s1scfvjspj5escao+hihtnefrrn+vuecsavh': 0,
#   'wilkes-barre,': 0,
#   'stinks,': 0,
#   'darkness': 0,
#   'disclaimer,': 0,
#   '(hans': 0,
#   '<p00421@psilink.com>': 0,
#   'server"': 0,
#   'alcohol,': 0,
#   '`sports': 0,
#   '>thirdly': 0,
#   '>capability,': 0,
#   '>carcinogens': 0,
#   'boast': 0,
#   'nuclear.med.bcm.tmc.edu': 0,
#   'iud': 0,
#   'xtlasttimestampprocessed()': 0,
#   'landmarks': 0,
#   'errr....': 0,
#   'woofing!': 0,
#   'oofgm,': 0,
#   'mistaken,': 0,
#   "m71y]+'u]?7tlngvz'gu=pkjz)k)=)eu=)etflkhfnkhf)ah:lahf<k)r<b:z": 0,
#   'mx^-[x^/cxxi[x^-[bn/cbdf*xxj*>tgcbn/c>s+cxxkcxxj*xwocxwlrxxkc': 0,
#   '>attributes.': 0,
#   '/\\/\\artin': 0,
#   'buckle': 0,
#   '50b/2239': 0,
#   'alludes': 0,
#   "max>'ax>'wb>?@=;6um;6um;6um;6um;6um;6um;6um;6um;6um;6uh&!@8'6": 0,
#   "mu-34r!045u=75z);p'4x.'6>gi[-*&!@gy\\w`2lks<w-4%!04%!04%!04%!0": 0,
#   'cobol;': 0,
#   'devvax.jpl.nasa.gov)': 0,
#   'rpi.zss56vm': 0,
#   'freon': 0,
#   'swissnet': 0,
#   'meetings..': 0,
#   'ices.': 0,
#   '"ferigner"': 0,
#   'pins,': 0,
#   'independence.': 0,
#   '/s': 0,
#   'startled..and': 0,
#   'dissipate?': 0,
#   'fact-finding': 0,
#   '13255,': 0,
#   'steel-o-': 0,
#   '$.50': 0,
#   '>involved': 0,
#   '(ghz)......': 0,
#   'tichauer"': 0,
#   "m@0;t@8s6ax>'ax>'az:f@^3/5\\@%2j`ej>0g8&!1'.o>45'ujpwu46!1#5%1": 0,
#   'spit': 0,
#   '"xl"': 0,
#   'nightfall': 0,
#   '(_)/(_)': 0,
#   '>gilmour': 0,
#   "m%a86%lg)r<g)b8f)b8f)3$p/q32+[5.pl!eqtcv9`uz[nriz1z5fq#&'ax>'": 0,
#   'mingle': 0,
#   'incandescent': 0,
#   'paedophilia': 0,
#   'patti,': 0,
#   'sovereignty': 0,
#   'konfessionslosen': 0,
#   '>>religions.': 0,
#   'b@+g5ar;]**#n;huv^@$': 0,
#   '10c': 0,
#   '>(pope': 0,
#   '>forty-two': 0,
#   'affairs.': 0,
#   'tirelessly.': 0,
#   'm*h8@2m><\']"<2!><j)$afppc0eg\'wg$pl': 0,
#   'davis,': 0,
#   'staring': 0,
#   'rationalistic.': 0,
#   'soundtool,': 0,
#   'ma2<t830t-#1g0!j4091a': 0,
#   'mcnab': 0,
#   '6819@sol.ctr.columbia.edu,': 0,
#   '.drw': 0,
#   'ns16550af,': 0,
#   'd<\\n^),5s)(h3rpp': 0,
#   'lethal.': 0,
#   'specialists...': 0,
#   'axe,': 0,
#   '\\\\-\\dave': 0,
#   'stanza,': 0,
#   'su-27': 0,
#   '2nd,...': 0,
#   'cavgeoe@yalevm.ycc.yale.': 0,
#   '1m3l(t:=-.@tsq\'4d#\\/:ip310p01)p#[ca.@2@"*(4=y': 0,
#   'magnesium:calcium': 0,
#   '>galaxy': 0,
#   '>>>always': 0,
#   'revelant).': 0,
#   'carlos@carlos.uucp': 0,
#   'top': 0,
#   'judea,': 0,
#   '"months': 0,
#   'present_,': 0,
#   '#15/15': 0,
#   'carbon-nitrogen-oxygen': 0,
#   '>>listen': 0,
#   'gts1000': 0,
#   'perihelions': 0,
#   'rik.': 0,
#   'suiss,': 0,
#   'ray_whitney': 0,
#   'belliard': 0,
#   'smartdrv,': 0,
#   'dot-3': 0,
#   'to."': 0,
#   'warner': 0,
#   'treatment?': 0,
#   'm@("`@*jjjc8vh^[n[@<\'!udy.1p<\'!py.3f7.6!1]?51s#<w!@8d"@h*)"0d': 0,
#   'hst.': 0,
#   'willdye@helios.unl.edu': 0,
#   'statues,': 0,
#   'rosa@ghost.dsi.unimi.it': 0,
#   'pillsbury': 0,
#   '>>primary': 0,
#   'dense.': 0,
#   'prisons]': 0,
#   '(68)': 0,
#   '1.1': 0,
#   'callihan"': 0,
#   'm867r[6;]7&;rhhlmjp<0u\'xk^@su"/4(]1gj=z@_4]j=*+/!d:*>hny$i0u5': 0,
#   'mra': 0,
#   "m$q,3$[qv=g9v4c,sax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'ax>'": 0,
#   'stifling': 0,
#   'pb.': 0,
#   '(212mb).': 0,
#   '(harleys,': 0,
#   'unpublished': 0,
#   'depression;': 0,
#   'baud,': 0,
#   'hackett': 0,
#   'forsale,': 0,
#   "harris'": 0,
#   'mmh:': 0,
#   '\\$<!6t+h:>=5]%[s/]': 0,
#   'xview...': 0,
#   'have)': 0,
#   'judeo-': 0,
#   'serf': 0,
#   'dobbin,': 0,
#   'm"`@("`@("`@("`@("`@("`@("`@("`@("`@("`@("`@("`@("`@("`@(;v\\5': 0,
#   'old-earth': 0,
#   'provide...).': 0,
#   'stafford@vax2.winona.msus.edu': 0,
#   'mf;+nc*u_!6pg%?>y)i)s\'hh:gw<&2ubdt;%_*>uk8"4[v1g%;&(-u,ly!y8p': 0,
#   'saw.': 0,
#   'distinctive': 0,
#   'turkish.': 0,
#   'snide': 0,
#   '-n)y[<3u&j@<,6">u_.a2dpn/)b&")](y+[z;=.#\\q?x906:h,t>3c(d*': 0,
#   'hp-9000,': 0,
#   "'djul": 0,
#   '(quality)': 0,
#   'subsampling': 0,
#   'olsen': 0,
#   'carbonneau': 0,
#   'tds32845@uxa.cso.uiuc.edu': 0,
#   'don.hancock@f303.n105.z1.fidonet.org': 0,
#   '==========================================================================': 0,
#   "m#f/((<4*p?'_70d((4!'/&e;'.q76?0jb6pwzasj$hc0": 0,
#   '(1787),': 0,
#   'sating': 0,
#   'neurons.': 0,
#   'not-so-quick': 0,
#   ...}}

# %%
### TRAIN
for category in categories:
    # Collect data strings for the current category
    data_category = [train.data[i] for i in range(len(train.data)) 
                     if train.target_names[train.target[i]] == category]

    # Initialize counts for the current category
    vocabcount_category[category] = {v: 0 for v in new_vocab}
    
    # Count occurrences of words in the current category 
    total_w = 0
    for dstr in data_category:
        words = set(dstr.lower().split())  # Convert to set for faster membership tests
        for w in words.intersection(new_vocab):  # Use intersection for efficient common elements
            total_w += 1
            vocabcount_category[category][w] += 1

    print(f"Total words in vocab for {category} = {total_w}")

    # Apply Laplace smoothing
    for k in vocabcount_category[category]:
        vocabcount_category[category][k] += 1

    # Convert counts to probabilities
    total = sum(vocabcount_category[category].values())
    for k in vocabcount_category[category]:
        vocabcount_category[category][k] /= total

    # Compute log-probabilities
    vocab_logp_category[category] = {key: np.log(value) for key, value in vocabcount_category[category].items()}
# Out:
# Total words in vocab for alt.atheism = 93469
# Total words in vocab for comp.graphics = 80125
# Total words in vocab for comp.os.ms-windows.misc = 89837
# Total words in vocab for comp.sys.ibm.pc.hardware = 78362
# Total words in vocab for comp.sys.mac.hardware = 72042
# Total words in vocab for comp.windows.x = 95287
# Total words in vocab for misc.forsale = 60799
# Total words in vocab for rec.autos = 89875
# Total words in vocab for rec.motorcycles = 86591
# Total words in vocab for rec.sport.baseball = 88539
# Total words in vocab for rec.sport.hockey = 106192
# Total words in vocab for sci.crypt = 128449
# Total words in vocab for sci.electronics = 81025
# Total words in vocab for sci.med = 107759
# Total words in vocab for sci.space = 109720
# Total words in vocab for soc.religion.christian = 124548
# Total words in vocab for talk.politics.guns = 117517
# Total words in vocab for talk.politics.mideast = 142915
# Total words in vocab for talk.politics.misc = 107829
# Total words in vocab for talk.religion.misc = 76543

# %%
### TEST
predicted_count = 0
total_samples = len(test.data)

predicted_labels = []
true_labels = []

for i in range(total_samples):
    # Extract test sample
    tsample = test.data[i]

    # Compute log probabilities for each category
    logp_category = {category: sum(vocab_logp_category[category].get(w, 0) 
                                   for w in set(tsample.lower().split())) for category in categories}

    # Find the index of the category with the maximum log probability
    predicted_index = np.argmax(list(logp_category.values()))
    
    # Get the predicted label using the index
    predicted_label = categories[predicted_index]
    predicted_labels.append(predicted_label)

    # Append true label to true_labels list
    true_label = test.target_names[test.target[i]]
    true_labels.append(true_label)

    # Compare with the true label
    if predicted_label == true_label:
        predicted_count += 1

# Calculate and print accuracy
test_accuracy = predicted_count / total_samples
print("Test Accuracy(%):", test_accuracy * 100)
# Out:
# Test Accuracy(%): 76.28783855549655

# %%
#VISUALIZATION(CONFUSION MATRIX)
cm = confusion_matrix(true_labels, predicted_labels, labels=categories)
# Plot confusion matrix as a heatmap
plt.figure(figsize=(10, 8))
sns.set(font_scale=1.2)
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=categories, yticklabels=categories)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
#VISUALIZATION(HISTOGRAM)
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.histplot(true_labels, bins=len(categories), kde=False, color='blue')
plt.title("True Label Histogram")
plt.xlabel("Categories")
plt.ylabel("Count")

plt.subplot(1, 2, 2)
sns.histplot(predicted_labels, bins=len(categories), kde=False, color='orange')
plt.title("Predicted Label Histogram")
plt.xlabel("Categories")
plt.ylabel("Count")

plt.tight_layout()
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
